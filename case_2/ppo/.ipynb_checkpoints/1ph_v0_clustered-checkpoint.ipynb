# %%
# to access functions from other locations
import sys
sys.path.append('/data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/')

# %%
# %matplotlib notebook
import numpy as np
import time
import pickle
import os
import matplotlib.pyplot as plt

import gym
from stable_baselines3.ppo import PPO, MlpPolicy
from stable_baselines3.common.vec_env import SubprocVecEnv, DummyVecEnv
from stable_baselines3.common.callbacks import CallbackList
from utils.custom_eval_callback import CustomEvalCallback
from typing import Callable

from utils.plot_functions import plot_learning

from model.ressim import Grid
from ressim_env import ResSimEnv_v0, ResSimEnv_v1, ResSimEnv_v2
from k_distributions.generate_constr_k import generate_cond_
from utils.env_wrappers import StepReset
# Out:
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
seed=1
case='1ph_v0_clustered'

# %%
os.makedirs('./data', exist_ok=True)
os.makedirs('./data/'+case, exist_ok=True)

# %%
case_ = '1ph_v0'
with open('../envs_params/env_data/env_'+case_+'_train.pkl', 'rb') as input:
    env_train = pickle.load(input)

rl_indices = [2,4,6,7,9,14,19,21,23]
with open('../envs_params/env_data/env_'+case_+'_eval.pkl', 'rb') as input:
    env_eval = pickle.load(input)
k_list_rl = env_eval.k_list[rl_indices]
env_eval.set_k(k_list_rl)
    
with open('../envs_params/env_data/env_list_'+case_+'_eval.pkl', 'rb') as input:
    envs = pickle.load(input)
    
k_train_clustered = np.load('../envs_params/k_data/k_log_md_'+case_+'_train_clustered.npy')
md_m2_conv = 1/1.01325e+15
k_train_clustered = md_m2_conv*np.exp(k_train_clustered) 
env_train.set_k(k_train_clustered)

# %%
# wrap environement
env_train = StepReset(env_train)
env_eval = StepReset(env_eval)
for env in envs:
    env = StepReset(env)

# %%
def make_env(env, rank: int, seed: int = 0) -> Callable:
    """
    Utility function for multiprocessed env.
    
    :param env_id: (str) the environment ID
    :param num_env: (int) the number of environment you wish to have in subprocesses
    :param seed: (int) the inital seed for RNG
    :param rank: (int) index of the subprocess
    :return: (Callable)
    """
    def _init() -> gym.Env:
        env_ = env
        env_.seed(seed + rank)
        return env_
    return _init

# %%
for seed in range(1,6):
    if True:
        print(f'seed {seed}')
        log_dir = './data/'+case+'/seed_'+str(seed)
        os.makedirs(log_dir, exist_ok=True)
        num_cpu = 64
        env_train.seed(seed)
        env_eval.seed(seed)
        train_callback = CustomEvalCallback(env_train, best_model_save_path=None, n_eval_episodes=1,
                             log_path=str(log_dir)+'/results_train', eval_freq=100)
        callback_list = [train_callback]
        for i in range(25):
            envs[i].seed(seed)
            eval_callback = CustomEvalCallback(envs[i], best_model_save_path=None, n_eval_episodes=1,
                             log_path=str(log_dir)+'/results_eval_'+str(i), eval_freq=300)
            callback_list.append(eval_callback)
        eval_callback = CustomEvalCallback(env_eval, best_model_save_path=str(log_dir)+'/best_model_eval', n_eval_episodes=1,
                             log_path=str(log_dir)+'/results_eval', eval_freq=100)
        callback_list.append(eval_callback)
        callback = CallbackList(callback_list)
        env = SubprocVecEnv([make_env(env_train, i, seed) for i in range(num_cpu)])
#     env = VecMonitor(env, filename=log_dir)
        print(f'seed {seed}: model definition ..')
        model = PPO(policy=MlpPolicy,
            env=env,
            learning_rate = 1e-5,
            n_steps = 4,
            batch_size = 32,
            n_epochs = 20,
            gamma = 0.99,
            gae_lambda = 0.95,
            clip_range = 0.2,
            clip_range_vf = None,
            ent_coef = 0.001,
            vf_coef = 0.5,
            max_grad_norm = 0.5,
            use_sde= False,
            create_eval_env= False,
            policy_kwargs = dict(net_arch=[4000,2000,800,300], log_std_init=-1.9),
            verbose = 1,
            target_kl =0.05,
            seed = seed,
            device = "auto")
        print(f'seed {seed}: learning ..')
        model.learn(total_timesteps=300000, callback=callback)
        model.save(log_dir+'/PPO')
        fig = plot_learning(log_dir, case='train')
        fig.savefig(log_dir+'/learn_train.png')
        fig = plot_learning(log_dir, case='eval')
        fig.savefig(log_dir+'/learn_eval.png')
# Out:
# seed 1
# seed 1: model definition ..
# Using cuda device
# seed 1: learning ..
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5597576908>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5597576940>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5597576978>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f55975769e8>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5597576a58>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5597576ac8>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5597576b38>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5597576ba8>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5597591e10>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5597576c50>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5597576c88>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5597576cf8>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5597576d68>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5597576dd8>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5597576e48>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5597576eb8>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5597576f28>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5597576f98>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f559755d080>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f559755d0b8>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f559755d128>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f559755d198>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f559755d208>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f559755d278>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f559755d2e8>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f559755d358>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f559758b550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f559755d3c8>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ----------------------------
# | time/              |     |
# |    fps             | 142 |
# |    iterations      | 1   |
# |    time_elapsed    | 1   |
# |    total_timesteps | 256 |
# ----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 512         |
# | train/                  |             |
# |    approx_kl            | 0.010806677 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.92        |
# |    explained_variance   | 0.24        |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0405     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0442     |
# |    std                  | 0.15        |
# |    value_loss           | 0.0171      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 79         |
# |    iterations           | 3          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 768        |
# | train/                  |            |
# |    approx_kl            | 0.02440685 |
# |    clip_fraction        | 0.236      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.93       |
# |    explained_variance   | 0.681      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0619    |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0601    |
# |    std                  | 0.149      |
# |    value_loss           | 0.00241    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 0.016796382 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.93        |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0732     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0643     |
# |    std                  | 0.149       |
# |    value_loss           | 0.00336     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 5           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 1280        |
# | train/                  |             |
# |    approx_kl            | 0.028639987 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.93        |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.125      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.072      |
# |    std                  | 0.149       |
# |    value_loss           | 0.00216     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 72         |
# |    iterations           | 6          |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 1536       |
# | train/                  |            |
# |    approx_kl            | 0.03486114 |
# |    clip_fraction        | 0.277      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.93       |
# |    explained_variance   | 0.882      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.115     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.07      |
# |    std                  | 0.149      |
# |    value_loss           | 0.00223    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 7           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 1792        |
# | train/                  |             |
# |    approx_kl            | 0.036241554 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.93        |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0881     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0761     |
# |    std                  | 0.149       |
# |    value_loss           | 0.00178     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 8          |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 2048       |
# | train/                  |            |
# |    approx_kl            | 0.06523922 |
# |    clip_fraction        | 0.317      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.93       |
# |    explained_variance   | 0.888      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0897    |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0741    |
# |    std                  | 0.149      |
# |    value_loss           | 0.00231    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 9           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 2304        |
# | train/                  |             |
# |    approx_kl            | 0.033269458 |
# |    clip_fraction        | 0.331       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.93        |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.101      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0745     |
# |    std                  | 0.149       |
# |    value_loss           | 0.00215     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 10          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.030987203 |
# |    clip_fraction        | 0.363       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.93        |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0973     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0778     |
# |    std                  | 0.149       |
# |    value_loss           | 0.00802     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 11          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 2816        |
# | train/                  |             |
# |    approx_kl            | 0.023389904 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.94        |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0938     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0762     |
# |    std                  | 0.149       |
# |    value_loss           | 0.00334     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 12          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.050084084 |
# |    clip_fraction        | 0.395       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.94        |
# |    explained_variance   | 0.881       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.136      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0822     |
# |    std                  | 0.149       |
# |    value_loss           | 0.0019      |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 68        |
# |    iterations           | 13        |
# |    time_elapsed         | 48        |
# |    total_timesteps      | 3328      |
# | train/                  |           |
# |    approx_kl            | 0.0389212 |
# |    clip_fraction        | 0.388     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 1.94      |
# |    explained_variance   | 0.896     |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.138    |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -0.0857   |
# |    std                  | 0.149     |
# |    value_loss           | 0.0019    |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 14          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 0.041786574 |
# |    clip_fraction        | 0.367       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.94        |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.114      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0822     |
# |    std                  | 0.149       |
# |    value_loss           | 0.00182     |
# -----------------------------------------
# Early stopping at step 13 due to reaching max kl: 0.08
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 15         |
# |    time_elapsed         | 55         |
# |    total_timesteps      | 3840       |
# | train/                  |            |
# |    approx_kl            | 0.08154045 |
# |    clip_fraction        | 0.329      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.94       |
# |    explained_variance   | 0.936      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.118     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0754    |
# |    std                  | 0.149      |
# |    value_loss           | 0.00156    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 16          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.055364415 |
# |    clip_fraction        | 0.431       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.94        |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0747     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0808     |
# |    std                  | 0.149       |
# |    value_loss           | 0.00148     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 17          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 4352        |
# | train/                  |             |
# |    approx_kl            | 0.069996834 |
# |    clip_fraction        | 0.389       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.95        |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.13       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0808     |
# |    std                  | 0.149       |
# |    value_loss           | 0.00141     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 18         |
# |    time_elapsed         | 67         |
# |    total_timesteps      | 4608       |
# | train/                  |            |
# |    approx_kl            | 0.06617157 |
# |    clip_fraction        | 0.416      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.95       |
# |    explained_variance   | 0.869      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0981    |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0908    |
# |    std                  | 0.149      |
# |    value_loss           | 0.00194    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 19         |
# |    time_elapsed         | 70         |
# |    total_timesteps      | 4864       |
# | train/                  |            |
# |    approx_kl            | 0.03339829 |
# |    clip_fraction        | 0.4        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.95       |
# |    explained_variance   | 0.909      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.104     |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0828    |
# |    std                  | 0.149      |
# |    value_loss           | 0.00218    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 20         |
# |    time_elapsed         | 74         |
# |    total_timesteps      | 5120       |
# | train/                  |            |
# |    approx_kl            | 0.05754497 |
# |    clip_fraction        | 0.424      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.95       |
# |    explained_variance   | 0.9        |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0929    |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0842    |
# |    std                  | 0.148      |
# |    value_loss           | 0.00162    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 21         |
# |    time_elapsed         | 78         |
# |    total_timesteps      | 5376       |
# | train/                  |            |
# |    approx_kl            | 0.06874619 |
# |    clip_fraction        | 0.416      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.95       |
# |    explained_variance   | 0.931      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.105     |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0825    |
# |    std                  | 0.148      |
# |    value_loss           | 0.00155    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 22         |
# |    time_elapsed         | 82         |
# |    total_timesteps      | 5632       |
# | train/                  |            |
# |    approx_kl            | 0.05157335 |
# |    clip_fraction        | 0.406      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.96       |
# |    explained_variance   | 0.923      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.1       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0801    |
# |    std                  | 0.148      |
# |    value_loss           | 0.00157    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 23          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 5888        |
# | train/                  |             |
# |    approx_kl            | 0.032273922 |
# |    clip_fraction        | 0.433       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.96        |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.109      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0908     |
# |    std                  | 0.148       |
# |    value_loss           | 0.0029      |
# -----------------------------------------
# Early stopping at step 17 due to reaching max kl: 0.08
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 24          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.075598195 |
# |    clip_fraction        | 0.413       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.96        |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.142      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.087      |
# |    std                  | 0.148       |
# |    value_loss           | 0.00314     |
# -----------------------------------------
# Eval num_timesteps=6400, episode_reward=0.59 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=6400, episode_reward=0.58 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.577       |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 25          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.050793584 |
# |    clip_fraction        | 0.427       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.96        |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0836     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0863     |
# |    std                  | 0.148       |
# |    value_loss           | 0.00125     |
# -----------------------------------------
# Early stopping at step 9 due to reaching max kl: 0.09
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 63         |
# |    iterations           | 26         |
# |    time_elapsed         | 105        |
# |    total_timesteps      | 6656       |
# | train/                  |            |
# |    approx_kl            | 0.08797833 |
# |    clip_fraction        | 0.271      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.96       |
# |    explained_variance   | 0.898      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0941    |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0598    |
# |    std                  | 0.148      |
# |    value_loss           | 0.00242    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 27          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 6912        |
# | train/                  |             |
# |    approx_kl            | 0.066121265 |
# |    clip_fraction        | 0.441       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.96        |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.12       |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0806     |
# |    std                  | 0.148       |
# |    value_loss           | 0.0016      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 63         |
# |    iterations           | 28         |
# |    time_elapsed         | 113        |
# |    total_timesteps      | 7168       |
# | train/                  |            |
# |    approx_kl            | 0.00461104 |
# |    clip_fraction        | 0.437      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.96       |
# |    explained_variance   | 0.922      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.112     |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.0845    |
# |    std                  | 0.148      |
# |    value_loss           | 0.00188    |
# ----------------------------------------
# Early stopping at step 17 due to reaching max kl: 0.08
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 63         |
# |    iterations           | 29         |
# |    time_elapsed         | 116        |
# |    total_timesteps      | 7424       |
# | train/                  |            |
# |    approx_kl            | 0.07813254 |
# |    clip_fraction        | 0.444      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.96       |
# |    explained_variance   | 0.944      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.118     |
# |    n_updates            | 560        |
# |    policy_gradient_loss | -0.0927    |
# |    std                  | 0.148      |
# |    value_loss           | 0.00134    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 30          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.041090734 |
# |    clip_fraction        | 0.472       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.96        |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.124      |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0936     |
# |    std                  | 0.148       |
# |    value_loss           | 0.00155     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 31          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 7936        |
# | train/                  |             |
# |    approx_kl            | 0.027237339 |
# |    clip_fraction        | 0.452       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.97        |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.114      |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0918     |
# |    std                  | 0.148       |
# |    value_loss           | 0.00137     |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 64        |
# |    iterations           | 32        |
# |    time_elapsed         | 127       |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.0419396 |
# |    clip_fraction        | 0.457     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 1.97      |
# |    explained_variance   | 0.934     |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.119    |
# |    n_updates            | 620       |
# |    policy_gradient_loss | -0.0844   |
# |    std                  | 0.148     |
# |    value_loss           | 0.00125   |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 33          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 8448        |
# | train/                  |             |
# |    approx_kl            | 0.052326225 |
# |    clip_fraction        | 0.451       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.97        |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.113      |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.0918     |
# |    std                  | 0.148       |
# |    value_loss           | 0.00179     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 34         |
# |    time_elapsed         | 135        |
# |    total_timesteps      | 8704       |
# | train/                  |            |
# |    approx_kl            | 0.05424126 |
# |    clip_fraction        | 0.435      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.97       |
# |    explained_variance   | 0.941      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.113     |
# |    n_updates            | 660        |
# |    policy_gradient_loss | -0.0882    |
# |    std                  | 0.148      |
# |    value_loss           | 0.00129    |
# ----------------------------------------
# Early stopping at step 12 due to reaching max kl: 0.08
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 35         |
# |    time_elapsed         | 138        |
# |    total_timesteps      | 8960       |
# | train/                  |            |
# |    approx_kl            | 0.07661004 |
# |    clip_fraction        | 0.39       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.97       |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0983    |
# |    n_updates            | 680        |
# |    policy_gradient_loss | -0.0762    |
# |    std                  | 0.148      |
# |    value_loss           | 0.0023     |
# ----------------------------------------
# Early stopping at step 18 due to reaching max kl: 0.08
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 36         |
# |    time_elapsed         | 141        |
# |    total_timesteps      | 9216       |
# | train/                  |            |
# |    approx_kl            | 0.08005932 |
# |    clip_fraction        | 0.423      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.97       |
# |    explained_variance   | 0.917      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.125     |
# |    n_updates            | 700        |
# |    policy_gradient_loss | -0.0827    |
# |    std                  | 0.148      |
# |    value_loss           | 0.00172    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 65          |
# |    iterations           | 37          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 9472        |
# | train/                  |             |
# |    approx_kl            | 0.059091493 |
# |    clip_fraction        | 0.479       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.98        |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.108      |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.0932     |
# |    std                  | 0.148       |
# |    value_loss           | 0.00207     |
# -----------------------------------------
# Early stopping at step 16 due to reaching max kl: 0.08
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 65          |
# |    iterations           | 38          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 9728        |
# | train/                  |             |
# |    approx_kl            | 0.075724736 |
# |    clip_fraction        | 0.428       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.98        |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0952     |
# |    n_updates            | 740         |
# |    policy_gradient_loss | -0.0785     |
# |    std                  | 0.148       |
# |    value_loss           | 0.00182     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 65          |
# |    iterations           | 39          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 9984        |
# | train/                  |             |
# |    approx_kl            | 0.043937527 |
# |    clip_fraction        | 0.473       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.98        |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.104      |
# |    n_updates            | 760         |
# |    policy_gradient_loss | -0.0872     |
# |    std                  | 0.147       |
# |    value_loss           | 0.0014      |
# -----------------------------------------
# Early stopping at step 18 due to reaching max kl: 0.08
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 65        |
# |    iterations           | 40        |
# |    time_elapsed         | 156       |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0754585 |
# |    clip_fraction        | 0.437     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 1.98      |
# |    explained_variance   | 0.933     |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.127    |
# |    n_updates            | 780       |
# |    policy_gradient_loss | -0.0851   |
# |    std                  | 0.147     |
# |    value_loss           | 0.00188   |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 65          |
# |    iterations           | 41          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 10496       |
# | train/                  |             |
# |    approx_kl            | 0.042106606 |
# |    clip_fraction        | 0.51        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.98        |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.137      |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.0966     |
# |    std                  | 0.147       |
# |    value_loss           | 0.00134     |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 65        |
# |    iterations           | 42        |
# |    time_elapsed         | 164       |
# |    total_timesteps      | 10752     |
# | train/                  |           |
# |    approx_kl            | 0.0528017 |
# |    clip_fraction        | 0.479     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 1.98      |
# |    explained_variance   | 0.949     |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.0838   |
# |    n_updates            | 820       |
# |    policy_gradient_loss | -0.0897   |
# |    std                  | 0.147     |
# |    value_loss           | 0.00107   |
# ---------------------------------------
# Early stopping at step 7 due to reaching max kl: 0.08
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 43          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 11008       |
# | train/                  |             |
# |    approx_kl            | 0.078966156 |
# |    clip_fraction        | 0.366       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.99        |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0449     |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0653     |
# |    std                  | 0.147       |
# |    value_loss           | 0.0018      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 44          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.043340422 |
# |    clip_fraction        | 0.445       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.99        |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.113      |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0864     |
# |    std                  | 0.147       |
# |    value_loss           | 0.00126     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 66         |
# |    iterations           | 45         |
# |    time_elapsed         | 173        |
# |    total_timesteps      | 11520      |
# | train/                  |            |
# |    approx_kl            | 0.02811397 |
# |    clip_fraction        | 0.455      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.99       |
# |    explained_variance   | 0.922      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.121     |
# |    n_updates            | 880        |
# |    policy_gradient_loss | -0.0982    |
# |    std                  | 0.147      |
# |    value_loss           | 0.00134    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 46          |
# ...
# |    iterations           | 364        |
# |    time_elapsed         | 1239       |
# |    total_timesteps      | 93184      |
# | train/                  |            |
# |    approx_kl            | 0.07683349 |
# |    clip_fraction        | 0.583      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.19       |
# |    explained_variance   | 0.946      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.114     |
# |    n_updates            | 7260       |
# |    policy_gradient_loss | -0.0997    |
# |    std                  | 0.14       |
# |    value_loss           | 0.00119    |
# ----------------------------------------
# Early stopping at step 15 due to reaching max kl: 0.09
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 75         |
# |    iterations           | 365        |
# |    time_elapsed         | 1243       |
# |    total_timesteps      | 93440      |
# | train/                  |            |
# |    approx_kl            | 0.08856127 |
# |    clip_fraction        | 0.613      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.19       |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.113     |
# |    n_updates            | 7280       |
# |    policy_gradient_loss | -0.0916    |
# |    std                  | 0.14       |
# |    value_loss           | 0.00118    |
# ----------------------------------------
# Early stopping at step 12 due to reaching max kl: 0.08
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 75         |
# |    iterations           | 366        |
# |    time_elapsed         | 1245       |
# |    total_timesteps      | 93696      |
# | train/                  |            |
# |    approx_kl            | 0.08391853 |
# |    clip_fraction        | 0.495      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.19       |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0884    |
# |    n_updates            | 7300       |
# |    policy_gradient_loss | -0.0808    |
# |    std                  | 0.14       |
# |    value_loss           | 0.00127    |
# ----------------------------------------
# Early stopping at step 5 due to reaching max kl: 0.10
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 75         |
# |    iterations           | 367        |
# |    time_elapsed         | 1247       |
# |    total_timesteps      | 93952      |
# | train/                  |            |
# |    approx_kl            | 0.09553027 |
# |    clip_fraction        | 0.354      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.19       |
# |    explained_variance   | 0.91       |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0836    |
# |    n_updates            | 7320       |
# |    policy_gradient_loss | -0.0569    |
# |    std                  | 0.14       |
# |    value_loss           | 0.00203    |
# ----------------------------------------
# Early stopping at step 11 due to reaching max kl: 0.09
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 75         |
# |    iterations           | 368        |
# |    time_elapsed         | 1250       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.09276287 |
# |    clip_fraction        | 0.453      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.19       |
# |    explained_variance   | 0.957      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.108     |
# |    n_updates            | 7340       |
# |    policy_gradient_loss | -0.0744    |
# |    std                  | 0.14       |
# |    value_loss           | 0.00102    |
# ----------------------------------------
# Early stopping at step 8 due to reaching max kl: 0.08
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 369         |
# |    time_elapsed         | 1252        |
# |    total_timesteps      | 94464       |
# | train/                  |             |
# |    approx_kl            | 0.077841714 |
# |    clip_fraction        | 0.449       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.19        |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.121      |
# |    n_updates            | 7360        |
# |    policy_gradient_loss | -0.0737     |
# |    std                  | 0.14        |
# |    value_loss           | 0.00132     |
# -----------------------------------------
# Early stopping at step 8 due to reaching max kl: 0.08
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 75         |
# |    iterations           | 370        |
# |    time_elapsed         | 1254       |
# |    total_timesteps      | 94720      |
# | train/                  |            |
# |    approx_kl            | 0.07914272 |
# |    clip_fraction        | 0.398      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.19       |
# |    explained_variance   | 0.946      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0926    |
# |    n_updates            | 7380       |
# |    policy_gradient_loss | -0.0698    |
# |    std                  | 0.14       |
# |    value_loss           | 0.00172    |
# ----------------------------------------
# Early stopping at step 12 due to reaching max kl: 0.08
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 371         |
# |    time_elapsed         | 1257        |
# |    total_timesteps      | 94976       |
# | train/                  |             |
# |    approx_kl            | 0.077203766 |
# |    clip_fraction        | 0.491       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.19        |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0941     |
# |    n_updates            | 7400        |
# |    policy_gradient_loss | -0.0822     |
# |    std                  | 0.14        |
# |    value_loss           | 0.00133     |
# -----------------------------------------
# Early stopping at step 15 due to reaching max kl: 0.08
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 75         |
# |    iterations           | 372        |
# |    time_elapsed         | 1260       |
# |    total_timesteps      | 95232      |
# | train/                  |            |
# |    approx_kl            | 0.07846685 |
# |    clip_fraction        | 0.531      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.19       |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.122     |
# |    n_updates            | 7420       |
# |    policy_gradient_loss | -0.0947    |
# |    std                  | 0.14       |
# |    value_loss           | 0.0011     |
# ----------------------------------------
# Early stopping at step 5 due to reaching max kl: 0.08
# --------------------------------------
# | time/                   |          |
# |    fps                  | 75       |
# |    iterations           | 373      |
# |    time_elapsed         | 1262     |
# |    total_timesteps      | 95488    |
# | train/                  |          |
# |    approx_kl            | 0.079888 |
# |    clip_fraction        | 0.33     |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 2.2      |
# |    explained_variance   | 0.962    |
# |    learning_rate        | 1e-05    |
# |    loss                 | -0.0782  |
# |    n_updates            | 7440     |
# |    policy_gradient_loss | -0.0518  |
# |    std                  | 0.14     |
# |    value_loss           | 0.00149  |
# --------------------------------------
# Early stopping at step 9 due to reaching max kl: 0.09
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 75         |
# |    iterations           | 374        |
# |    time_elapsed         | 1264       |
# |    total_timesteps      | 95744      |
# | train/                  |            |
# |    approx_kl            | 0.09093009 |
# |    clip_fraction        | 0.455      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.2        |
# |    explained_variance   | 0.955      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.124     |
# |    n_updates            | 7460       |
# |    policy_gradient_loss | -0.0768    |
# |    std                  | 0.14       |
# |    value_loss           | 0.00131    |
# ----------------------------------------
# Early stopping at step 3 due to reaching max kl: 0.08
# Eval num_timesteps=96000, episode_reward=0.60 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=96000, episode_reward=0.50 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=96000, episode_reward=0.58 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=96000, episode_reward=0.55 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=96000, episode_reward=0.53 +/- 0.00
# Episode length: 5.00 +/- 0.00
# Eval num_timesteps=96000, episode_reward=0.64 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=96000, episode_reward=0.56 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=96000, episode_reward=0.57 +/- 0.00
# Episode length: 5.00 +/- 0.00
# Eval num_timesteps=96000, episode_reward=0.52 +/- 0.00
# Episode length: 5.00 +/- 0.00
# Eval num_timesteps=96000, episode_reward=0.52 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=96000, episode_reward=0.55 +/- 0.00
# Episode length: 5.00 +/- 0.00
# Eval num_timesteps=96000, episode_reward=0.60 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=96000, episode_reward=0.58 +/- 0.00
# Episode length: 5.00 +/- 0.00
# Eval num_timesteps=96000, episode_reward=0.60 +/- 0.00
# Episode length: 5.00 +/- 0.00
# Eval num_timesteps=96000, episode_reward=0.50 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=96000, episode_reward=0.55 +/- 0.00
# Episode length: 5.00 +/- 0.00
# Eval num_timesteps=96000, episode_reward=0.58 +/- 0.00
# Episode length: 5.00 +/- 0.00
# Eval num_timesteps=96000, episode_reward=0.57 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=96000, episode_reward=0.53 +/- 0.00
# Episode length: 5.00 +/- 0.00
# Eval num_timesteps=96000, episode_reward=0.59 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=96000, episode_reward=0.59 +/- 0.00
# Episode length: 5.00 +/- 0.00
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/ad181/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-5cd9c39318b9>", line 45, in <module>
#     model.learn(total_timesteps=300000, callback=callback)
#   File "/home/ad181/anaconda3/lib/python3.7/site-packages/stable_baselines3/ppo/ppo.py", line 264, in learn
#     reset_num_timesteps=reset_num_timesteps,
#   File "/home/ad181/anaconda3/lib/python3.7/site-packages/stable_baselines3/common/on_policy_algorithm.py", line 222, in learn
#     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#   File "/home/ad181/anaconda3/lib/python3.7/site-packages/stable_baselines3/common/on_policy_algorithm.py", line 169, in collect_rollouts
#     if callback.on_step() is False:
#   File "/home/ad181/anaconda3/lib/python3.7/site-packages/stable_baselines3/common/callbacks.py", line 88, in on_step
#     return self._on_step()
#   File "/home/ad181/anaconda3/lib/python3.7/site-packages/stable_baselines3/common/callbacks.py", line 192, in _on_step
#     continue_training = callback.on_step() and continue_training
#   File "/home/ad181/anaconda3/lib/python3.7/site-packages/stable_baselines3/common/callbacks.py", line 88, in on_step
#     return self._on_step()
#   File "/data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py", line 115, in _on_step
#     return_episode_rewards=True,
#   File "/data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py", line 27, in custom_evaluate_policy
#     state, reward, done, info = eval_env.step(action)
#   File "/data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/ressim_env.py", line 151, in step
#     state, reward, done, info = self.sim_step(q)
#   File "/data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/ressim_env.py", line 127, in sim_step
#     self.solverS.step(self.dt)
#   File "/data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/model/ressim.py", line 357, in step
#     s = self.solve(residual, s0=s, residual_jac=residual_jac)
#   File "/data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/model/ressim.py", line 466, in solve
#     return scipy.optimize.nonlin.nonlin_solve(residual, s0, jacobian=residual_jac)
#   File "/home/ad181/anaconda3/lib/python3.7/site-packages/scipy/optimize/nonlin.py", line 312, in nonlin_solve
#     dx = -jacobian.solve(Fx, tol=tol)
#   File "/home/ad181/anaconda3/lib/python3.7/site-packages/scipy/optimize/nonlin.py", line 618, in solve
#     return spsolve(m, v)
#   File "/home/ad181/anaconda3/lib/python3.7/site-packages/scipy/sparse/linalg/dsolve/linsolve.py", line 196, in spsolve
#     b, flag, options=options)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ad181/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ad181/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1148, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/ad181/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/ad181/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/ad181/anaconda3/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/ad181/anaconda3/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/ad181/anaconda3/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/ad181/anaconda3/lib/python3.7/inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "/home/ad181/anaconda3/lib/python3.7/inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/home/ad181/anaconda3/lib/python3.7/inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "/home/ad181/anaconda3/lib/python3.7/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
