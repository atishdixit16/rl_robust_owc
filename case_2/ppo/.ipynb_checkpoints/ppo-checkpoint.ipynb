# %%
# to access functions from other locations
import sys
sys.path.append('/data/ad181/RemoteDir/rl_robust_owc')

# %%
# %matplotlib notebook
import numpy as np
import time
import pickle
import os
import matplotlib.pyplot as plt

import gym
from stable_baselines3.ppo import PPO, MlpPolicy
from stable_baselines3.common.vec_env import SubprocVecEnv, DummyVecEnv
from stable_baselines3.common.callbacks import CallbackList
from utils.custom_eval_callback import CustomEvalCallback
from typing import Callable

from utils.plot_functions import plot_learning

from model.ressim import Grid
from ressim_env import ResSimEnv_v0, ResSimEnv_v1, ResSimEnv_v2
from k_distributions.generate_constr_k import generate_cond_
from utils.env_wrappers import StepReset, StateCoarse
# Out:
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
seed=1
case='case_2_ppo'

# %%
os.makedirs('./data', exist_ok=True)
os.makedirs('./data/'+case, exist_ok=True)

# %%
with open('../envs_params/env_data/env_train.pkl', 'rb') as input:
    env_train = pickle.load(input)

with open('../envs_params/env_data/env_eval.pkl', 'rb') as input:
    env_eval = pickle.load(input)

# %%
# env wrapper to reduce state space
x_coords, y_coords = env_train.p_x, env_train.p_y

def env_wrappers(env, x_coords, y_coords):
    env = StepReset(env)
    env = StateCoarse(env, x_coords, y_coords, include_well_pr=True)
    return env

# %%
# env_train = env_wrappers(env_train, x_coords, y_coords)
# print(env_train.observation_space)
# base_action = np.ones(env_train.action_space.shape[0])

# state, done = env_train.reset(), False
# print(state)
# while not done:
#     state, reward, done, info = env_train.step(base_action)
#     print(state)

# %%
def make_env(env, rank: int, seed: int) -> Callable:
    """
    Utility function for multiprocessed env.
    
    :param env_id: (str) the environment ID
    :param num_env: (int) the number of environment you wish to have in subprocesses
    :param seed: (int) the inital seed for RNG
    :param rank: (int) index of the subprocess
    :return: (Callable)
    """
    def _init() -> gym.Env:
        env_ = env
        env_.seed(seed + rank)
        return env_
    return _init

# %%
for seed in range(1,4):
    if True:
        print(f'seed {seed}')
        log_dir = './data/'+case+'/seed_'+str(seed)
        os.makedirs(log_dir, exist_ok=True)
        num_cpu = 64
        env_train.seed(seed)
        env_eval.seed(seed)
        env_train_ = env_wrappers(env_train, x_coords, y_coords)
        env_eval_ = env_wrappers(env_eval, x_coords, y_coords)
        train_callback = CustomEvalCallback(env_train_, 
                                            best_model_save_path=None, 
                                            n_eval_episodes=1,
                                            log_path=str(log_dir)+'/results_train', 
                                            eval_freq=100)
        callback_list = [train_callback]
        eval_callback = CustomEvalCallback(env_eval_, 
                                           best_model_save_path=str(log_dir)+'/best_model_eval', 
                                           n_eval_episodes=1,
                                           log_path=str(log_dir)+'/results_eval', 
                                           eval_freq=100)
        callback_list.append(eval_callback)
        callback = CallbackList(callback_list)
        env = SubprocVecEnv([make_env(env_train_, i, seed) for i in range(num_cpu)])
        print(env.observation_space)
        print(f'seed {seed}: model definition ..')
        model = PPO(policy=MlpPolicy,
                env=env,
                learning_rate = 5e-5,
                n_steps = 50,
                batch_size = 16,
                n_epochs = 20,
                gamma = 0.99,
                gae_lambda = 0.95,
                clip_range = 0.1,
                clip_range_vf = None,
                ent_coef = 0.001,
                vf_coef = 0.5,
                max_grad_norm = 0.5,
                use_sde= False,
                create_eval_env= False,
                policy_kwargs = dict(net_arch=[20,20], log_std_init=-1.9),
                verbose = 1,
                target_kl =0.05,
                seed = seed,
                device = "auto")
        print(f'seed {seed}: learning ..')
        model.learn(total_timesteps=300000, callback=callback)
        model.save(log_dir+'/PPO')
        fig = plot_learning(log_dir, case='train')
        fig.savefig(log_dir+'/learn_train.png')
        fig = plot_learning(log_dir, case='eval')
        fig.savefig(log_dir+'/learn_eval.png')
# Out:
# seed 1
# Box(-100000.0, 100000.0, (9,), float64)
# seed 1: model definition ..
# Using cuda device
# seed 1: learning ..
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:106: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f6cfc3c1240> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f6cfc3c1198>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:106: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f6cfc3c1240> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f6cfc3c11d0>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# -----------------------------
# | time/              |      |
# |    fps             | 251  |
# |    iterations      | 1    |
# |    time_elapsed    | 12   |
# |    total_timesteps | 3200 |
# -----------------------------
# Eval num_timesteps=6400, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=6400, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 4            |
# |    mean_reward          | 0.572        |
# | time/                   |              |
# |    fps                  | 109          |
# |    iterations           | 2            |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 0.0026606661 |
# |    clip_fraction        | 0.106        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.41         |
# |    explained_variance   | -0.0327      |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00595     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00373     |
# |    std                  | 0.149        |
# |    value_loss           | 0.0461       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 95           |
# |    iterations           | 3            |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 9600         |
# | train/                  |              |
# |    approx_kl            | 0.0048113796 |
# |    clip_fraction        | 0.143        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.41         |
# |    explained_variance   | 0.765        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0202      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00744     |
# |    std                  | 0.149        |
# |    value_loss           | 0.00305      |
# ------------------------------------------
# Eval num_timesteps=12800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=12800, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 4            |
# |    mean_reward          | 0.599        |
# | time/                   |              |
# |    fps                  | 87           |
# |    iterations           | 4            |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 12800        |
# | train/                  |              |
# |    approx_kl            | 0.0020898313 |
# |    clip_fraction        | 0.12         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.43         |
# |    explained_variance   | 0.909        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0135      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00738     |
# |    std                  | 0.149        |
# |    value_loss           | 0.00256      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 5           |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 16000       |
# | train/                  |             |
# |    approx_kl            | 0.004645577 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.45        |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0154     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00883    |
# |    std                  | 0.148       |
# |    value_loss           | 0.00251     |
# -----------------------------------------
# Eval num_timesteps=19200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=19200, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 4            |
# |    mean_reward          | 0.6          |
# | time/                   |              |
# |    fps                  | 84           |
# |    iterations           | 6            |
# |    time_elapsed         | 227          |
# |    total_timesteps      | 19200        |
# | train/                  |              |
# |    approx_kl            | 0.0038763771 |
# |    clip_fraction        | 0.137        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.47         |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0153       |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00779     |
# |    std                  | 0.148        |
# |    value_loss           | 0.00224      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 7           |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 22400       |
# | train/                  |             |
# |    approx_kl            | 0.002626293 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.47        |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0139     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00992    |
# |    std                  | 0.148       |
# |    value_loss           | 0.0021      |
# -----------------------------------------
# Eval num_timesteps=25600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=25600, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# --------------------------------------------
# | eval/                   |                |
# |    mean_ep_length       | 4              |
# |    mean_reward          | 0.603          |
# | time/                   |                |
# |    fps                  | 83             |
# |    iterations           | 8              |
# |    time_elapsed         | 307            |
# |    total_timesteps      | 25600          |
# | train/                  |                |
# |    approx_kl            | -0.00015081782 |
# |    clip_fraction        | 0.17           |
# |    clip_range           | 0.1            |
# |    entropy_loss         | 2.48           |
# |    explained_variance   | 0.928          |
# |    learning_rate        | 5e-05          |
# |    loss                 | -0.00788       |
# |    n_updates            | 140            |
# |    policy_gradient_loss | -0.0099        |
# |    std                  | 0.147          |
# |    value_loss           | 0.00216        |
# --------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 9           |
# |    time_elapsed         | 341         |
# |    total_timesteps      | 28800       |
# | train/                  |             |
# |    approx_kl            | 0.003227567 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.5         |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0306     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00756    |
# |    std                  | 0.147       |
# |    value_loss           | 0.00197     |
# -----------------------------------------
# Eval num_timesteps=32000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=32000, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 4            |
# |    mean_reward          | 0.599        |
# | time/                   |              |
# |    fps                  | 82           |
# |    iterations           | 10           |
# |    time_elapsed         | 387          |
# |    total_timesteps      | 32000        |
# | train/                  |              |
# |    approx_kl            | 0.0033566551 |
# |    clip_fraction        | 0.137        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.52         |
# |    explained_variance   | 0.932        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0262       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00814     |
# |    std                  | 0.146        |
# |    value_loss           | 0.00209      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 11           |
# |    time_elapsed         | 422          |
# |    total_timesteps      | 35200        |
# | train/                  |              |
# |    approx_kl            | 0.0017997539 |
# |    clip_fraction        | 0.164        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.54         |
# |    explained_variance   | 0.932        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0124      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00889     |
# |    std                  | 0.145        |
# |    value_loss           | 0.00205      |
# ------------------------------------------
# Eval num_timesteps=38400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=38400, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 4           |
# |    mean_reward          | 0.602       |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 12          |
# |    time_elapsed         | 469         |
# |    total_timesteps      | 38400       |
# | train/                  |             |
# |    approx_kl            | 0.005264798 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.55        |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.00695     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00577    |
# |    std                  | 0.145       |
# |    value_loss           | 0.00202     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 13          |
# |    time_elapsed         | 506         |
# |    total_timesteps      | 41600       |
# | train/                  |             |
# |    approx_kl            | 0.002126648 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.56        |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.00461    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00671    |
# |    std                  | 0.145       |
# |    value_loss           | 0.00203     |
# -----------------------------------------
# Eval num_timesteps=44800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=44800, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 4            |
# |    mean_reward          | 0.602        |
# | time/                   |              |
# |    fps                  | 81           |
# |    iterations           | 14           |
# |    time_elapsed         | 550          |
# |    total_timesteps      | 44800        |
# | train/                  |              |
# |    approx_kl            | 0.0017814265 |
# |    clip_fraction        | 0.124        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.58         |
# |    explained_variance   | 0.938        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0111       |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00627     |
# |    std                  | 0.144        |
# |    value_loss           | 0.0019       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 80           |
# |    iterations           | 15           |
# |    time_elapsed         | 593          |
# |    total_timesteps      | 48000        |
# | train/                  |              |
# |    approx_kl            | 0.0027732977 |
# |    clip_fraction        | 0.147        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.58         |
# |    explained_variance   | 0.935        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0115      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00682     |
# |    std                  | 0.144        |
# |    value_loss           | 0.00198      |
# ------------------------------------------
# Eval num_timesteps=51200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=51200, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 4            |
# |    mean_reward          | 0.604        |
# | time/                   |              |
# |    fps                  | 80           |
# |    iterations           | 16           |
# |    time_elapsed         | 637          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0022739274 |
# |    clip_fraction        | 0.106        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.6          |
# |    explained_variance   | 0.935        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00289     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00517     |
# |    std                  | 0.144        |
# |    value_loss           | 0.00204      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 80           |
# |    iterations           | 17           |
# |    time_elapsed         | 672          |
# |    total_timesteps      | 54400        |
# | train/                  |              |
# |    approx_kl            | 0.0034653984 |
# |    clip_fraction        | 0.127        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.62         |
# |    explained_variance   | 0.935        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00214     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00606     |
# |    std                  | 0.143        |
# |    value_loss           | 0.00193      |
# ------------------------------------------
# Eval num_timesteps=57600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=57600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 4            |
# |    mean_reward          | 0.605        |
# | time/                   |              |
# |    fps                  | 80           |
# |    iterations           | 18           |
# |    time_elapsed         | 719          |
# |    total_timesteps      | 57600        |
# | train/                  |              |
# |    approx_kl            | 0.0034736274 |
# |    clip_fraction        | 0.152        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.65         |
# |    explained_variance   | 0.939        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.00679      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00724     |
# |    std                  | 0.142        |
# |    value_loss           | 0.00192      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 19          |
# |    time_elapsed         | 755         |
# |    total_timesteps      | 60800       |
# | train/                  |             |
# |    approx_kl            | 0.003726213 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.68        |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.026      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00654    |
# |    std                  | 0.141       |
# |    value_loss           | 0.00195     |
# -----------------------------------------
# Eval num_timesteps=64000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=64000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 4            |
# |    mean_reward          | 0.607        |
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 20           |
# |    time_elapsed         | 805          |
# |    total_timesteps      | 64000        |
# | train/                  |              |
# |    approx_kl            | 0.0023344038 |
# |    clip_fraction        | 0.136        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.7          |
# |    explained_variance   | 0.936        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0106      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00687     |
# |    std                  | 0.141        |
# |    value_loss           | 0.00196      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 21          |
# |    time_elapsed         | 839         |
# |    total_timesteps      | 67200       |
# | train/                  |             |
# |    approx_kl            | 0.003917414 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.73        |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0115     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00641    |
# |    std                  | 0.14        |
# |    value_loss           | 0.00194     |
# -----------------------------------------
# Eval num_timesteps=70400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=70400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 4            |
# |    mean_reward          | 0.607        |
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 22           |
# |    time_elapsed         | 884          |
# |    total_timesteps      | 70400        |
# | train/                  |              |
# |    approx_kl            | 0.0021852918 |
# |    clip_fraction        | 0.132        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.76         |
# |    explained_variance   | 0.942        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00849     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00603     |
# |    std                  | 0.139        |
# |    value_loss           | 0.00182      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 23           |
# |    time_elapsed         | 920          |
# |    total_timesteps      | 73600        |
# | train/                  |              |
# |    approx_kl            | 0.0037818952 |
# |    clip_fraction        | 0.154        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.8          |
# |    explained_variance   | 0.939        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00669     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0074      |
# |    std                  | 0.138        |
# |    value_loss           | 0.00187      |
# ------------------------------------------
# Eval num_timesteps=76800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=76800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 4            |
# |    mean_reward          | 0.607        |
# | time/                   |              |
# |    fps                  | 78           |
# |    iterations           | 24           |
# |    time_elapsed         | 976          |
# |    total_timesteps      | 76800        |
# | train/                  |              |
# |    approx_kl            | 0.0013828746 |
# |    clip_fraction        | 0.124        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.83         |
# |    explained_variance   | 0.942        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0121       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00542     |
# |    std                  | 0.137        |
# |    value_loss           | 0.00183      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 25          |
# |    time_elapsed         | 1022        |
# |    total_timesteps      | 80000       |
# | train/                  |             |
# |    approx_kl            | 0.004453504 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.85        |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0219     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00525    |
# |    std                  | 0.137       |
# |    value_loss           | 0.00186     |
# -----------------------------------------
# Eval num_timesteps=83200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=83200, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 4            |
# |    mean_reward          | 0.604        |
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 26           |
# |    time_elapsed         | 1068         |
# |    total_timesteps      | 83200        |
# | train/                  |              |
# |    approx_kl            | 0.0019852673 |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.89         |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0207       |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00458     |
# |    std                  | 0.136        |
# |    value_loss           | 0.00178      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 78           |
# |    iterations           | 27           |
# |    time_elapsed         | 1103         |
# |    total_timesteps      | 86400        |
# | train/                  |              |
# |    approx_kl            | 0.0024552515 |
# |    clip_fraction        | 0.118        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 2.92         |
# |    explained_variance   | 0.941        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0134       |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00488     |
# |    std                  | 0.135        |
# |    value_loss           | 0.00185      |
# ------------------------------------------
# Eval num_timesteps=89600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=89600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 4           |
# |    mean_reward          | 0.606       |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 28          |
# |    time_elapsed         | 1150        |
# |    total_timesteps      | 89600       |
# | train/                  |             |
# |    approx_kl            | 0.003492155 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 2.97        |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0221     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00604    |
# |    std                  | 0.133       |
# |    value_loss           | 0.00182     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 78           |
# |    iterations           | 29           |
# |    time_elapsed         | 1186         |
# |    total_timesteps      | 92800        |
# | train/                  |              |
# |    approx_kl            | 0.0031549064 |
# |    clip_fraction        | 0.149        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 3            |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0239       |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.0062      |
# |    std                  | 0.133        |
# |    value_loss           | 0.00173      |
# ------------------------------------------
# Eval num_timesteps=96000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=96000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 4           |
# |    mean_reward          | 0.606       |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 30          |
# |    time_elapsed         | 1233        |
# |    total_timesteps      | 96000       |
# | train/                  |             |
# |    approx_kl            | 0.006020175 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 3.02        |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0498     |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00738    |
# |    std                  | 0.132       |
# |    value_loss           | 0.00174     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 31          |
# |    time_elapsed         | 1279        |
# |    total_timesteps      | 99200       |
# | train/                  |             |
# |    approx_kl            | 0.002601148 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 3.04        |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0108      |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00635    |
# |    std                  | 0.132       |
# |    value_loss           | 0.00174     |
# -----------------------------------------
# Eval num_timesteps=102400, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=102400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 4           |
# |    mean_reward          | 0.607       |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 32          |
# |    time_elapsed         | 1333        |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.000739221 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 3.07        |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.00217    |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.00589    |
# |    std                  | 0.131       |
# |    value_loss           | 0.00169     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 33           |
# |    time_elapsed         | 1369         |
# |    total_timesteps      | 105600       |
# | train/                  |              |
# |    approx_kl            | 0.0028276856 |
# |    clip_fraction        | 0.131        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 3.09         |
# |    explained_variance   | 0.943        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.016       |
# |    n_updates            | 640          |
# |    policy_gradient_loss | -0.00517     |
# |    std                  | 0.13         |
# |    value_loss           | 0.00176      |
# ------------------------------------------
# Eval num_timesteps=108800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=108800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 4            |
# |    mean_reward          | 0.606        |
# | time/                   |              |
# |    fps                  | 76           |
# |    iterations           | 34           |
# |    time_elapsed         | 1416         |
# |    total_timesteps      | 108800       |
# | train/                  |              |
# |    approx_kl            | 0.0013822201 |
# |    clip_fraction        | 0.12         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 3.12         |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0175      |
# |    n_updates            | 660          |
# |    policy_gradient_loss | -0.00488     |
# |    std                  | 0.13         |
# |    value_loss           | 0.00174      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 35           |
# |    time_elapsed         | 1453         |
# |    total_timesteps      | 112000       |
# | train/                  |              |
# |    approx_kl            | 8.002609e-05 |
# |    clip_fraction        | 0.133        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 3.16         |
# |    explained_variance   | 0.943        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.000233     |
# |    n_updates            | 680          |
# |    policy_gradient_loss | -0.00534     |
# |    std                  | 0.129        |
# |    value_loss           | 0.00177      |
# ------------------------------------------
# Eval num_timesteps=115200, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=115200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 4            |
# |    mean_reward          | 0.607        |
# | time/                   |              |
# |    fps                  | 76           |
# |    iterations           | 36           |
# |    time_elapsed         | 1505         |
# |    total_timesteps      | 115200       |
# | train/                  |              |
# |    approx_kl            | 0.0025407376 |
# |    clip_fraction        | 0.122        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 3.2          |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.00648      |
# |    n_updates            | 700          |
# |    policy_gradient_loss | -0.00428     |
# |    std                  | 0.128        |
# |    value_loss           | 0.00166      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 76           |
# |    iterations           | 37           |
# |    time_elapsed         | 1540         |
# |    total_timesteps      | 118400       |
# | train/                  |              |
# |    approx_kl            | 0.0014615565 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 3.24         |
# |    explained_variance   | 0.948        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0123      |
# |    n_updates            | 720          |
# |    policy_gradient_loss | -0.00501     |
# |    std                  | 0.127        |
# |    value_loss           | 0.00165      |
# ------------------------------------------
# Eval num_timesteps=121600, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=121600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 4            |
# |    mean_reward          | 0.607        |
# | time/                   |              |
# |    fps                  | 76           |
# |    iterations           | 38           |
# |    time_elapsed         | 1586         |
# |    total_timesteps      | 121600       |
# | train/                  |              |
# |    approx_kl            | 0.0014356733 |
# |    clip_fraction        | 0.13         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 3.28         |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0103      |
# |    n_updates            | 740          |
# |    policy_gradient_loss | -0.00448     |
# |    std                  | 0.126        |
# |    value_loss           | 0.0017       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 39          |
# |    time_elapsed         | 1622        |
# |    total_timesteps      | 124800      |
# | train/                  |             |
# |    approx_kl            | 0.002261332 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 3.29        |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.00213    |
# |    n_updates            | 760         |
# |    policy_gradient_loss | -0.00451    |
# |    std                  | 0.126       |
# |    value_loss           | 0.00162     |
# -----------------------------------------
# Eval num_timesteps=128000, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=128000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 4            |
# |    mean_reward          | 0.609        |
# | time/                   |              |
# |    fps                  | 76           |
# |    iterations           | 40           |
# |    time_elapsed         | 1668         |
# |    total_timesteps      | 128000       |
# | train/                  |              |
# |    approx_kl            | 0.0047980365 |
# |    clip_fraction        | 0.159        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 3.31         |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0134      |
# |    n_updates            | 780          |
# |    policy_gradient_loss | -0.00699     |
# |    std                  | 0.125        |
# |    value_loss           | 0.00162      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 41          |
# |    time_elapsed         | 1701        |
# |    total_timesteps      | 131200      |
# | train/                  |             |
# |    approx_kl            | 0.001728284 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 3.32        |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.000833   |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.00418    |
# |    std                  | 0.125       |
# |    value_loss           | 0.00164     |
# -----------------------------------------
# Eval num_timesteps=134400, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=134400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 4            |
# |    mean_reward          | 0.608        |
# | time/                   |              |
# |    fps                  | 76           |
# |    iterations           | 42           |
# |    time_elapsed         | 1746         |
# |    total_timesteps      | 134400       |
# | train/                  |              |
# |    approx_kl            | 0.0029676212 |
# |    clip_fraction        | 0.145        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 3.37         |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0182      |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.00582     |
# |    std                  | 0.123        |
# |    value_loss           | 0.00159      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 43           |
# |    time_elapsed         | 1780         |
# |    total_timesteps      | 137600       |
# | train/                  |              |
# |    approx_kl            | 0.0027638408 |
# |    clip_fraction        | 0.113        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 3.4          |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0154       |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.00379     |
# |    std                  | 0.123        |
# |    value_loss           | 0.00165      |
# ------------------------------------------
# Eval num_timesteps=140800, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=140800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 4            |
# |    mean_reward          | 0.608        |
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 44           |
# |    time_elapsed         | 1825         |
# |    total_timesteps      | 140800       |
# | train/                  |              |
# |    approx_kl            | 0.0051040496 |
# |    clip_fraction        | 0.144        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 3.44         |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0348      |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.00493     |
# |    std                  | 0.122        |
# |    value_loss           | 0.00161      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 45           |
# |    time_elapsed         | 1860         |
# |    total_timesteps      | 144000       |
# | train/                  |              |
# |    approx_kl            | 0.0014716401 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 3.49         |
# |    explained_variance   | 0.953        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00252     |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.00465     |
# |    std                  | 0.12         |
# |    value_loss           | 0.00152      |
# ------------------------------------------
# Eval num_timesteps=147200, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=147200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# --------------------------------------------
# | eval/                   |                |
# |    mean_ep_length       | 4              |
# |    mean_reward          | 0.607          |
# | time/                   |                |
# |    fps                  | 77             |
# |    iterations           | 46             |
# |    time_elapsed         | 1906           |
# |    total_timesteps      | 147200         |
# | train/                  |                |
# |    approx_kl            | -0.00028292465 |
# |    clip_fraction        | 0.126          |
# |    clip_range           | 0.1            |
# |    entropy_loss         | 3.52           |
# |    explained_variance   | 0.95           |
# |    learning_rate        | 5e-05          |
# |    loss                 | -0.00272       |
# |    n_updates            | 900            |
# |    policy_gradient_loss | -0.00397       |
# |    std                  | 0.12           |
# |    value_loss           | 0.00164        |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 47           |
# |    time_elapsed         | 1941         |
# |    total_timesteps      | 150400       |
# | train/                  |              |
# |    approx_kl            | 0.0038312613 |
# |    clip_fraction        | 0.154        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 3.54         |
# |    explained_variance   | 0.953        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00825     |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.00518     |
# |    std                  | 0.12         |
# |    value_loss           | 0.00152      |
# ------------------------------------------
# Eval num_timesteps=153600, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=153600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 4           |
# |    mean_reward          | 0.608       |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 48          |
# |    time_elapsed         | 1994        |
# |    total_timesteps      | 153600      |
# | train/                  |             |
# |    approx_kl            | 0.003875647 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 3.57        |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0148      |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.00463    |
# |    std                  | 0.119       |
# |    value_loss           | 0.00155     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 49           |
# |    time_elapsed         | 2028         |
# |    total_timesteps      | 156800       |
# | train/                  |              |
# |    approx_kl            | 0.0013419427 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 3.62         |
# |    explained_variance   | 0.955        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0012       |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.00367     |
# |    std                  | 0.118        |
# |    value_loss           | 0.00148      |
# ------------------------------------------
# Eval num_timesteps=160000, episode_reward=0.62 +/- 0.00
# ...
# |    entropy_loss         | 4.42        |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0247      |
# |    n_updates            | 1540        |
# |    policy_gradient_loss | -0.00343    |
# |    std                  | 0.102       |
# |    value_loss           | 0.00114     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 79           |
# |    time_elapsed         | 3271         |
# |    total_timesteps      | 252800       |
# | train/                  |              |
# |    approx_kl            | 0.0020056618 |
# |    clip_fraction        | 0.148        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 4.45         |
# |    explained_variance   | 0.967        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.021       |
# |    n_updates            | 1560         |
# |    policy_gradient_loss | -0.00415     |
# |    std                  | 0.101        |
# |    value_loss           | 0.00113      |
# ------------------------------------------
# Eval num_timesteps=256000, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=256000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 4            |
# |    mean_reward          | 0.611        |
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 80           |
# |    time_elapsed         | 3319         |
# |    total_timesteps      | 256000       |
# | train/                  |              |
# |    approx_kl            | 0.0015902284 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 4.49         |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0156      |
# |    n_updates            | 1580         |
# |    policy_gradient_loss | -0.00333     |
# |    std                  | 0.1          |
# |    value_loss           | 0.00111      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 81          |
# |    time_elapsed         | 3353        |
# |    total_timesteps      | 259200      |
# | train/                  |             |
# |    approx_kl            | 0.002842535 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 4.52        |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.000144   |
# |    n_updates            | 1600        |
# |    policy_gradient_loss | -0.00351    |
# |    std                  | 0.0996      |
# |    value_loss           | 0.00115     |
# -----------------------------------------
# Eval num_timesteps=262400, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=262400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# --------------------------------------------
# | eval/                   |                |
# |    mean_ep_length       | 4              |
# |    mean_reward          | 0.612          |
# | time/                   |                |
# |    fps                  | 76             |
# |    iterations           | 82             |
# |    time_elapsed         | 3408           |
# |    total_timesteps      | 262400         |
# | train/                  |                |
# |    approx_kl            | -8.0754235e-06 |
# |    clip_fraction        | 0.12           |
# |    clip_range           | 0.1            |
# |    entropy_loss         | 4.56           |
# |    explained_variance   | 0.967          |
# |    learning_rate        | 5e-05          |
# |    loss                 | 0.0154         |
# |    n_updates            | 1620           |
# |    policy_gradient_loss | -0.00321       |
# |    std                  | 0.099          |
# |    value_loss           | 0.00116        |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 83           |
# |    time_elapsed         | 3446         |
# |    total_timesteps      | 265600       |
# | train/                  |              |
# |    approx_kl            | 0.0018143011 |
# |    clip_fraction        | 0.118        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 4.58         |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.00293      |
# |    n_updates            | 1640         |
# |    policy_gradient_loss | -0.0018      |
# |    std                  | 0.0986       |
# |    value_loss           | 0.0011       |
# ------------------------------------------
# Eval num_timesteps=268800, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=268800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 4          |
# |    mean_reward          | 0.612      |
# | time/                   |            |
# |    fps                  | 77         |
# |    iterations           | 84         |
# |    time_elapsed         | 3489       |
# |    total_timesteps      | 268800     |
# | train/                  |            |
# |    approx_kl            | 0.00298034 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | 4.59       |
# |    explained_variance   | 0.968      |
# |    learning_rate        | 5e-05      |
# |    loss                 | -0.0167    |
# |    n_updates            | 1660       |
# |    policy_gradient_loss | -0.0038    |
# |    std                  | 0.0985     |
# |    value_loss           | 0.00109    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 85          |
# |    time_elapsed         | 3521        |
# |    total_timesteps      | 272000      |
# | train/                  |             |
# |    approx_kl            | 0.000866977 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 4.61        |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0113     |
# |    n_updates            | 1680        |
# |    policy_gradient_loss | -0.00283    |
# |    std                  | 0.0982      |
# |    value_loss           | 0.00111     |
# -----------------------------------------
# Eval num_timesteps=275200, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=275200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 4           |
# |    mean_reward          | 0.611       |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 86          |
# |    time_elapsed         | 3566        |
# |    total_timesteps      | 275200      |
# | train/                  |             |
# |    approx_kl            | 0.002428892 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 4.63        |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.00332     |
# |    n_updates            | 1700        |
# |    policy_gradient_loss | -0.00235    |
# |    std                  | 0.0979      |
# |    value_loss           | 0.00107     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 87           |
# |    time_elapsed         | 3607         |
# |    total_timesteps      | 278400       |
# | train/                  |              |
# |    approx_kl            | 0.0026245052 |
# |    clip_fraction        | 0.144        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 4.65         |
# |    explained_variance   | 0.966        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00848     |
# |    n_updates            | 1720         |
# |    policy_gradient_loss | -0.00349     |
# |    std                  | 0.0975       |
# |    value_loss           | 0.00115      |
# ------------------------------------------
# Eval num_timesteps=281600, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=281600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 4           |
# |    mean_reward          | 0.611       |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 88          |
# |    time_elapsed         | 3650        |
# |    total_timesteps      | 281600      |
# | train/                  |             |
# |    approx_kl            | 0.002632559 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 4.67        |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0126      |
# |    n_updates            | 1740        |
# |    policy_gradient_loss | -0.00257    |
# |    std                  | 0.0972      |
# |    value_loss           | 0.00107     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 89           |
# |    time_elapsed         | 3684         |
# |    total_timesteps      | 284800       |
# | train/                  |              |
# |    approx_kl            | 0.0035888301 |
# |    clip_fraction        | 0.13         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 4.69         |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00574     |
# |    n_updates            | 1760         |
# |    policy_gradient_loss | -0.00267     |
# |    std                  | 0.0967       |
# |    value_loss           | 0.00111      |
# ------------------------------------------
# Eval num_timesteps=288000, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=288000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 4            |
# |    mean_reward          | 0.612        |
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 90           |
# |    time_elapsed         | 3729         |
# |    total_timesteps      | 288000       |
# | train/                  |              |
# |    approx_kl            | 0.0018158205 |
# |    clip_fraction        | 0.147        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 4.71         |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0091      |
# |    n_updates            | 1780         |
# |    policy_gradient_loss | -0.00435     |
# |    std                  | 0.0963       |
# |    value_loss           | 0.00105      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 91           |
# |    time_elapsed         | 3769         |
# |    total_timesteps      | 291200       |
# | train/                  |              |
# |    approx_kl            | 0.0017943489 |
# |    clip_fraction        | 0.132        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 4.73         |
# |    explained_variance   | 0.967        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0154      |
# |    n_updates            | 1800         |
# |    policy_gradient_loss | -0.00259     |
# |    std                  | 0.0962       |
# |    value_loss           | 0.00113      |
# ------------------------------------------
# Eval num_timesteps=294400, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=294400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# --------------------------------------------
# | eval/                   |                |
# |    mean_ep_length       | 4              |
# |    mean_reward          | 0.612          |
# | time/                   |                |
# |    fps                  | 77             |
# |    iterations           | 92             |
# |    time_elapsed         | 3813           |
# |    total_timesteps      | 294400         |
# | train/                  |                |
# |    approx_kl            | -0.00013155077 |
# |    clip_fraction        | 0.136          |
# |    clip_range           | 0.1            |
# |    entropy_loss         | 4.75           |
# |    explained_variance   | 0.97           |
# |    learning_rate        | 5e-05          |
# |    loss                 | 0.00848        |
# |    n_updates            | 1820           |
# |    policy_gradient_loss | -0.00302       |
# |    std                  | 0.0958         |
# |    value_loss           | 0.00105        |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 93           |
# |    time_elapsed         | 3846         |
# |    total_timesteps      | 297600       |
# | train/                  |              |
# |    approx_kl            | 0.0012378608 |
# |    clip_fraction        | 0.136        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 4.77         |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00783     |
# |    n_updates            | 1840         |
# |    policy_gradient_loss | -0.00304     |
# |    std                  | 0.0953       |
# |    value_loss           | 0.00105      |
# ------------------------------------------
# Eval num_timesteps=300800, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=300800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 4           |
# |    mean_reward          | 0.611       |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 94          |
# |    time_elapsed         | 3890        |
# |    total_timesteps      | 300800      |
# | train/                  |             |
# |    approx_kl            | 0.003236953 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 4.79        |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.00518    |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | -0.00229    |
# |    std                  | 0.0951      |
# |    value_loss           | 0.00108     |
# -----------------------------------------
# <img src="data:image/png;base64,..." width="599.4666666666667">
# <img src="data:image/png;base64,..." width="599.4666666666667">
