# %%
# to access functions from other locations
import sys
sys.path.append('/data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/')

# %%
# %matplotlib notebook
import numpy as np
import time
import pickle
import os
import matplotlib.pyplot as plt

import gym
import torch as th
from stable_baselines3.a2c import A2C, MlpPolicy
from stable_baselines3.common.vec_env import SubprocVecEnv, DummyVecEnv
from stable_baselines3.common.callbacks import CallbackList
from utils.custom_eval_callback import CustomEvalCallback
from typing import Callable
from utils.env_wrappers import StateCoarse

from utils.plot_functions import plot_learning

from model.ressim import Grid
from ressim_env import ResSimEnv_v0, ResSimEnv_v1, ResSimEnv_v2
from k_distributions.generate_constr_k import generate_cond_
from utils.env_wrappers import StepReset
# Out:
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
seed=1
case='1ph_v0_state_wells_sp_large_batch'

# %%
os.makedirs('./data', exist_ok=True)
os.makedirs('./data/'+case, exist_ok=True)

# %%
case_ = '1ph_v0'
with open('../envs_params/env_data_v1/env_'+case_+'_train_cluster.pkl', 'rb') as input:
    env_train = pickle.load(input)

rl_indices = [24,5,14,1,6,12,0,25,22]
with open('../envs_params/env_data_v1/env_'+case_+'_eval_cluster.pkl', 'rb') as input:
    env_eval = pickle.load(input)
k_list_rl = env_eval.k_list[rl_indices]
env_eval.set_k(k_list_rl)

# %%
# env wrapper to reduce state space
x_coords, y_coords = env_train.p_x, env_train.p_y

def env_wrappers(env, x_coords, y_coords):
    env = StateCoarse(env, x_coords, y_coords, include_well_pr=True)
    env = StepReset(env)
    return env

# %%
def make_env(env, rank: int, seed: int = 0) -> Callable:
    """
    Utility function for multiprocessed env.
    
    :param env_id: (str) the environment ID
    :param num_env: (int) the number of environment you wish to have in subprocesses
    :param seed: (int) the inital seed for RNG
    :param rank: (int) index of the subprocess
    :return: (Callable)
    """
    def _init() -> gym.Env:
        env_ = env
        env_.seed(seed + rank)
        return env_
    return _init

# %%
for seed in range(1,4):
    if True:
        print(f'seed {seed}')
        log_dir = './data/'+case+'/seed_'+str(seed)
        os.makedirs(log_dir, exist_ok=True)
        num_cpu = 32
        env_train.seed(seed)
        env_eval.seed(seed)
        env_train_ = env_wrappers(env_train, x_coords, y_coords)
        env_eval_ = env_wrappers(env_eval, x_coords, y_coords)
        train_callback = CustomEvalCallback(env_train_, 
                                            best_model_save_path=None, 
                                            n_eval_episodes=1,
                                            log_path=str(log_dir)+'/results_train', 
                                            eval_freq=100)
        callback_list = [train_callback]
        eval_callback = CustomEvalCallback(env_eval_, 
                                           best_model_save_path=str(log_dir)+'/best_model_eval', 
                                           n_eval_episodes=1,
                                           log_path=str(log_dir)+'/results_eval', 
                                           eval_freq=100)
        callback_list.append(eval_callback)
        callback = CallbackList(callback_list)
        env = SubprocVecEnv([make_env(env_train_, i, seed) for i in range(num_cpu)])
        print(env.observation_space)
#     env = VecMonitor(env, filename=log_dir)
        print(f'seed {seed}: model definition ..')
        model = A2C(policy=MlpPolicy,
                    env=env,
                    learning_rate = 1e-4,
                    n_steps = 50,
                    gamma = 0.99,
                    gae_lambda = 0.95,
                    ent_coef = 0.001,
                    vf_coef = 0.5,
                    max_grad_norm = 0.5,
                    use_sde= False,
                    create_eval_env= False,
                    policy_kwargs = dict(net_arch=[20,20], 
                                         log_std_init=-2.9),
                    verbose = 1,
                    seed = seed,
                    device = "auto")
#         model_params = model_pretrained.get_parameters()
#         model.set_parameters(model_params, exact_match=False)
        model.get_parameters()['policy']['mlp_extractor.shared_net.0.weight'][:,4:] = 0
        print(f'seed {seed}: learning ..')
        model.learn(total_timesteps=300000, callback=callback, log_interval=10)
        model.save(log_dir+'/A2C')
        fig = plot_learning(log_dir, case='train')
        fig.savefig(log_dir+'/learn_train.png')
        fig = plot_learning(log_dir, case='eval')
        fig.savefig(log_dir+'/learn_eval.png')
# Out:
# seed 1
# Box(-100000.0, 100000.0, (9,), float64)
# seed 1: model definition ..
# Using cuda device
# seed 1: learning ..
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:97: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f5fac7bd5f8> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5fac7bd588>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:97: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f5fac7bd5f8> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5fac7bd5c0>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# Eval num_timesteps=3200, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=3200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=6400, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=6400, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=9600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=9600, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=12800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=12800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=16000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=16000, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.623    |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 10       |
# |    time_elapsed       | 146      |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | -16      |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 9        |
# |    policy_loss        | -0.878   |
# |    std                | 0.0551   |
# |    value_loss         | 0.0633   |
# ------------------------------------
# Eval num_timesteps=19200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=19200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=22400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=22400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=25600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=25600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=28800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=28800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=32000, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=32000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.627    |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 20       |
# |    time_elapsed       | 292      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | -12.8    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 19       |
# |    policy_loss        | -0.678   |
# |    std                | 0.0551   |
# |    value_loss         | 0.0487   |
# ------------------------------------
# Eval num_timesteps=35200, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=35200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=38400, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=38400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=41600, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=41600, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=44800, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=44800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=48000, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=48000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.627    |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 30       |
# |    time_elapsed       | 439      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | -8.57    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 29       |
# |    policy_loss        | -0.586   |
# |    std                | 0.0551   |
# |    value_loss         | 0.0412   |
# ------------------------------------
# Eval num_timesteps=51200, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=51200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=54400, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=54400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=57600, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=57600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=60800, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=60800, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=64000, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=64000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.627    |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 40       |
# |    time_elapsed       | 585      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | -4.6     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 39       |
# |    policy_loss        | -0.491   |
# |    std                | 0.0551   |
# |    value_loss         | 0.0331   |
# ------------------------------------
# Eval num_timesteps=67200, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=67200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=70400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=70400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=73600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=73600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=76800, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=76800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=80000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=80000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.627    |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 50       |
# |    time_elapsed       | 732      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | -2.79    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 49       |
# |    policy_loss        | -0.423   |
# |    std                | 0.0551   |
# |    value_loss         | 0.0281   |
# ------------------------------------
# Eval num_timesteps=83200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=83200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=86400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=86400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=89600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=89600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=92800, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=92800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=96000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=96000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.627    |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 60       |
# |    time_elapsed       | 880      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | -2.06    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 59       |
# |    policy_loss        | -0.397   |
# |    std                | 0.055    |
# |    value_loss         | 0.0259   |
# ------------------------------------
# Eval num_timesteps=99200, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=99200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=102400, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=102400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=105600, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=105600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=108800, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=108800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=112000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=112000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.627    |
# | time/                 |          |
# |    fps                | 108      |
# |    iterations         | 70       |
# |    time_elapsed       | 1027     |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | -1.16    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 69       |
# |    policy_loss        | -0.296   |
# |    std                | 0.0551   |
# |    value_loss         | 0.0216   |
# ------------------------------------
# Eval num_timesteps=115200, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=115200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=118400, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=118400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=121600, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=121600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=124800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=124800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=128000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=128000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.631    |
# | time/                 |          |
# |    fps                | 108      |
# |    iterations         | 80       |
# |    time_elapsed       | 1174     |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | -0.74    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 79       |
# |    policy_loss        | -0.306   |
# |    std                | 0.0551   |
# |    value_loss         | 0.0204   |
# ------------------------------------
# Eval num_timesteps=131200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=131200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=134400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=134400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=137600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=137600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=140800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=140800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=144000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=144000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.631    |
# | time/                 |          |
# |    fps                | 108      |
# |    iterations         | 90       |
# |    time_elapsed       | 1321     |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | -0.421   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 89       |
# |    policy_loss        | -0.286   |
# |    std                | 0.0551   |
# |    value_loss         | 0.0187   |
# ------------------------------------
# Eval num_timesteps=147200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=147200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=150400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=150400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=153600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=153600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=156800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=156800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=160000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=160000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.63     |
# | time/                 |          |
# |    fps                | 108      |
# |    iterations         | 100      |
# |    time_elapsed       | 1468     |
# |    total_timesteps    | 160000   |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | -0.269   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.247   |
# |    std                | 0.0551   |
# |    value_loss         | 0.0173   |
# ------------------------------------
# Eval num_timesteps=163200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=163200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=166400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=166400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=169600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=169600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=172800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=172800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=176000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=176000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.631    |
# | time/                 |          |
# |    fps                | 108      |
# |    iterations         | 110      |
# |    time_elapsed       | 1614     |
# |    total_timesteps    | 176000   |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | -0.114   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 109      |
# |    policy_loss        | -0.22    |
# |    std                | 0.0551   |
# |    value_loss         | 0.0161   |
# ------------------------------------
# Eval num_timesteps=179200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=179200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=182400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=182400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=185600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=185600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=188800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=188800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=192000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=192000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.627    |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 120      |
# |    time_elapsed       | 1761     |
# |    total_timesteps    | 192000   |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | 0.0619   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 119      |
# |    policy_loss        | -0.183   |
# |    std                | 0.055    |
# |    value_loss         | 0.0143   |
# ------------------------------------
# Eval num_timesteps=195200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=195200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=198400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=198400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=201600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=201600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=204800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=204800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=208000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=208000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.631    |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 130      |
# |    time_elapsed       | 1907     |
# |    total_timesteps    | 208000   |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | 0.16     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 129      |
# |    policy_loss        | -0.19    |
# |    std                | 0.055    |
# |    value_loss         | 0.0137   |
# ------------------------------------
# Eval num_timesteps=211200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=211200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=214400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=214400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=217600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=217600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=220800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=220800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=224000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=224000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.632    |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 140      |
# |    time_elapsed       | 2053     |
# |    total_timesteps    | 224000   |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | 0.249    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 139      |
# |    policy_loss        | -0.151   |
# |    std                | 0.055    |
# |    value_loss         | 0.0127   |
# ------------------------------------
# Eval num_timesteps=227200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=227200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=230400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=230400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=233600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=233600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=236800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=236800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=240000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=240000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.632    |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 150      |
# |    time_elapsed       | 2199     |
# |    total_timesteps    | 240000   |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | 0.319    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 149      |
# |    policy_loss        | -0.163   |
# |    std                | 0.055    |
# |    value_loss         | 0.0123   |
# ------------------------------------
# Eval num_timesteps=243200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=243200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=246400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=246400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=249600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=249600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=252800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=252800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=265600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=265600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=268800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=268800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=272000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=272000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.632    |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 170      |
# |    time_elapsed       | 2490     |
# |    total_timesteps    | 272000   |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | 0.395    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 169      |
# |    policy_loss        | -0.125   |
# |    std                | 0.055    |
# |    value_loss         | 0.0112   |
# ------------------------------------
# Eval num_timesteps=275200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=275200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=278400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=278400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=281600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=281600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=284800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=284800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=288000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=288000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.63     |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 180      |
# |    time_elapsed       | 2635     |
# |    total_timesteps    | 288000   |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | 0.498    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 179      |
# |    policy_loss        | -0.12    |
# |    std                | 0.055    |
# |    value_loss         | 0.0105   |
# ------------------------------------
# Eval num_timesteps=291200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=291200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=294400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=294400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=297600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=297600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=300800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=300800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">
# seed 2
# Box(-100000.0, 100000.0, (9,), float64)
# seed 2: model definition ..
# Using cuda device
# seed 2: learning ..
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:97: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f5f6475f2b0> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5f6475ff60>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:97: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f5f6475f2b0> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f5f6475fb70>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# Eval num_timesteps=3200, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=3200, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=6400, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=6400, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=9600, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=9600, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=12800, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=12800, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=16000, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=16000, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.586    |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 10       |
# |    time_elapsed       | 146      |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | -3.75    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 9        |
# |    policy_loss        | -0.927   |
# |    std                | 0.055    |
# |    value_loss         | 0.0689   |
# ------------------------------------
# Eval num_timesteps=19200, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=19200, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=22400, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=22400, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=25600, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=25600, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=28800, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=28800, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=32000, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=32000, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.581    |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 20       |
# |    time_elapsed       | 292      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | -4.14    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 19       |
# |    policy_loss        | -0.736   |
# |    std                | 0.055    |
# |    value_loss         | 0.0562   |
# ------------------------------------
# Eval num_timesteps=35200, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=35200, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=38400, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=38400, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=41600, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=41600, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=44800, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=44800, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=48000, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=48000, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.57     |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 30       |
# |    time_elapsed       | 439      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | 5.93     |
# |    explained_variance | -4.41    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 29       |
# |    policy_loss        | -0.605   |
# |    std                | 0.055    |
# |    value_loss         | 0.0472   |
# ------------------------------------
# Eval num_timesteps=51200, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=51200, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=54400, episode_reward=0.56 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=54400, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=57600, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=57600, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=60800, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=60800, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=64000, episode_reward=0.56 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=64000, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.572    |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 40       |
# |    time_elapsed       | 585      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | 5.93     |
# |    explained_variance | -3.59    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 39       |
# |    policy_loss        | -0.489   |
# |    std                | 0.055    |
# |    value_loss         | 0.0415   |
# ------------------------------------
# Eval num_timesteps=67200, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=67200, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=70400, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=70400, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=73600, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=73600, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=76800, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=76800, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=80000, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=80000, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.584    |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 50       |
# |    time_elapsed       | 731      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | 5.93     |
# |    explained_variance | -2.87    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 49       |
# |    policy_loss        | -0.446   |
# |    std                | 0.055    |
# |    value_loss         | 0.0352   |
# ------------------------------------
# Eval num_timesteps=83200, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=83200, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=86400, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=86400, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=89600, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=89600, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=92800, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=92800, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=96000, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=96000, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.582    |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 60       |
# |    time_elapsed       | 878      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | 5.93     |
# |    explained_variance | -2.63    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 59       |
# |    policy_loss        | -0.366   |
# |    std                | 0.055    |
# |    value_loss         | 0.0313   |
# ------------------------------------
# Eval num_timesteps=99200, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=99200, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=102400, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=102400, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=105600, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=105600, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=108800, episode_reward=0.57 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=108800, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=112000, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=112000, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.586    |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 70       |
# |    time_elapsed       | 1024     |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | 5.93     |
# |    explained_variance | -1.82    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 69       |
# |    policy_loss        | -0.338   |
# |    std                | 0.055    |
# |    value_loss         | 0.0277   |
# ------------------------------------
# Eval num_timesteps=115200, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=115200, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=118400, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=118400, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=121600, episode_reward=0.58 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=121600, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=124800, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=124800, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=128000, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=128000, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.598    |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 80       |
# |    time_elapsed       | 1171     |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | 5.93     |
# |    explained_variance | -1.27    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 79       |
# |    policy_loss        | -0.311   |
# |    std                | 0.055    |
# |    value_loss         | 0.0244   |
# ------------------------------------
# Eval num_timesteps=131200, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=131200, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=134400, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=134400, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=137600, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=137600, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=140800, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=140800, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=144000, episode_reward=0.59 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=144000, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.6      |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 90       |
# |    time_elapsed       | 1317     |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | 5.93     |
# |    explained_variance | -1.09    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 89       |
# |    policy_loss        | -0.262   |
# |    std                | 0.055    |
# |    value_loss         | 0.0232   |
# ------------------------------------
# Eval num_timesteps=147200, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=147200, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=150400, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=150400, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=153600, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=153600, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=156800, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=156800, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=160000, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=160000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.608    |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 100      |
# |    time_elapsed       | 1462     |
# |    total_timesteps    | 160000   |
# | train/                |          |
# |    entropy_loss       | 5.93     |
# |    explained_variance | -0.74    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.266   |
# |    std                | 0.055    |
# |    value_loss         | 0.0212   |
# ------------------------------------
# Eval num_timesteps=163200, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=163200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=166400, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=166400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=169600, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=169600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=172800, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=172800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=176000, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=176000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.608    |
# | time/                 |          |
# |    fps                | 109      |
# |    iterations         | 110      |
# |    time_elapsed       | 1607     |
# |    total_timesteps    | 176000   |
# | train/                |          |
# |    entropy_loss       | 5.93     |
# |    explained_variance | -0.455   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 109      |
# |    policy_loss        | -0.227   |
# |    std                | 0.055    |
# |    value_loss         | 0.0191   |
# ------------------------------------
# Eval num_timesteps=179200, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=179200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=182400, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=182400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=185600, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=185600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=188800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=188800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=192000, episode_reward=0.60 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=192000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.614    |
# | time/                 |          |
# ...
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=137600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=140800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=140800, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=144000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=144000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.627    |
# | time/                 |          |
# |    fps                | 111      |
# |    iterations         | 90       |
# |    time_elapsed       | 1286     |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | -0.398   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 89       |
# |    policy_loss        | -0.293   |
# |    std                | 0.055    |
# |    value_loss         | 0.018    |
# ------------------------------------
# Eval num_timesteps=147200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=147200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=150400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=150400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=153600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=153600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=156800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=156800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=160000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=160000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.627    |
# | time/                 |          |
# |    fps                | 111      |
# |    iterations         | 100      |
# |    time_elapsed       | 1429     |
# |    total_timesteps    | 160000   |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | -0.204   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.25    |
# |    std                | 0.055    |
# |    value_loss         | 0.0168   |
# ------------------------------------
# Eval num_timesteps=163200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=163200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=166400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=166400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=169600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=169600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=172800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=172800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=176000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=176000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.631    |
# | time/                 |          |
# |    fps                | 111      |
# |    iterations         | 110      |
# |    time_elapsed       | 1571     |
# |    total_timesteps    | 176000   |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | 0.0171   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 109      |
# |    policy_loss        | -0.226   |
# |    std                | 0.055    |
# |    value_loss         | 0.0152   |
# ------------------------------------
# Eval num_timesteps=179200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=179200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=182400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=182400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=185600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=185600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=188800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=188800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=192000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=192000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.629    |
# | time/                 |          |
# |    fps                | 111      |
# |    iterations         | 120      |
# |    time_elapsed       | 1714     |
# |    total_timesteps    | 192000   |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | 0.171    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 119      |
# |    policy_loss        | -0.197   |
# |    std                | 0.055    |
# |    value_loss         | 0.0139   |
# ------------------------------------
# Eval num_timesteps=195200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=195200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=198400, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=198400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=201600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=201600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=204800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=204800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=208000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=208000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.628    |
# | time/                 |          |
# |    fps                | 112      |
# |    iterations         | 130      |
# |    time_elapsed       | 1856     |
# |    total_timesteps    | 208000   |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | 0.284    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 129      |
# |    policy_loss        | -0.198   |
# |    std                | 0.055    |
# |    value_loss         | 0.0131   |
# ------------------------------------
# Eval num_timesteps=211200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=211200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=214400, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=214400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=217600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=217600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=220800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=220800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=224000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=224000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.63     |
# | time/                 |          |
# |    fps                | 112      |
# |    iterations         | 140      |
# |    time_elapsed       | 1997     |
# |    total_timesteps    | 224000   |
# | train/                |          |
# |    entropy_loss       | 5.92     |
# |    explained_variance | 0.348    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 139      |
# |    policy_loss        | -0.191   |
# |    std                | 0.055    |
# |    value_loss         | 0.0125   |
# ------------------------------------
# Eval num_timesteps=227200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=227200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=230400, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=230400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=233600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=233600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=236800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=236800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=240000, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=240000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.627    |
# | time/                 |          |
# |    fps                | 112      |
# |    iterations         | 150      |
# |    time_elapsed       | 2139     |
# |    total_timesteps    | 240000   |
# | train/                |          |
# |    entropy_loss       | 5.93     |
# |    explained_variance | 0.356    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 149      |
# |    policy_loss        | -0.156   |
# |    std                | 0.055    |
# |    value_loss         | 0.0122   |
# ------------------------------------
# Eval num_timesteps=243200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=243200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=246400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=246400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=249600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=249600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=252800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=252800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=256000, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=256000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.627    |
# | time/                 |          |
# |    fps                | 112      |
# |    iterations         | 160      |
# |    time_elapsed       | 2281     |
# |    total_timesteps    | 256000   |
# | train/                |          |
# |    entropy_loss       | 5.93     |
# |    explained_variance | 0.43     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 159      |
# |    policy_loss        | -0.158   |
# |    std                | 0.055    |
# |    value_loss         | 0.0112   |
# ------------------------------------
# Eval num_timesteps=259200, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=259200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=262400, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=262400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=265600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=265600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=268800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=268800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=272000, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=272000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.63     |
# | time/                 |          |
# |    fps                | 112      |
# |    iterations         | 170      |
# |    time_elapsed       | 2423     |
# |    total_timesteps    | 272000   |
# | train/                |          |
# |    entropy_loss       | 5.93     |
# |    explained_variance | 0.469    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 169      |
# |    policy_loss        | -0.138   |
# |    std                | 0.055    |
# |    value_loss         | 0.0105   |
# ------------------------------------
# Eval num_timesteps=275200, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=275200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=278400, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=278400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=281600, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=281600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=284800, episode_reward=0.61 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=284800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=288000, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=288000, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 4        |
# |    mean_reward        | 0.63     |
# | time/                 |          |
# |    fps                | 112      |
# |    iterations         | 180      |
# |    time_elapsed       | 2564     |
# |    total_timesteps    | 288000   |
# | train/                |          |
# |    entropy_loss       | 5.93     |
# |    explained_variance | 0.529    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 179      |
# |    policy_loss        | -0.102   |
# |    std                | 0.055    |
# |    value_loss         | 0.00982  |
# ------------------------------------
# Eval num_timesteps=291200, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=291200, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=294400, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=294400, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=297600, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=297600, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# Eval num_timesteps=300800, episode_reward=0.62 +/- 0.00
# Episode length: 4.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=300800, episode_reward=0.63 +/- 0.00
# Episode length: 4.00 +/- 0.00
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">
