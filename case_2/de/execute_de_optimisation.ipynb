# %%
# to access functions from root directory 
import sys
sys.path.append('/data/ad181/RemoteDir/rl_robust_owc')

# %%
# %matplotlib notebook
from utils.plot_functions import plot_s_animation, plot_s_snapshots

import numpy as np
import time
import pickle
import os
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.optimize import differential_evolution

from utils.env_evaluate_functions import eval_actions
# Out:
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
seed=1
case = 'case_2'
opt_dir = './'+case
os.makedirs(opt_dir, exist_ok=True)

# %%
with open('../envs_params/env_data/env_list_eval.pkl', 'rb') as input:
    envs = pickle.load(input)
rl_indices = list(range(16))

# %%
def objective_function(q_arg, *args ):
    env = args[0]
    assert q_arg.size == env.terminal_step*env.action_space.shape[0], 'invalid argument size'
    q_arg = q_arg.reshape(env.terminal_step, -1)
    _,_, rewards = eval_actions(env, q_arg)
    return -sum(rewards)

# %%
for i,env in enumerate(envs):
    if i in rl_indices:
        args = (env,)
        base_action = np.ones((env.terminal_step,env.action_space.shape[0]))
        _,_, rewards = eval_actions(env, base_action)
        print(f'case: {i} (base reward: {-round(sum(rewards), 2)})')
        bounds =  [(env.action_space.low[0],env.action_space.high[0])]*(env.terminal_step*env.action_space.shape[0])
        result = differential_evolution(objective_function, bounds, args=args,
                                    maxiter=750, popsize=1, tol=1e-5,
                                    disp=True, polish=False,
                                    recombination=0.9, mutation=(0.5,1),
                                    updating='deferred', workers=64, seed=seed)
        np.save(opt_dir+'/ck_argmax_'+str(i)+'.npy', result.x)
        np.save(opt_dir+'/ck_max_'+str(i)+'.npy', result.fun)
        print(result.fun, result.x)
# Out:
# case: 0 (base reward: -0.58)
# differential_evolution step 1: f(x)= -0.601596
# differential_evolution step 2: f(x)= -0.601596
# differential_evolution step 3: f(x)= -0.610637
# differential_evolution step 4: f(x)= -0.610737
# differential_evolution step 5: f(x)= -0.617322
# differential_evolution step 6: f(x)= -0.61861
# differential_evolution step 7: f(x)= -0.621134
# differential_evolution step 8: f(x)= -0.621134
# differential_evolution step 9: f(x)= -0.624959
# differential_evolution step 10: f(x)= -0.624959
# differential_evolution step 11: f(x)= -0.624959
# differential_evolution step 12: f(x)= -0.624959
# differential_evolution step 13: f(x)= -0.624959
# differential_evolution step 14: f(x)= -0.624959
# differential_evolution step 15: f(x)= -0.624959
# differential_evolution step 16: f(x)= -0.624959
# differential_evolution step 17: f(x)= -0.6259
# differential_evolution step 18: f(x)= -0.6259
# differential_evolution step 19: f(x)= -0.625926
# differential_evolution step 20: f(x)= -0.626612
# differential_evolution step 21: f(x)= -0.626612
# differential_evolution step 22: f(x)= -0.626825
# differential_evolution step 23: f(x)= -0.626825
# differential_evolution step 24: f(x)= -0.626825
# differential_evolution step 25: f(x)= -0.626825
# differential_evolution step 26: f(x)= -0.626845
# differential_evolution step 27: f(x)= -0.627265
# differential_evolution step 28: f(x)= -0.627734
# differential_evolution step 29: f(x)= -0.627734
# differential_evolution step 30: f(x)= -0.62798
# differential_evolution step 31: f(x)= -0.628657
# differential_evolution step 32: f(x)= -0.628958
# differential_evolution step 33: f(x)= -0.629182
# differential_evolution step 34: f(x)= -0.629182
# differential_evolution step 35: f(x)= -0.629608
# differential_evolution step 36: f(x)= -0.629608
# differential_evolution step 37: f(x)= -0.629643
# differential_evolution step 38: f(x)= -0.630111
# differential_evolution step 39: f(x)= -0.630111
# differential_evolution step 40: f(x)= -0.630111
# differential_evolution step 41: f(x)= -0.630111
# differential_evolution step 42: f(x)= -0.630111
# differential_evolution step 43: f(x)= -0.630138
# differential_evolution step 44: f(x)= -0.630313
# differential_evolution step 45: f(x)= -0.630316
# differential_evolution step 46: f(x)= -0.630462
# differential_evolution step 47: f(x)= -0.630462
# differential_evolution step 48: f(x)= -0.630831
# differential_evolution step 49: f(x)= -0.630831
# differential_evolution step 50: f(x)= -0.630831
# differential_evolution step 51: f(x)= -0.630831
# differential_evolution step 52: f(x)= -0.630831
# differential_evolution step 53: f(x)= -0.630896
# differential_evolution step 54: f(x)= -0.630929
# differential_evolution step 55: f(x)= -0.630929
# differential_evolution step 56: f(x)= -0.630929
# differential_evolution step 57: f(x)= -0.630929
# differential_evolution step 58: f(x)= -0.630992
# differential_evolution step 59: f(x)= -0.630995
# differential_evolution step 60: f(x)= -0.630995
# differential_evolution step 61: f(x)= -0.630995
# differential_evolution step 62: f(x)= -0.630995
# differential_evolution step 63: f(x)= -0.631021
# differential_evolution step 64: f(x)= -0.631026
# differential_evolution step 65: f(x)= -0.631071
# differential_evolution step 66: f(x)= -0.631071
# differential_evolution step 67: f(x)= -0.631083
# differential_evolution step 68: f(x)= -0.631083
# differential_evolution step 69: f(x)= -0.631083
# differential_evolution step 70: f(x)= -0.631113
# differential_evolution step 71: f(x)= -0.631119
# differential_evolution step 72: f(x)= -0.631136
# differential_evolution step 73: f(x)= -0.631163
# differential_evolution step 74: f(x)= -0.631188
# differential_evolution step 75: f(x)= -0.631233
# differential_evolution step 76: f(x)= -0.631233
# differential_evolution step 77: f(x)= -0.631233
# differential_evolution step 78: f(x)= -0.631233
# differential_evolution step 79: f(x)= -0.631254
# differential_evolution step 80: f(x)= -0.631254
# differential_evolution step 81: f(x)= -0.631295
# differential_evolution step 82: f(x)= -0.631295
# differential_evolution step 83: f(x)= -0.631295
# differential_evolution step 84: f(x)= -0.631295
# differential_evolution step 85: f(x)= -0.631319
# differential_evolution step 86: f(x)= -0.63134
# differential_evolution step 87: f(x)= -0.63134
# differential_evolution step 88: f(x)= -0.63134
# differential_evolution step 89: f(x)= -0.631356
# differential_evolution step 90: f(x)= -0.631365
# differential_evolution step 91: f(x)= -0.631395
# differential_evolution step 92: f(x)= -0.631403
# differential_evolution step 93: f(x)= -0.631414
# differential_evolution step 94: f(x)= -0.63142
# differential_evolution step 95: f(x)= -0.631423
# differential_evolution step 96: f(x)= -0.631423
# differential_evolution step 97: f(x)= -0.631427
# differential_evolution step 98: f(x)= -0.631427
# differential_evolution step 99: f(x)= -0.631429
# differential_evolution step 100: f(x)= -0.631431
# differential_evolution step 101: f(x)= -0.631431
# differential_evolution step 102: f(x)= -0.631434
# differential_evolution step 103: f(x)= -0.631435
# differential_evolution step 104: f(x)= -0.63144
# -0.6314399445463859 [0.50559106 0.44306157 0.61302288 0.36213888 0.00292388 0.52047223
#  0.12108752 0.98424864 0.2348701  0.00143196 0.85477562 0.15377535
#  0.9484068  0.39940555 0.13045088 0.1644607  0.08445508 0.84747892
#  0.31890326 0.24451483 0.43941461 0.11488632 0.542278   0.23889921
#  0.24704251]
# case: 1 (base reward: -0.61)
# differential_evolution step 1: f(x)= -0.627467
# differential_evolution step 2: f(x)= -0.627467
# differential_evolution step 3: f(x)= -0.628071
# differential_evolution step 4: f(x)= -0.630113
# differential_evolution step 5: f(x)= -0.631047
# differential_evolution step 6: f(x)= -0.631425
# differential_evolution step 7: f(x)= -0.631425
# differential_evolution step 8: f(x)= -0.631425
# differential_evolution step 9: f(x)= -0.633147
# differential_evolution step 10: f(x)= -0.633482
# differential_evolution step 11: f(x)= -0.633824
# differential_evolution step 12: f(x)= -0.633984
# differential_evolution step 13: f(x)= -0.633984
# differential_evolution step 14: f(x)= -0.634102
# differential_evolution step 15: f(x)= -0.634146
# differential_evolution step 16: f(x)= -0.63435
# differential_evolution step 17: f(x)= -0.63435
# differential_evolution step 18: f(x)= -0.634484
# differential_evolution step 19: f(x)= -0.634484
# differential_evolution step 20: f(x)= -0.634558
# differential_evolution step 21: f(x)= -0.634558
# differential_evolution step 22: f(x)= -0.634582
# differential_evolution step 23: f(x)= -0.634966
# differential_evolution step 24: f(x)= -0.635185
# differential_evolution step 25: f(x)= -0.635303
# differential_evolution step 26: f(x)= -0.635303
# differential_evolution step 27: f(x)= -0.635303
# differential_evolution step 28: f(x)= -0.635303
# differential_evolution step 29: f(x)= -0.635303
# differential_evolution step 30: f(x)= -0.635303
# differential_evolution step 31: f(x)= -0.635303
# differential_evolution step 32: f(x)= -0.635373
# differential_evolution step 33: f(x)= -0.635373
# differential_evolution step 34: f(x)= -0.635373
# differential_evolution step 35: f(x)= -0.635373
# differential_evolution step 36: f(x)= -0.63542
# differential_evolution step 37: f(x)= -0.63542
# differential_evolution step 38: f(x)= -0.63542
# differential_evolution step 39: f(x)= -0.63542
# differential_evolution step 40: f(x)= -0.63542
# differential_evolution step 41: f(x)= -0.63542
# differential_evolution step 42: f(x)= -0.63542
# differential_evolution step 43: f(x)= -0.635431
# differential_evolution step 44: f(x)= -0.635493
# differential_evolution step 45: f(x)= -0.635555
# differential_evolution step 46: f(x)= -0.635637
# differential_evolution step 47: f(x)= -0.635689
# differential_evolution step 48: f(x)= -0.635727
# differential_evolution step 49: f(x)= -0.635798
# differential_evolution step 50: f(x)= -0.635798
# differential_evolution step 51: f(x)= -0.635884
# differential_evolution step 52: f(x)= -0.635884
# differential_evolution step 53: f(x)= -0.635884
# differential_evolution step 54: f(x)= -0.635884
# differential_evolution step 55: f(x)= -0.635884
# differential_evolution step 56: f(x)= -0.635911
# differential_evolution step 57: f(x)= -0.635911
# differential_evolution step 58: f(x)= -0.635911
# differential_evolution step 59: f(x)= -0.635911
# differential_evolution step 60: f(x)= -0.635911
# differential_evolution step 61: f(x)= -0.63592
# differential_evolution step 62: f(x)= -0.635941
# differential_evolution step 63: f(x)= -0.635979
# differential_evolution step 64: f(x)= -0.635981
# differential_evolution step 65: f(x)= -0.636016
# differential_evolution step 66: f(x)= -0.636021
# differential_evolution step 67: f(x)= -0.636036
# differential_evolution step 68: f(x)= -0.636047
# differential_evolution step 69: f(x)= -0.636047
# differential_evolution step 70: f(x)= -0.636053
# differential_evolution step 71: f(x)= -0.636092
# differential_evolution step 72: f(x)= -0.636108
# differential_evolution step 73: f(x)= -0.636108
# differential_evolution step 74: f(x)= -0.636142
# differential_evolution step 75: f(x)= -0.636142
# differential_evolution step 76: f(x)= -0.636161
# differential_evolution step 77: f(x)= -0.636161
# differential_evolution step 78: f(x)= -0.636163
# differential_evolution step 79: f(x)= -0.636184
# differential_evolution step 80: f(x)= -0.636186
# differential_evolution step 81: f(x)= -0.636192
# differential_evolution step 82: f(x)= -0.636215
# differential_evolution step 83: f(x)= -0.636267
# differential_evolution step 84: f(x)= -0.636267
# differential_evolution step 85: f(x)= -0.6363
# differential_evolution step 86: f(x)= -0.636303
# differential_evolution step 87: f(x)= -0.636303
# differential_evolution step 88: f(x)= -0.636318
# differential_evolution step 89: f(x)= -0.636318
# differential_evolution step 90: f(x)= -0.636318
# differential_evolution step 91: f(x)= -0.636322
# differential_evolution step 92: f(x)= -0.63633
# differential_evolution step 93: f(x)= -0.636333
# differential_evolution step 94: f(x)= -0.636336
# -0.6363358092834457 [0.73202391 0.48942616 0.34689748 0.23288189 0.00250282 0.04518974
#  0.27040826 0.83304535 0.49028058 0.00451657 0.29553805 0.2240725
#  0.50023477 0.72795841 0.72298706 0.42464931 0.03978736 0.30578967
#  0.59829667 0.64787748 0.63359687 0.03442411 0.31665019 0.44019589
#  0.28218922]
# case: 2 (base reward: -0.62)
# differential_evolution step 1: f(x)= -0.621959
# differential_evolution step 2: f(x)= -0.625103
# differential_evolution step 3: f(x)= -0.625103
# differential_evolution step 4: f(x)= -0.625103
# differential_evolution step 5: f(x)= -0.625103
# differential_evolution step 6: f(x)= -0.625705
# differential_evolution step 7: f(x)= -0.627019
# differential_evolution step 8: f(x)= -0.627019
# differential_evolution step 9: f(x)= -0.627019
# differential_evolution step 10: f(x)= -0.627019
# differential_evolution step 11: f(x)= -0.627019
# differential_evolution step 12: f(x)= -0.627763
# differential_evolution step 13: f(x)= -0.628265
# differential_evolution step 14: f(x)= -0.628265
# differential_evolution step 15: f(x)= -0.629506
# differential_evolution step 16: f(x)= -0.629525
# differential_evolution step 17: f(x)= -0.629969
# differential_evolution step 18: f(x)= -0.63028
# differential_evolution step 19: f(x)= -0.630369
# differential_evolution step 20: f(x)= -0.630403
# differential_evolution step 21: f(x)= -0.630509
# differential_evolution step 22: f(x)= -0.630509
# differential_evolution step 23: f(x)= -0.630509
# differential_evolution step 24: f(x)= -0.630689
# differential_evolution step 25: f(x)= -0.630689
# differential_evolution step 26: f(x)= -0.630689
# differential_evolution step 27: f(x)= -0.630806
# differential_evolution step 28: f(x)= -0.630962
# differential_evolution step 29: f(x)= -0.630962
# differential_evolution step 30: f(x)= -0.631101
# differential_evolution step 31: f(x)= -0.631237
# differential_evolution step 32: f(x)= -0.631285
# differential_evolution step 33: f(x)= -0.631434
# differential_evolution step 34: f(x)= -0.631473
# differential_evolution step 35: f(x)= -0.631473
# differential_evolution step 36: f(x)= -0.631473
# differential_evolution step 37: f(x)= -0.631486
# differential_evolution step 38: f(x)= -0.631493
# differential_evolution step 39: f(x)= -0.631595
# differential_evolution step 40: f(x)= -0.631595
# differential_evolution step 41: f(x)= -0.631595
# differential_evolution step 42: f(x)= -0.631595
# differential_evolution step 43: f(x)= -0.631595
# differential_evolution step 44: f(x)= -0.631655
# differential_evolution step 45: f(x)= -0.631788
# differential_evolution step 46: f(x)= -0.631818
# differential_evolution step 47: f(x)= -0.631818
# differential_evolution step 48: f(x)= -0.631825
# differential_evolution step 49: f(x)= -0.631825
# differential_evolution step 50: f(x)= -0.631825
# differential_evolution step 51: f(x)= -0.631825
# differential_evolution step 52: f(x)= -0.63189
# differential_evolution step 53: f(x)= -0.63189
# differential_evolution step 54: f(x)= -0.631931
# differential_evolution step 55: f(x)= -0.631938
# differential_evolution step 56: f(x)= -0.631958
# differential_evolution step 57: f(x)= -0.631958
# differential_evolution step 58: f(x)= -0.631971
# differential_evolution step 59: f(x)= -0.631971
# differential_evolution step 60: f(x)= -0.631971
# differential_evolution step 61: f(x)= -0.631976
# differential_evolution step 62: f(x)= -0.632013
# differential_evolution step 63: f(x)= -0.632015
# differential_evolution step 64: f(x)= -0.632027
# differential_evolution step 65: f(x)= -0.632027
# differential_evolution step 66: f(x)= -0.632048
# differential_evolution step 67: f(x)= -0.632053
# differential_evolution step 68: f(x)= -0.632053
# differential_evolution step 69: f(x)= -0.632053
# differential_evolution step 70: f(x)= -0.632082
# differential_evolution step 71: f(x)= -0.632082
# differential_evolution step 72: f(x)= -0.632083
# differential_evolution step 73: f(x)= -0.632103
# differential_evolution step 74: f(x)= -0.632107
# differential_evolution step 75: f(x)= -0.632122
# differential_evolution step 76: f(x)= -0.632152
# differential_evolution step 77: f(x)= -0.632152
# differential_evolution step 78: f(x)= -0.632161
# differential_evolution step 79: f(x)= -0.632161
# differential_evolution step 80: f(x)= -0.632179
# differential_evolution step 81: f(x)= -0.632186
# differential_evolution step 82: f(x)= -0.632189
# differential_evolution step 83: f(x)= -0.632189
# differential_evolution step 84: f(x)= -0.632189
# differential_evolution step 85: f(x)= -0.632189
# differential_evolution step 86: f(x)= -0.632191
# differential_evolution step 87: f(x)= -0.632195
# differential_evolution step 88: f(x)= -0.632195
# differential_evolution step 89: f(x)= -0.632195
# differential_evolution step 90: f(x)= -0.632195
# differential_evolution step 91: f(x)= -0.632197
# differential_evolution step 92: f(x)= -0.632201
# differential_evolution step 93: f(x)= -0.632205
# differential_evolution step 94: f(x)= -0.632211
# differential_evolution step 95: f(x)= -0.632211
# -0.6322112970321868 [0.42124015 0.26273148 0.50920079 0.29504421 0.60202144 0.34365962
#  0.0019506  0.34495381 0.65502988 0.66132924 0.62932798 0.00259583
#  0.66198343 0.85253485 0.58597043 0.4741508  0.91243201 0.25832066
#  0.06802689 0.11310215 0.77699924 0.82724252 0.16513126 0.06164743
#  0.03507828]
# case: 3 (base reward: -0.56)
# differential_evolution step 1: f(x)= -0.586033
# differential_evolution step 2: f(x)= -0.586033
# differential_evolution step 3: f(x)= -0.58714
# differential_evolution step 4: f(x)= -0.589594
# differential_evolution step 5: f(x)= -0.589594
# differential_evolution step 6: f(x)= -0.589594
# differential_evolution step 7: f(x)= -0.589594
# differential_evolution step 8: f(x)= -0.589594
# differential_evolution step 9: f(x)= -0.589594
# differential_evolution step 10: f(x)= -0.589594
# differential_evolution step 11: f(x)= -0.590407
# differential_evolution step 12: f(x)= -0.590918
# differential_evolution step 13: f(x)= -0.590918
# differential_evolution step 14: f(x)= -0.590918
# differential_evolution step 15: f(x)= -0.591233
# differential_evolution step 16: f(x)= -0.591233
# differential_evolution step 17: f(x)= -0.591233
# differential_evolution step 18: f(x)= -0.591233
# differential_evolution step 19: f(x)= -0.591233
# differential_evolution step 20: f(x)= -0.591233
# differential_evolution step 21: f(x)= -0.591233
# differential_evolution step 22: f(x)= -0.591359
# differential_evolution step 23: f(x)= -0.591745
# differential_evolution step 24: f(x)= -0.591816
# differential_evolution step 25: f(x)= -0.592231
# differential_evolution step 26: f(x)= -0.592352
# differential_evolution step 27: f(x)= -0.592352
# differential_evolution step 28: f(x)= -0.592352
# differential_evolution step 29: f(x)= -0.592352
# differential_evolution step 30: f(x)= -0.592352
# differential_evolution step 31: f(x)= -0.592352
# differential_evolution step 32: f(x)= -0.592603
# differential_evolution step 33: f(x)= -0.59267
# differential_evolution step 34: f(x)= -0.592832
# differential_evolution step 35: f(x)= -0.592854
# differential_evolution step 36: f(x)= -0.592854
# differential_evolution step 37: f(x)= -0.592854
# differential_evolution step 38: f(x)= -0.593245
# differential_evolution step 39: f(x)= -0.593425
# differential_evolution step 40: f(x)= -0.593425
# differential_evolution step 41: f(x)= -0.593984
# differential_evolution step 42: f(x)= -0.593984
# differential_evolution step 43: f(x)= -0.593984
# differential_evolution step 44: f(x)= -0.593984
# differential_evolution step 45: f(x)= -0.593984
# differential_evolution step 46: f(x)= -0.593984
# differential_evolution step 47: f(x)= -0.593984
# differential_evolution step 48: f(x)= -0.594369
# differential_evolution step 49: f(x)= -0.594369
# differential_evolution step 50: f(x)= -0.594369
# differential_evolution step 51: f(x)= -0.594676
# differential_evolution step 52: f(x)= -0.594676
# differential_evolution step 53: f(x)= -0.594676
# differential_evolution step 54: f(x)= -0.594696
# differential_evolution step 55: f(x)= -0.594696
# differential_evolution step 56: f(x)= -0.594696
# differential_evolution step 57: f(x)= -0.594708
# differential_evolution step 58: f(x)= -0.594796
# differential_evolution step 59: f(x)= -0.594796
# differential_evolution step 60: f(x)= -0.594796
# differential_evolution step 61: f(x)= -0.594796
# differential_evolution step 62: f(x)= -0.594831
# differential_evolution step 63: f(x)= -0.594991
# differential_evolution step 64: f(x)= -0.595042
# differential_evolution step 65: f(x)= -0.595055
# differential_evolution step 66: f(x)= -0.595055
# differential_evolution step 67: f(x)= -0.595077
# differential_evolution step 68: f(x)= -0.595077
# differential_evolution step 69: f(x)= -0.595077
# differential_evolution step 70: f(x)= -0.595092
# differential_evolution step 71: f(x)= -0.5951
# differential_evolution step 72: f(x)= -0.59513
# differential_evolution step 73: f(x)= -0.59513
# differential_evolution step 74: f(x)= -0.59513
# differential_evolution step 75: f(x)= -0.59513
# differential_evolution step 76: f(x)= -0.595153
# differential_evolution step 77: f(x)= -0.595153
# differential_evolution step 78: f(x)= -0.595153
# differential_evolution step 79: f(x)= -0.595178
# differential_evolution step 80: f(x)= -0.595178
# differential_evolution step 81: f(x)= -0.595201
# differential_evolution step 82: f(x)= -0.595209
# differential_evolution step 83: f(x)= -0.595209
# differential_evolution step 84: f(x)= -0.595209
# differential_evolution step 85: f(x)= -0.595214
# differential_evolution step 86: f(x)= -0.595229
# differential_evolution step 87: f(x)= -0.595229
# differential_evolution step 88: f(x)= -0.595231
# differential_evolution step 89: f(x)= -0.595235
# differential_evolution step 90: f(x)= -0.595237
# differential_evolution step 91: f(x)= -0.595237
# differential_evolution step 92: f(x)= -0.595237
# -0.5952369747010774 [0.38078837 0.68096791 0.00392834 0.26858384 0.16099643 0.19690989
#  0.00728969 0.7496733  0.10926556 0.92556513 0.72402884 0.00476432
#  0.52540975 0.12722444 0.88168798 0.57194896 0.69027365 0.04365363
#  0.17603916 0.26604928 0.34248224 0.65087084 0.00249709 0.29768812
#  0.24243275]
# case: 4 (base reward: -0.58)
# differential_evolution step 1: f(x)= -0.590845
# differential_evolution step 2: f(x)= -0.597004
# differential_evolution step 3: f(x)= -0.598412
# differential_evolution step 4: f(x)= -0.598412
# differential_evolution step 5: f(x)= -0.598412
# differential_evolution step 6: f(x)= -0.598997
# differential_evolution step 7: f(x)= -0.598997
# differential_evolution step 8: f(x)= -0.598997
# differential_evolution step 9: f(x)= -0.601058
# differential_evolution step 10: f(x)= -0.601058
# differential_evolution step 11: f(x)= -0.601058
# differential_evolution step 12: f(x)= -0.601058
# differential_evolution step 13: f(x)= -0.601058
# differential_evolution step 14: f(x)= -0.601536
# differential_evolution step 15: f(x)= -0.601536
# differential_evolution step 16: f(x)= -0.602639
# differential_evolution step 17: f(x)= -0.602639
# differential_evolution step 18: f(x)= -0.603039
# differential_evolution step 19: f(x)= -0.603039
# differential_evolution step 20: f(x)= -0.603039
# differential_evolution step 21: f(x)= -0.603039
# differential_evolution step 22: f(x)= -0.60325
# differential_evolution step 23: f(x)= -0.604206
# differential_evolution step 24: f(x)= -0.604712
# differential_evolution step 25: f(x)= -0.604712
# differential_evolution step 26: f(x)= -0.604871
# differential_evolution step 27: f(x)= -0.605303
# differential_evolution step 28: f(x)= -0.605303
# differential_evolution step 29: f(x)= -0.605509
# differential_evolution step 30: f(x)= -0.605509
# differential_evolution step 31: f(x)= -0.605647
# differential_evolution step 32: f(x)= -0.605647
# differential_evolution step 33: f(x)= -0.605647
# differential_evolution step 34: f(x)= -0.605875
# differential_evolution step 35: f(x)= -0.605875
# differential_evolution step 36: f(x)= -0.605875
# differential_evolution step 37: f(x)= -0.605875
# differential_evolution step 38: f(x)= -0.605875
# differential_evolution step 39: f(x)= -0.605875
# differential_evolution step 40: f(x)= -0.605875
# differential_evolution step 41: f(x)= -0.606029
# differential_evolution step 42: f(x)= -0.606094
# differential_evolution step 43: f(x)= -0.606122
# differential_evolution step 44: f(x)= -0.606122
# differential_evolution step 45: f(x)= -0.606141
# differential_evolution step 46: f(x)= -0.606346
# differential_evolution step 47: f(x)= -0.606427
# differential_evolution step 48: f(x)= -0.606427
# differential_evolution step 49: f(x)= -0.606569
# differential_evolution step 50: f(x)= -0.606828
# differential_evolution step 51: f(x)= -0.606828
# differential_evolution step 52: f(x)= -0.606828
# differential_evolution step 53: f(x)= -0.60683
# differential_evolution step 54: f(x)= -0.606891
# differential_evolution step 55: f(x)= -0.606891
# differential_evolution step 56: f(x)= -0.606891
# differential_evolution step 57: f(x)= -0.606891
# differential_evolution step 58: f(x)= -0.606891
# differential_evolution step 59: f(x)= -0.606891
# differential_evolution step 60: f(x)= -0.606975
# differential_evolution step 61: f(x)= -0.607064
# differential_evolution step 62: f(x)= -0.607134
# differential_evolution step 63: f(x)= -0.607292
# differential_evolution step 64: f(x)= -0.607295
# differential_evolution step 65: f(x)= -0.607366
# differential_evolution step 66: f(x)= -0.607366
# differential_evolution step 67: f(x)= -0.607395
# differential_evolution step 68: f(x)= -0.607451
# differential_evolution step 69: f(x)= -0.607519
# differential_evolution step 70: f(x)= -0.60758
# differential_evolution step 71: f(x)= -0.607585
# differential_evolution step 72: f(x)= -0.607652
# differential_evolution step 73: f(x)= -0.60768
# differential_evolution step 74: f(x)= -0.60768
# differential_evolution step 75: f(x)= -0.60768
# differential_evolution step 76: f(x)= -0.607705
# differential_evolution step 77: f(x)= -0.60776
# differential_evolution step 78: f(x)= -0.607789
# differential_evolution step 79: f(x)= -0.607789
# differential_evolution step 80: f(x)= -0.607807
# differential_evolution step 81: f(x)= -0.607825
# differential_evolution step 82: f(x)= -0.607825
# differential_evolution step 83: f(x)= -0.607859
# differential_evolution step 84: f(x)= -0.607867
# differential_evolution step 85: f(x)= -0.607879
# differential_evolution step 86: f(x)= -0.607896
# differential_evolution step 87: f(x)= -0.607913
# differential_evolution step 88: f(x)= -0.607913
# differential_evolution step 89: f(x)= -0.607941
# differential_evolution step 90: f(x)= -0.607946
# differential_evolution step 91: f(x)= -0.607976
# differential_evolution step 92: f(x)= -0.608007
# differential_evolution step 93: f(x)= -0.608008
# differential_evolution step 94: f(x)= -0.608008
# differential_evolution step 95: f(x)= -0.608008
# differential_evolution step 96: f(x)= -0.608008
# differential_evolution step 97: f(x)= -0.608015
# differential_evolution step 98: f(x)= -0.608015
# differential_evolution step 99: f(x)= -0.608017
# differential_evolution step 100: f(x)= -0.608034
# differential_evolution step 101: f(x)= -0.608054
# differential_evolution step 102: f(x)= -0.608056
# differential_evolution step 103: f(x)= -0.608056
# differential_evolution step 104: f(x)= -0.608062
# differential_evolution step 105: f(x)= -0.608064
# differential_evolution step 106: f(x)= -0.608066
# differential_evolution step 107: f(x)= -0.608072
# differential_evolution step 108: f(x)= -0.60808
# differential_evolution step 109: f(x)= -0.60808
# differential_evolution step 110: f(x)= -0.608082
# differential_evolution step 111: f(x)= -0.608083
# -0.6080828954784633 [0.86528829 0.04310412 0.99169504 0.06023145 0.35923302 0.62016391
#  0.18151028 0.15122769 0.92278634 0.00236438 0.56269994 0.0946216
#  0.02156381 0.87246496 0.12171052 0.37528277 0.22243171 0.12199738
#  0.90426131 0.47079502 0.51473976 0.31395204 0.36849595 0.08943462
#  0.40975097]
# case: 5 (base reward: -0.63)
# differential_evolution step 1: f(x)= -0.62968
# differential_evolution step 2: f(x)= -0.629792
# differential_evolution step 3: f(x)= -0.630457
# differential_evolution step 4: f(x)= -0.632117
# differential_evolution step 5: f(x)= -0.632117
# differential_evolution step 6: f(x)= -0.632117
# differential_evolution step 7: f(x)= -0.632483
# differential_evolution step 8: f(x)= -0.632483
# differential_evolution step 9: f(x)= -0.632564
# differential_evolution step 10: f(x)= -0.632616
# differential_evolution step 11: f(x)= -0.632882
# differential_evolution step 12: f(x)= -0.633378
# differential_evolution step 13: f(x)= -0.634114
# differential_evolution step 14: f(x)= -0.634404
# differential_evolution step 15: f(x)= -0.63443
# differential_evolution step 16: f(x)= -0.63443
# differential_evolution step 17: f(x)= -0.634467
# differential_evolution step 18: f(x)= -0.634467
# differential_evolution step 19: f(x)= -0.634467
# differential_evolution step 20: f(x)= -0.634707
# differential_evolution step 21: f(x)= -0.634781
# differential_evolution step 22: f(x)= -0.634781
# differential_evolution step 23: f(x)= -0.634812
# differential_evolution step 24: f(x)= -0.634812
# differential_evolution step 25: f(x)= -0.634812
# differential_evolution step 26: f(x)= -0.634813
# differential_evolution step 27: f(x)= -0.634831
# differential_evolution step 28: f(x)= -0.634902
# differential_evolution step 29: f(x)= -0.634902
# differential_evolution step 30: f(x)= -0.634943
# differential_evolution step 31: f(x)= -0.635
# differential_evolution step 32: f(x)= -0.635
# differential_evolution step 33: f(x)= -0.635
# differential_evolution step 34: f(x)= -0.63504
# differential_evolution step 35: f(x)= -0.635077
# differential_evolution step 36: f(x)= -0.63513
# differential_evolution step 37: f(x)= -0.63513
# differential_evolution step 38: f(x)= -0.63513
# differential_evolution step 39: f(x)= -0.63513
# differential_evolution step 40: f(x)= -0.63513
# differential_evolution step 41: f(x)= -0.63513
# differential_evolution step 42: f(x)= -0.635145
# differential_evolution step 43: f(x)= -0.635169
# differential_evolution step 44: f(x)= -0.635169
# differential_evolution step 45: f(x)= -0.635169
# differential_evolution step 46: f(x)= -0.635169
# differential_evolution step 47: f(x)= -0.635169
# differential_evolution step 48: f(x)= -0.635169
# differential_evolution step 49: f(x)= -0.635175
# differential_evolution step 50: f(x)= -0.63518
# differential_evolution step 51: f(x)= -0.63518
# differential_evolution step 52: f(x)= -0.635187
# differential_evolution step 53: f(x)= -0.635187
# differential_evolution step 54: f(x)= -0.635188
# differential_evolution step 55: f(x)= -0.635188
# differential_evolution step 56: f(x)= -0.635189
# differential_evolution step 57: f(x)= -0.635189
# differential_evolution step 58: f(x)= -0.635189
# -0.6351892686791516 [0.73278742 0.73348347 0.76682464 0.00405729 0.27933419 0.59021498
#  0.41391805 0.42755038 0.98194148 0.65506511 0.53185359 0.26833676
#  0.1729814  0.72137679 0.29500514 0.69407612 0.36520936 0.16441487
#  0.56808089 0.45996087 0.69794612 0.53276416 0.40550717 0.26198776
#  0.49375909]
# case: 6 (base reward: -0.59)
# differential_evolution step 1: f(x)= -0.60391
# differential_evolution step 2: f(x)= -0.60391
# differential_evolution step 3: f(x)= -0.60391
# differential_evolution step 4: f(x)= -0.60391
# differential_evolution step 5: f(x)= -0.60391
# differential_evolution step 6: f(x)= -0.604987
# differential_evolution step 7: f(x)= -0.605094
# differential_evolution step 8: f(x)= -0.605094
# differential_evolution step 9: f(x)= -0.605337
# differential_evolution step 10: f(x)= -0.605337
# differential_evolution step 11: f(x)= -0.605337
# differential_evolution step 12: f(x)= -0.606115
# differential_evolution step 13: f(x)= -0.606115
# differential_evolution step 14: f(x)= -0.606115
# differential_evolution step 15: f(x)= -0.60635
# differential_evolution step 16: f(x)= -0.606647
# differential_evolution step 17: f(x)= -0.606647
# differential_evolution step 18: f(x)= -0.606647
# differential_evolution step 19: f(x)= -0.606735
# differential_evolution step 20: f(x)= -0.606735
# differential_evolution step 21: f(x)= -0.606735
# differential_evolution step 22: f(x)= -0.606924
# differential_evolution step 23: f(x)= -0.606924
# differential_evolution step 24: f(x)= -0.606944
# differential_evolution step 25: f(x)= -0.606967
# differential_evolution step 26: f(x)= -0.60699
# differential_evolution step 27: f(x)= -0.60699
# differential_evolution step 28: f(x)= -0.607014
# differential_evolution step 29: f(x)= -0.607018
# differential_evolution step 30: f(x)= -0.607047
# differential_evolution step 31: f(x)= -0.607077
# differential_evolution step 32: f(x)= -0.607077
# differential_evolution step 33: f(x)= -0.607105
# differential_evolution step 34: f(x)= -0.607126
# differential_evolution step 35: f(x)= -0.607126
# differential_evolution step 36: f(x)= -0.607126
# differential_evolution step 37: f(x)= -0.607126
# differential_evolution step 38: f(x)= -0.607126
# differential_evolution step 39: f(x)= -0.607126
# differential_evolution step 40: f(x)= -0.607146
# differential_evolution step 41: f(x)= -0.607155
# differential_evolution step 42: f(x)= -0.607181
# differential_evolution step 43: f(x)= -0.607188
# differential_evolution step 44: f(x)= -0.60719
# differential_evolution step 45: f(x)= -0.607208
# differential_evolution step 46: f(x)= -0.607208
# differential_evolution step 47: f(x)= -0.607208
# differential_evolution step 48: f(x)= -0.607208
# differential_evolution step 49: f(x)= -0.607208
# differential_evolution step 50: f(x)= -0.607208
# differential_evolution step 51: f(x)= -0.607214
# differential_evolution step 52: f(x)= -0.60723
# differential_evolution step 53: f(x)= -0.607247
# differential_evolution step 54: f(x)= -0.607247
# differential_evolution step 55: f(x)= -0.607252
# differential_evolution step 56: f(x)= -0.607294
# differential_evolution step 57: f(x)= -0.607316
# differential_evolution step 58: f(x)= -0.607316
# differential_evolution step 59: f(x)= -0.607316
# differential_evolution step 60: f(x)= -0.60733
# differential_evolution step 61: f(x)= -0.60733
# differential_evolution step 62: f(x)= -0.607349
# differential_evolution step 63: f(x)= -0.607366
# differential_evolution step 64: f(x)= -0.607385
# differential_evolution step 65: f(x)= -0.607385
# differential_evolution step 66: f(x)= -0.607385
# differential_evolution step 67: f(x)= -0.607388
# differential_evolution step 68: f(x)= -0.607388
# differential_evolution step 69: f(x)= -0.607393
# differential_evolution step 70: f(x)= -0.6074
# differential_evolution step 71: f(x)= -0.607414
# differential_evolution step 72: f(x)= -0.607414
# differential_evolution step 73: f(x)= -0.607414
# differential_evolution step 74: f(x)= -0.607414
# differential_evolution step 75: f(x)= -0.607417
# differential_evolution step 76: f(x)= -0.607425
# differential_evolution step 77: f(x)= -0.607426
# differential_evolution step 78: f(x)= -0.607427
# differential_evolution step 79: f(x)= -0.607428
# differential_evolution step 80: f(x)= -0.607439
# differential_evolution step 81: f(x)= -0.607439
# differential_evolution step 82: f(x)= -0.607443
# differential_evolution step 83: f(x)= -0.607449
# differential_evolution step 84: f(x)= -0.60745
# differential_evolution step 85: f(x)= -0.60745
# differential_evolution step 86: f(x)= -0.607451
# differential_evolution step 87: f(x)= -0.607451
# -0.6074513095831893 [0.61913104 0.65508079 0.85153897 0.00982933 0.41423257 0.1463511
#  0.30459791 0.80039369 0.60234887 0.28846038 0.45690317 0.59575388
#  0.92912306 0.50966519 0.6386044  0.2338914  0.4876136  0.57156476
#  0.21776049 0.6532249  0.49749391 0.50572556 0.52028407 0.27736513
#  0.72147584]
# case: 7 (base reward: -0.55)
# differential_evolution step 1: f(x)= -0.569591
# differential_evolution step 2: f(x)= -0.580397
# differential_evolution step 3: f(x)= -0.580397
# differential_evolution step 4: f(x)= -0.58467
# differential_evolution step 5: f(x)= -0.58467
# differential_evolution step 6: f(x)= -0.58467
# differential_evolution step 7: f(x)= -0.586555
# differential_evolution step 8: f(x)= -0.588389
# differential_evolution step 9: f(x)= -0.588389
# differential_evolution step 10: f(x)= -0.589212
# differential_evolution step 11: f(x)= -0.589212
# differential_evolution step 12: f(x)= -0.591242
# differential_evolution step 13: f(x)= -0.591242
# differential_evolution step 14: f(x)= -0.592253
# differential_evolution step 15: f(x)= -0.592484
# differential_evolution step 16: f(x)= -0.592484
# differential_evolution step 17: f(x)= -0.592484
# differential_evolution step 18: f(x)= -0.592484
# differential_evolution step 19: f(x)= -0.59402
# differential_evolution step 20: f(x)= -0.594387
# differential_evolution step 21: f(x)= -0.594387
# differential_evolution step 22: f(x)= -0.594387
# differential_evolution step 23: f(x)= -0.594387
# differential_evolution step 24: f(x)= -0.594387
# differential_evolution step 25: f(x)= -0.594387
# differential_evolution step 26: f(x)= -0.594387
# differential_evolution step 27: f(x)= -0.594387
# differential_evolution step 28: f(x)= -0.594711
# differential_evolution step 29: f(x)= -0.594711
# differential_evolution step 30: f(x)= -0.594711
# differential_evolution step 31: f(x)= -0.594711
# differential_evolution step 32: f(x)= -0.594711
# differential_evolution step 33: f(x)= -0.594751
# differential_evolution step 34: f(x)= -0.594751
# differential_evolution step 35: f(x)= -0.595243
# differential_evolution step 36: f(x)= -0.595243
# differential_evolution step 37: f(x)= -0.595243
# differential_evolution step 38: f(x)= -0.595243
# differential_evolution step 39: f(x)= -0.595401
# differential_evolution step 40: f(x)= -0.595401
# differential_evolution step 41: f(x)= -0.595406
# differential_evolution step 42: f(x)= -0.59546
# differential_evolution step 43: f(x)= -0.59546
# differential_evolution step 44: f(x)= -0.59546
# differential_evolution step 45: f(x)= -0.59546
# differential_evolution step 46: f(x)= -0.595539
# differential_evolution step 47: f(x)= -0.595593
# differential_evolution step 48: f(x)= -0.595593
# differential_evolution step 49: f(x)= -0.595593
# differential_evolution step 50: f(x)= -0.595593
# differential_evolution step 51: f(x)= -0.595593
# differential_evolution step 52: f(x)= -0.595598
# differential_evolution step 53: f(x)= -0.595598
# differential_evolution step 54: f(x)= -0.595617
# differential_evolution step 55: f(x)= -0.595617
# differential_evolution step 56: f(x)= -0.595632
# differential_evolution step 57: f(x)= -0.595632
# differential_evolution step 58: f(x)= -0.595638
# differential_evolution step 59: f(x)= -0.595645
# differential_evolution step 60: f(x)= -0.595656
# differential_evolution step 61: f(x)= -0.595656
# differential_evolution step 62: f(x)= -0.595656
# differential_evolution step 63: f(x)= -0.595682
# differential_evolution step 64: f(x)= -0.595755
# differential_evolution step 65: f(x)= -0.595759
# differential_evolution step 66: f(x)= -0.595759
# differential_evolution step 67: f(x)= -0.595759
# differential_evolution step 68: f(x)= -0.595759
# differential_evolution step 69: f(x)= -0.595759
# differential_evolution step 70: f(x)= -0.595759
# differential_evolution step 71: f(x)= -0.595761
# differential_evolution step 72: f(x)= -0.595761
# differential_evolution step 73: f(x)= -0.595765
# differential_evolution step 74: f(x)= -0.595765
# differential_evolution step 75: f(x)= -0.595765
# differential_evolution step 76: f(x)= -0.595765
# differential_evolution step 77: f(x)= -0.595776
# differential_evolution step 78: f(x)= -0.595776
# differential_evolution step 79: f(x)= -0.595785
# differential_evolution step 80: f(x)= -0.595793
# differential_evolution step 81: f(x)= -0.595799
# differential_evolution step 82: f(x)= -0.595799
# differential_evolution step 83: f(x)= -0.595802
# differential_evolution step 84: f(x)= -0.595802
# differential_evolution step 85: f(x)= -0.595802
# differential_evolution step 86: f(x)= -0.595802
# differential_evolution step 87: f(x)= -0.595802
# differential_evolution step 88: f(x)= -0.595802
# differential_evolution step 89: f(x)= -0.595805
# differential_evolution step 90: f(x)= -0.595805
# differential_evolution step 91: f(x)= -0.595807
# differential_evolution step 92: f(x)= -0.595812
# differential_evolution step 93: f(x)= -0.595817
# differential_evolution step 94: f(x)= -0.595824
# differential_evolution step 95: f(x)= -0.595835
# differential_evolution step 96: f(x)= -0.595848
# differential_evolution step 97: f(x)= -0.595848
# differential_evolution step 98: f(x)= -0.595848
# differential_evolution step 99: f(x)= -0.595848
# differential_evolution step 100: f(x)= -0.595859
# differential_evolution step 101: f(x)= -0.595864
# differential_evolution step 102: f(x)= -0.595864
# differential_evolution step 103: f(x)= -0.595878
# differential_evolution step 104: f(x)= -0.595878
# differential_evolution step 105: f(x)= -0.595879
# differential_evolution step 106: f(x)= -0.595879
# -0.5958794931160448 [0.25323151 0.00137378 0.79599437 0.84201106 0.5552197  0.51889916
#  0.91545371 0.23288689 0.97536461 0.11502779 0.60714706 0.2599505
#  0.79249571 0.83016634 0.09309096 0.31473259 0.09344836 0.96536281
#  0.79492545 0.19397729 0.5195475  0.06604046 0.51169815 0.17993418
#  0.1578576 ]
# case: 8 (base reward: -0.57)
# differential_evolution step 1: f(x)= -0.605836
# differential_evolution step 2: f(x)= -0.607219
# differential_evolution step 3: f(x)= -0.613326
# differential_evolution step 4: f(x)= -0.613326
# differential_evolution step 5: f(x)= -0.613326
# differential_evolution step 6: f(x)= -0.615172
# differential_evolution step 7: f(x)= -0.620007
# differential_evolution step 8: f(x)= -0.620007
# differential_evolution step 9: f(x)= -0.621393
# differential_evolution step 10: f(x)= -0.621393
# differential_evolution step 11: f(x)= -0.622124
# differential_evolution step 12: f(x)= -0.622124
# differential_evolution step 13: f(x)= -0.622124
# differential_evolution step 14: f(x)= -0.622919
# differential_evolution step 15: f(x)= -0.623177
# differential_evolution step 16: f(x)= -0.623177
# differential_evolution step 17: f(x)= -0.623177
# differential_evolution step 18: f(x)= -0.624163
# differential_evolution step 19: f(x)= -0.624696
# differential_evolution step 20: f(x)= -0.624725
# differential_evolution step 21: f(x)= -0.625398
# differential_evolution step 22: f(x)= -0.625398
# differential_evolution step 23: f(x)= -0.625398
# differential_evolution step 24: f(x)= -0.625398
# differential_evolution step 25: f(x)= -0.625626
# differential_evolution step 26: f(x)= -0.626418
# differential_evolution step 27: f(x)= -0.627642
# differential_evolution step 28: f(x)= -0.627642
# differential_evolution step 29: f(x)= -0.627642
# differential_evolution step 30: f(x)= -0.627642
# differential_evolution step 31: f(x)= -0.627986
# differential_evolution step 32: f(x)= -0.628232
# differential_evolution step 33: f(x)= -0.628232
# differential_evolution step 34: f(x)= -0.628232
# differential_evolution step 35: f(x)= -0.628349
# differential_evolution step 36: f(x)= -0.628884
# differential_evolution step 37: f(x)= -0.628884
# differential_evolution step 38: f(x)= -0.628929
# differential_evolution step 39: f(x)= -0.629207
# differential_evolution step 40: f(x)= -0.629207
# differential_evolution step 41: f(x)= -0.629207
# differential_evolution step 42: f(x)= -0.629207
# differential_evolution step 43: f(x)= -0.629207
# differential_evolution step 44: f(x)= -0.629532
# differential_evolution step 45: f(x)= -0.629559
# differential_evolution step 46: f(x)= -0.629869
# differential_evolution step 47: f(x)= -0.630334
# differential_evolution step 48: f(x)= -0.630334
# differential_evolution step 49: f(x)= -0.630334
# differential_evolution step 50: f(x)= -0.630388
# differential_evolution step 51: f(x)= -0.63047
# differential_evolution step 52: f(x)= -0.630523
# differential_evolution step 53: f(x)= -0.630665
# differential_evolution step 54: f(x)= -0.630665
# differential_evolution step 55: f(x)= -0.630837
# differential_evolution step 56: f(x)= -0.630837
# differential_evolution step 57: f(x)= -0.630854
# differential_evolution step 58: f(x)= -0.630854
# differential_evolution step 59: f(x)= -0.630854
# differential_evolution step 60: f(x)= -0.630854
# differential_evolution step 61: f(x)= -0.630854
# differential_evolution step 62: f(x)= -0.631129
# differential_evolution step 63: f(x)= -0.631129
# differential_evolution step 64: f(x)= -0.631273
# differential_evolution step 65: f(x)= -0.631315
# differential_evolution step 66: f(x)= -0.631508
# differential_evolution step 67: f(x)= -0.63159
# differential_evolution step 68: f(x)= -0.632096
# differential_evolution step 69: f(x)= -0.632096
# differential_evolution step 70: f(x)= -0.632096
# differential_evolution step 71: f(x)= -0.632096
# differential_evolution step 72: f(x)= -0.63238
# differential_evolution step 73: f(x)= -0.63238
# differential_evolution step 74: f(x)= -0.63238
# differential_evolution step 75: f(x)= -0.63238
# differential_evolution step 76: f(x)= -0.63238
# differential_evolution step 77: f(x)= -0.63238
# differential_evolution step 78: f(x)= -0.63238
# differential_evolution step 79: f(x)= -0.63238
# differential_evolution step 80: f(x)= -0.63238
# differential_evolution step 81: f(x)= -0.63238
# differential_evolution step 82: f(x)= -0.632751
# differential_evolution step 83: f(x)= -0.632751
# differential_evolution step 84: f(x)= -0.632751
# differential_evolution step 85: f(x)= -0.632751
# differential_evolution step 86: f(x)= -0.632751
# differential_evolution step 87: f(x)= -0.632814
# differential_evolution step 88: f(x)= -0.632814
# differential_evolution step 89: f(x)= -0.632814
# differential_evolution step 90: f(x)= -0.632901
# differential_evolution step 91: f(x)= -0.632901
# differential_evolution step 92: f(x)= -0.632901
# differential_evolution step 93: f(x)= -0.632916
# differential_evolution step 94: f(x)= -0.632924
# differential_evolution step 95: f(x)= -0.632959
# differential_evolution step 96: f(x)= -0.632959
# differential_evolution step 97: f(x)= -0.632959
# differential_evolution step 98: f(x)= -0.632995
# differential_evolution step 99: f(x)= -0.632999
# differential_evolution step 100: f(x)= -0.633023
# differential_evolution step 101: f(x)= -0.633052
# differential_evolution step 102: f(x)= -0.633065
# differential_evolution step 103: f(x)= -0.633096
# differential_evolution step 104: f(x)= -0.633096
# differential_evolution step 105: f(x)= -0.633108
# differential_evolution step 106: f(x)= -0.633165
# differential_evolution step 107: f(x)= -0.633173
# differential_evolution step 108: f(x)= -0.633197
# differential_evolution step 109: f(x)= -0.633198
# differential_evolution step 110: f(x)= -0.633208
# differential_evolution step 111: f(x)= -0.633223
# differential_evolution step 112: f(x)= -0.633229
# differential_evolution step 113: f(x)= -0.633229
# differential_evolution step 114: f(x)= -0.633229
# differential_evolution step 115: f(x)= -0.633232
# differential_evolution step 116: f(x)= -0.63324
# differential_evolution step 117: f(x)= -0.633255
# differential_evolution step 118: f(x)= -0.633268
# differential_evolution step 119: f(x)= -0.633268
# differential_evolution step 120: f(x)= -0.633288
# differential_evolution step 121: f(x)= -0.633288
# differential_evolution step 122: f(x)= -0.633307
# differential_evolution step 123: f(x)= -0.633307
# differential_evolution step 124: f(x)= -0.633307
# differential_evolution step 125: f(x)= -0.633307
# differential_evolution step 126: f(x)= -0.633307
# differential_evolution step 127: f(x)= -0.633318
# differential_evolution step 128: f(x)= -0.633319
# differential_evolution step 129: f(x)= -0.633334
# differential_evolution step 130: f(x)= -0.633363
# differential_evolution step 131: f(x)= -0.633363
# differential_evolution step 132: f(x)= -0.633363
# differential_evolution step 133: f(x)= -0.633399
# differential_evolution step 134: f(x)= -0.6334
# differential_evolution step 135: f(x)= -0.633418
# differential_evolution step 136: f(x)= -0.633423
# differential_evolution step 137: f(x)= -0.633452
# differential_evolution step 138: f(x)= -0.633457
# differential_evolution step 139: f(x)= -0.633457
# differential_evolution step 140: f(x)= -0.633461
# differential_evolution step 141: f(x)= -0.633462
# differential_evolution step 142: f(x)= -0.633471
# differential_evolution step 143: f(x)= -0.633476
# differential_evolution step 144: f(x)= -0.633476
# differential_evolution step 145: f(x)= -0.633476
# differential_evolution step 146: f(x)= -0.633476
# differential_evolution step 147: f(x)= -0.633486
# differential_evolution step 148: f(x)= -0.633486
# differential_evolution step 149: f(x)= -0.633493
# differential_evolution step 150: f(x)= -0.633499
# differential_evolution step 151: f(x)= -0.633507
# differential_evolution step 152: f(x)= -0.633518
# differential_evolution step 153: f(x)= -0.633522
# differential_evolution step 154: f(x)= -0.633525
# differential_evolution step 155: f(x)= -0.633527
# differential_evolution step 156: f(x)= -0.633527
# differential_evolution step 157: f(x)= -0.633527
# differential_evolution step 158: f(x)= -0.63353
# differential_evolution step 159: f(x)= -0.633537
# differential_evolution step 160: f(x)= -0.633544
# differential_evolution step 161: f(x)= -0.633544
# differential_evolution step 162: f(x)= -0.63355
# differential_evolution step 163: f(x)= -0.633561
# differential_evolution step 164: f(x)= -0.633563
# differential_evolution step 165: f(x)= -0.633563
# differential_evolution step 166: f(x)= -0.633563
# differential_evolution step 167: f(x)= -0.633569
# differential_evolution step 168: f(x)= -0.633569
# differential_evolution step 169: f(x)= -0.633569
# differential_evolution step 170: f(x)= -0.633575
# differential_evolution step 171: f(x)= -0.633575
# differential_evolution step 172: f(x)= -0.633575
# differential_evolution step 173: f(x)= -0.633575
# differential_evolution step 174: f(x)= -0.633586
# differential_evolution step 175: f(x)= -0.633586
# differential_evolution step 176: f(x)= -0.633591
# differential_evolution step 177: f(x)= -0.633591
# differential_evolution step 178: f(x)= -0.633591
# differential_evolution step 179: f(x)= -0.633602
# differential_evolution step 180: f(x)= -0.633602
# differential_evolution step 181: f(x)= -0.633602
# differential_evolution step 182: f(x)= -0.633602
# differential_evolution step 183: f(x)= -0.633605
# differential_evolution step 184: f(x)= -0.633606
# differential_evolution step 185: f(x)= -0.633607
# differential_evolution step 186: f(x)= -0.633608
# differential_evolution step 187: f(x)= -0.633608
# differential_evolution step 188: f(x)= -0.633611
# differential_evolution step 189: f(x)= -0.633622
# differential_evolution step 190: f(x)= -0.633622
# differential_evolution step 191: f(x)= -0.633622
# differential_evolution step 192: f(x)= -0.633622
# differential_evolution step 193: f(x)= -0.633623
# -0.6336230607037938 [0.53292667 0.00143456 0.41225723 0.00134549 0.45353427 0.32152946
#  0.11934826 0.41312422 0.2675963  0.46686113 0.19128173 0.24021408
#  0.02342423 0.80074551 0.00109132 0.24329736 0.11062414 0.01027194
# ...
# differential_evolution step 112: f(x)= -0.596054
# differential_evolution step 113: f(x)= -0.596054
# differential_evolution step 114: f(x)= -0.596054
# differential_evolution step 115: f(x)= -0.596062
# differential_evolution step 116: f(x)= -0.596066
# differential_evolution step 117: f(x)= -0.596067
# differential_evolution step 118: f(x)= -0.596076
# differential_evolution step 119: f(x)= -0.596078
# -0.5960783507340669 [0.38322841 0.92753554 0.00166558 0.49043782 0.76078706 0.90634975
#  0.93355403 0.00168097 0.35731332 0.53428159 0.50392197 0.88774609
#  0.01249813 0.22879161 0.23884598 0.60781558 0.06676111 0.97657759
#  0.11633594 0.1507686  0.40655606 0.07964582 0.68690174 0.26150078
#  0.21076947]
# case: 12 (base reward: -0.58)
# differential_evolution step 1: f(x)= -0.605667
# differential_evolution step 2: f(x)= -0.610908
# differential_evolution step 3: f(x)= -0.62924
# differential_evolution step 4: f(x)= -0.629864
# differential_evolution step 5: f(x)= -0.629864
# differential_evolution step 6: f(x)= -0.629864
# differential_evolution step 7: f(x)= -0.629864
# differential_evolution step 8: f(x)= -0.629864
# differential_evolution step 9: f(x)= -0.633191
# differential_evolution step 10: f(x)= -0.633444
# differential_evolution step 11: f(x)= -0.633697
# differential_evolution step 12: f(x)= -0.633697
# differential_evolution step 13: f(x)= -0.633747
# differential_evolution step 14: f(x)= -0.633747
# differential_evolution step 15: f(x)= -0.633747
# differential_evolution step 16: f(x)= -0.633871
# differential_evolution step 17: f(x)= -0.633948
# differential_evolution step 18: f(x)= -0.634255
# differential_evolution step 19: f(x)= -0.634255
# differential_evolution step 20: f(x)= -0.634255
# differential_evolution step 21: f(x)= -0.634402
# differential_evolution step 22: f(x)= -0.634425
# differential_evolution step 23: f(x)= -0.634425
# differential_evolution step 24: f(x)= -0.634425
# differential_evolution step 25: f(x)= -0.63458
# differential_evolution step 26: f(x)= -0.634618
# differential_evolution step 27: f(x)= -0.634698
# differential_evolution step 28: f(x)= -0.634698
# differential_evolution step 29: f(x)= -0.634849
# differential_evolution step 30: f(x)= -0.634849
# differential_evolution step 31: f(x)= -0.634849
# differential_evolution step 32: f(x)= -0.634849
# differential_evolution step 33: f(x)= -0.634852
# differential_evolution step 34: f(x)= -0.634949
# differential_evolution step 35: f(x)= -0.634984
# differential_evolution step 36: f(x)= -0.634984
# differential_evolution step 37: f(x)= -0.635013
# differential_evolution step 38: f(x)= -0.635029
# differential_evolution step 39: f(x)= -0.635059
# differential_evolution step 40: f(x)= -0.635065
# differential_evolution step 41: f(x)= -0.635111
# differential_evolution step 42: f(x)= -0.635138
# differential_evolution step 43: f(x)= -0.635143
# differential_evolution step 44: f(x)= -0.635152
# differential_evolution step 45: f(x)= -0.63516
# differential_evolution step 46: f(x)= -0.63517
# differential_evolution step 47: f(x)= -0.63518
# differential_evolution step 48: f(x)= -0.635189
# differential_evolution step 49: f(x)= -0.635203
# differential_evolution step 50: f(x)= -0.63521
# differential_evolution step 51: f(x)= -0.635227
# differential_evolution step 52: f(x)= -0.635232
# differential_evolution step 53: f(x)= -0.635247
# differential_evolution step 54: f(x)= -0.635254
# differential_evolution step 55: f(x)= -0.635274
# differential_evolution step 56: f(x)= -0.635274
# differential_evolution step 57: f(x)= -0.635275
# differential_evolution step 58: f(x)= -0.635283
# differential_evolution step 59: f(x)= -0.635283
# differential_evolution step 60: f(x)= -0.635283
# differential_evolution step 61: f(x)= -0.635284
# differential_evolution step 62: f(x)= -0.635284
# differential_evolution step 63: f(x)= -0.63529
# -0.6352896916346928 [0.23421222 0.62236367 0.49978489 0.56532172 0.54243816 0.45646705
#  0.87118626 0.31225223 0.31691339 0.26961761 0.64535233 0.71602946
#  0.22014382 0.51066118 0.09564997 0.45497132 0.95798188 0.37159101
#  0.90265544 0.05650843 0.4078917  0.55579457 0.51279752 0.8150992
#  0.06953149]
# case: 13 (base reward: -0.6)
# differential_evolution step 1: f(x)= -0.612026
# differential_evolution step 2: f(x)= -0.61213
# differential_evolution step 3: f(x)= -0.61213
# differential_evolution step 4: f(x)= -0.612671
# differential_evolution step 5: f(x)= -0.613882
# differential_evolution step 6: f(x)= -0.614094
# differential_evolution step 7: f(x)= -0.614094
# differential_evolution step 8: f(x)= -0.614094
# differential_evolution step 9: f(x)= -0.614094
# differential_evolution step 10: f(x)= -0.614094
# differential_evolution step 11: f(x)= -0.614094
# differential_evolution step 12: f(x)= -0.614094
# differential_evolution step 13: f(x)= -0.614177
# differential_evolution step 14: f(x)= -0.614177
# differential_evolution step 15: f(x)= -0.614312
# differential_evolution step 16: f(x)= -0.614394
# differential_evolution step 17: f(x)= -0.614394
# differential_evolution step 18: f(x)= -0.614394
# differential_evolution step 19: f(x)= -0.61442
# differential_evolution step 20: f(x)= -0.614512
# differential_evolution step 21: f(x)= -0.614802
# differential_evolution step 22: f(x)= -0.614802
# differential_evolution step 23: f(x)= -0.614802
# differential_evolution step 24: f(x)= -0.614802
# differential_evolution step 25: f(x)= -0.614802
# differential_evolution step 26: f(x)= -0.614802
# differential_evolution step 27: f(x)= -0.614802
# differential_evolution step 28: f(x)= -0.614802
# differential_evolution step 29: f(x)= -0.615024
# differential_evolution step 30: f(x)= -0.615024
# differential_evolution step 31: f(x)= -0.615024
# differential_evolution step 32: f(x)= -0.615093
# differential_evolution step 33: f(x)= -0.61512
# differential_evolution step 34: f(x)= -0.615239
# differential_evolution step 35: f(x)= -0.615325
# differential_evolution step 36: f(x)= -0.615446
# differential_evolution step 37: f(x)= -0.615446
# differential_evolution step 38: f(x)= -0.615446
# differential_evolution step 39: f(x)= -0.615498
# differential_evolution step 40: f(x)= -0.615498
# differential_evolution step 41: f(x)= -0.615498
# differential_evolution step 42: f(x)= -0.615498
# differential_evolution step 43: f(x)= -0.615498
# differential_evolution step 44: f(x)= -0.615531
# differential_evolution step 45: f(x)= -0.615581
# differential_evolution step 46: f(x)= -0.615641
# differential_evolution step 47: f(x)= -0.615672
# differential_evolution step 48: f(x)= -0.615672
# differential_evolution step 49: f(x)= -0.615672
# differential_evolution step 50: f(x)= -0.6157
# differential_evolution step 51: f(x)= -0.615708
# differential_evolution step 52: f(x)= -0.61576
# differential_evolution step 53: f(x)= -0.615783
# differential_evolution step 54: f(x)= -0.615829
# differential_evolution step 55: f(x)= -0.615832
# differential_evolution step 56: f(x)= -0.615832
# differential_evolution step 57: f(x)= -0.615886
# differential_evolution step 58: f(x)= -0.615894
# differential_evolution step 59: f(x)= -0.61592
# differential_evolution step 60: f(x)= -0.61592
# differential_evolution step 61: f(x)= -0.61592
# differential_evolution step 62: f(x)= -0.615956
# differential_evolution step 63: f(x)= -0.615956
# differential_evolution step 64: f(x)= -0.615956
# differential_evolution step 65: f(x)= -0.615956
# differential_evolution step 66: f(x)= -0.615957
# differential_evolution step 67: f(x)= -0.615957
# differential_evolution step 68: f(x)= -0.615997
# differential_evolution step 69: f(x)= -0.61602
# differential_evolution step 70: f(x)= -0.61602
# differential_evolution step 71: f(x)= -0.616027
# differential_evolution step 72: f(x)= -0.616027
# differential_evolution step 73: f(x)= -0.616027
# differential_evolution step 74: f(x)= -0.616027
# differential_evolution step 75: f(x)= -0.616027
# differential_evolution step 76: f(x)= -0.616027
# differential_evolution step 77: f(x)= -0.616027
# differential_evolution step 78: f(x)= -0.616027
# differential_evolution step 79: f(x)= -0.616027
# -0.6160271735982726 [0.81265277 0.47802004 0.8024598  0.00126636 0.81131675 0.48619657
#  0.30756961 0.30127761 0.18634676 0.15091437 0.82271134 0.84983327
#  0.72523273 0.50467827 0.28206623 0.38372695 0.85127162 0.60752213
#  0.63668419 0.58173212 0.49865186 0.68681633 0.28157962 0.14095426
#  0.7463691 ]
# case: 14 (base reward: -0.56)
# differential_evolution step 1: f(x)= -0.569003
# differential_evolution step 2: f(x)= -0.569003
# differential_evolution step 3: f(x)= -0.570845
# differential_evolution step 4: f(x)= -0.572955
# differential_evolution step 5: f(x)= -0.573046
# differential_evolution step 6: f(x)= -0.573046
# differential_evolution step 7: f(x)= -0.573765
# differential_evolution step 8: f(x)= -0.573765
# differential_evolution step 9: f(x)= -0.573765
# differential_evolution step 10: f(x)= -0.573765
# differential_evolution step 11: f(x)= -0.573765
# differential_evolution step 12: f(x)= -0.573765
# differential_evolution step 13: f(x)= -0.574219
# differential_evolution step 14: f(x)= -0.574219
# differential_evolution step 15: f(x)= -0.574219
# differential_evolution step 16: f(x)= -0.574219
# differential_evolution step 17: f(x)= -0.574537
# differential_evolution step 18: f(x)= -0.574537
# differential_evolution step 19: f(x)= -0.574537
# differential_evolution step 20: f(x)= -0.574758
# differential_evolution step 21: f(x)= -0.574758
# differential_evolution step 22: f(x)= -0.574758
# differential_evolution step 23: f(x)= -0.574837
# differential_evolution step 24: f(x)= -0.57486
# differential_evolution step 25: f(x)= -0.57486
# differential_evolution step 26: f(x)= -0.575032
# differential_evolution step 27: f(x)= -0.575032
# differential_evolution step 28: f(x)= -0.575032
# differential_evolution step 29: f(x)= -0.575032
# differential_evolution step 30: f(x)= -0.575032
# differential_evolution step 31: f(x)= -0.575032
# differential_evolution step 32: f(x)= -0.575082
# differential_evolution step 33: f(x)= -0.575187
# differential_evolution step 34: f(x)= -0.575196
# differential_evolution step 35: f(x)= -0.575233
# differential_evolution step 36: f(x)= -0.575353
# differential_evolution step 37: f(x)= -0.575353
# differential_evolution step 38: f(x)= -0.575393
# differential_evolution step 39: f(x)= -0.575393
# differential_evolution step 40: f(x)= -0.575395
# differential_evolution step 41: f(x)= -0.575416
# differential_evolution step 42: f(x)= -0.575416
# differential_evolution step 43: f(x)= -0.575416
# differential_evolution step 44: f(x)= -0.575427
# differential_evolution step 45: f(x)= -0.575427
# differential_evolution step 46: f(x)= -0.575427
# differential_evolution step 47: f(x)= -0.575451
# differential_evolution step 48: f(x)= -0.575451
# differential_evolution step 49: f(x)= -0.575466
# differential_evolution step 50: f(x)= -0.575478
# differential_evolution step 51: f(x)= -0.575488
# differential_evolution step 52: f(x)= -0.575501
# differential_evolution step 53: f(x)= -0.575501
# differential_evolution step 54: f(x)= -0.575503
# differential_evolution step 55: f(x)= -0.575503
# differential_evolution step 56: f(x)= -0.575527
# differential_evolution step 57: f(x)= -0.575527
# differential_evolution step 58: f(x)= -0.575527
# differential_evolution step 59: f(x)= -0.575533
# differential_evolution step 60: f(x)= -0.575533
# differential_evolution step 61: f(x)= -0.575533
# differential_evolution step 62: f(x)= -0.575533
# differential_evolution step 63: f(x)= -0.575533
# differential_evolution step 64: f(x)= -0.575533
# differential_evolution step 65: f(x)= -0.575533
# differential_evolution step 66: f(x)= -0.575538
# differential_evolution step 67: f(x)= -0.575538
# differential_evolution step 68: f(x)= -0.575538
# differential_evolution step 69: f(x)= -0.575538
# -0.5755375470951987 [0.27084599 0.43772188 0.2794237  0.21623764 0.58218342 0.36051388
#  0.87480333 0.86880329 0.15292986 0.70448297 0.94174931 0.19144033
#  0.57440673 0.83260846 0.34976614 0.40844418 0.15966857 0.38471182
#  0.76843718 0.23550476 0.62979423 0.26718104 0.45219746 0.93469898
#  0.40725389]
# case: 15 (base reward: -0.54)
# differential_evolution step 1: f(x)= -0.551376
# differential_evolution step 2: f(x)= -0.552394
# differential_evolution step 3: f(x)= -0.552394
# differential_evolution step 4: f(x)= -0.553556
# differential_evolution step 5: f(x)= -0.553992
# differential_evolution step 6: f(x)= -0.553992
# differential_evolution step 7: f(x)= -0.553992
# differential_evolution step 8: f(x)= -0.554167
# differential_evolution step 9: f(x)= -0.554167
# differential_evolution step 10: f(x)= -0.554846
# differential_evolution step 11: f(x)= -0.554846
# differential_evolution step 12: f(x)= -0.555109
# differential_evolution step 13: f(x)= -0.555109
# differential_evolution step 14: f(x)= -0.555109
# differential_evolution step 15: f(x)= -0.555109
# differential_evolution step 16: f(x)= -0.555572
# differential_evolution step 17: f(x)= -0.555572
# differential_evolution step 18: f(x)= -0.556026
# differential_evolution step 19: f(x)= -0.556026
# differential_evolution step 20: f(x)= -0.556304
# differential_evolution step 21: f(x)= -0.556304
# differential_evolution step 22: f(x)= -0.556304
# differential_evolution step 23: f(x)= -0.556304
# differential_evolution step 24: f(x)= -0.55635
# differential_evolution step 25: f(x)= -0.556865
# differential_evolution step 26: f(x)= -0.556865
# differential_evolution step 27: f(x)= -0.556913
# differential_evolution step 28: f(x)= -0.556939
# differential_evolution step 29: f(x)= -0.556977
# differential_evolution step 30: f(x)= -0.556977
# differential_evolution step 31: f(x)= -0.557067
# differential_evolution step 32: f(x)= -0.557071
# differential_evolution step 33: f(x)= -0.55716
# differential_evolution step 34: f(x)= -0.557235
# differential_evolution step 35: f(x)= -0.557287
# differential_evolution step 36: f(x)= -0.557333
# differential_evolution step 37: f(x)= -0.557373
# differential_evolution step 38: f(x)= -0.557476
# differential_evolution step 39: f(x)= -0.557549
# differential_evolution step 40: f(x)= -0.557549
# differential_evolution step 41: f(x)= -0.5576
# differential_evolution step 42: f(x)= -0.5576
# differential_evolution step 43: f(x)= -0.557629
# differential_evolution step 44: f(x)= -0.557659
# differential_evolution step 45: f(x)= -0.557684
# differential_evolution step 46: f(x)= -0.557684
# differential_evolution step 47: f(x)= -0.557698
# differential_evolution step 48: f(x)= -0.557718
# differential_evolution step 49: f(x)= -0.557718
# differential_evolution step 50: f(x)= -0.557718
# differential_evolution step 51: f(x)= -0.557718
# differential_evolution step 52: f(x)= -0.557721
# differential_evolution step 53: f(x)= -0.557721
# differential_evolution step 54: f(x)= -0.557721
# differential_evolution step 55: f(x)= -0.557721
# differential_evolution step 56: f(x)= -0.557724
# differential_evolution step 57: f(x)= -0.557724
# differential_evolution step 58: f(x)= -0.557736
# differential_evolution step 59: f(x)= -0.557746
# differential_evolution step 60: f(x)= -0.557748
# differential_evolution step 61: f(x)= -0.55775
# differential_evolution step 62: f(x)= -0.557763
# differential_evolution step 63: f(x)= -0.557778
# differential_evolution step 64: f(x)= -0.557783
# differential_evolution step 65: f(x)= -0.557787
# differential_evolution step 66: f(x)= -0.557818
# differential_evolution step 67: f(x)= -0.557819
# differential_evolution step 68: f(x)= -0.557819
# differential_evolution step 69: f(x)= -0.557819
# differential_evolution step 70: f(x)= -0.557819
# differential_evolution step 71: f(x)= -0.557829
# differential_evolution step 72: f(x)= -0.557829
# differential_evolution step 73: f(x)= -0.557835
# differential_evolution step 74: f(x)= -0.557838
# differential_evolution step 75: f(x)= -0.557845
# differential_evolution step 76: f(x)= -0.557851
# differential_evolution step 77: f(x)= -0.557854
# differential_evolution step 78: f(x)= -0.557873
# differential_evolution step 79: f(x)= -0.557873
# differential_evolution step 80: f(x)= -0.557873
# differential_evolution step 81: f(x)= -0.557873
# -0.5578732276162709 [0.18888284 0.0065285  0.25704753 0.50981341 0.90565223 0.14766394
#  0.25770175 0.37297687 0.86323937 0.67200336 0.12607913 0.56445559
#  0.34087454 0.49534229 0.23022565 0.18337894 0.59607795 0.81296452
#  0.82861782 0.12275087 0.68239966 0.08152511 0.50186525 0.94913573
#  0.10430814]
