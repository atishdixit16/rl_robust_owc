# %%
# to access functions from other locations
import sys
sys.path.append('/data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/')

# %%
# %matplotlib notebook
import numpy as np
import time
import pickle
import os
import matplotlib.pyplot as plt

import gym
from stable_baselines3.ppo import PPO, MlpPolicy
# from utils.subproc_vec_env import SubprocVecEnv
# from utils.multiprocessing_env import SubprocVecEnv
from stable_baselines3.common.vec_env import SubprocVecEnv, DummyVecEnv
from stable_baselines3.common.callbacks import CallbackList
from utils.custom_eval_callback import CustomEvalCallback
from typing import Callable
from utils.plot_functions import plot_learning

from model.ressim import Grid
from ressim_env import ResSimEnv_v0, ResSimEnv_v1, ResSimEnv_v3
# Out:
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
seed=1
case='2ph_v1'

# %%
os.makedirs('./data', exist_ok=True)
os.makedirs('./data/'+case, exist_ok=True)

# %%
with open('../envs_params/env_data/env_'+case+'_train.pkl', 'rb') as input:
    env_train = pickle.load(input)
    
with open('../envs_params/env_data/env_'+case+'_eval_rl.pkl', 'rb') as input:
    env_eval = pickle.load(input)

# %%
# domain properties
nx = 61
ny = 61
lx = 1200*0.3048 # 1200 ft
ly = 1200*0.3048 # 1200 ft
grid = Grid(nx=nx, ny=ny, lx=lx, ly=ly)

k_train = np.load('../envs_params/k_data/k_log_md_train.npy')
md_m2_conv = 1/1.01325e+15
k_train = md_m2_conv*np.exp(k_train) 
phi = 0.2*np.ones(grid.shape)
s_wir = 0.2
s_oir = 0.2

# fluid properties
mu_w = 3e-4 # 0.3 cp
mu_o = 3e-3 # 3.0 cp
mobility='quadratic'

# time steps
dt = 0.5
nstep = 50
terminal_step= 5 # total: 125 days

# initial conditions
ooip = grid.lx * grid.ly * phi[0,0] * (1 - s_wir - s_oir) # original oil in place
total_time = nstep*terminal_step*dt
fraction = 0.4
Q = fraction*ooip/total_time 
q = np.zeros(grid.shape)
q[::2,0] = Q/round(grid.nx/2)
q[::2,-1] = -Q/round(grid.nx/2)
s = np.ones(grid.shape)*s_wir

env_train = ResSimEnv_v3(grid, k_train, phi, s_wir, s_oir,                     # domain properties
                         mu_w, mu_o, mobility,                                 # fluid properties
                         dt, nstep, terminal_step,                             # timesteps
                         q, s)

# %%
def make_env(env, rank: int, seed: int = 0) -> Callable:
    """
    Utility function for multiprocessed env.
    
    :param env_id: (str) the environment ID
    :param num_env: (int) the number of environment you wish to have in subprocesses
    :param seed: (int) the inital seed for RNG
    :param rank: (int) index of the subprocess
    :return: (Callable)
    """
    def _init() -> gym.Env:
        env_ = env
        env_.seed(seed + rank)
        return env_
    return _init

# %%
for seed in range(1,8):
    if seed>6:
        print(f'seed {seed}')
        log_dir = './data/'+case+'/seed_'+str(seed)
        os.makedirs(log_dir, exist_ok=True)
        num_cpu = 64
        env_train.seed(seed)
        env_eval.seed(seed)
        train_callback = CustomEvalCallback(env_train, best_model_save_path=str(log_dir)+'/best_model_train', n_eval_episodes=1,
                             log_path=str(log_dir)+'/results_train', eval_freq=100)
        eval_callback = CustomEvalCallback(env_eval, best_model_save_path=str(log_dir)+'/best_model_eval', n_eval_episodes=1,
                             log_path=str(log_dir)+'/results_eval', eval_freq=100)
        callback = CallbackList([train_callback, eval_callback])
        env = SubprocVecEnv([make_env(env_train, i, seed) for i in range(num_cpu)])
#     env = VecMonitor(env, filename=log_dir)
        print(f'seed {seed}: model definition ..')
        model = PPO(policy=MlpPolicy,
            env=env,
            learning_rate = 1e-5,
            n_steps = 4,
            batch_size = 16,
            n_epochs = 20,
            gamma = 0.99,
            gae_lambda = 0.95,
            clip_range = 0.2,
            clip_range_vf = None,
            ent_coef = 0.001,
            vf_coef = 0.5,
            max_grad_norm = 0.5,
            use_sde= False,
            create_eval_env= False,
            policy_kwargs = dict(net_arch=[4000,2000,800,300], log_std_init=-1.9),
            verbose = 1,
            seed = seed,
            device = "auto")
        print(f'seed {seed}: learning ..')
        model.learn(total_timesteps=400000, callback=callback)
        model.save(log_dir+'/PPO')
        del model
        fig = plot_learning(log_dir, case='train')
        fig.savefig(log_dir+'/learn_train.png')
        fig = plot_learning(log_dir, case='eval')
        fig.savefig(log_dir+'/learn_eval.png')
# Out:
# seed 7
# seed 7: model definition ..
# Using cuda device
# seed 7: learning ..
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7ff2d463b518> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7ff247322320>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7ff2d463b518> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7ff2d463ba90>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ----------------------------
# | time/              |     |
# |    fps             | 32  |
# |    iterations      | 1   |
# |    time_elapsed    | 7   |
# |    total_timesteps | 256 |
# ----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 2          |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 512        |
# | train/                  |            |
# |    approx_kl            | 0.16350397 |
# |    clip_fraction        | 0.667      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | -0.25      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 0.00871    |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0968    |
# |    std                  | 0.15       |
# |    value_loss           | 0.0181     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 3           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 768         |
# | train/                  |             |
# |    approx_kl            | -0.02630078 |
# |    clip_fraction        | 0.606       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | -1.66       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0828     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0978     |
# |    std                  | 0.15        |
# |    value_loss           | 0.0245      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 18         |
# |    iterations           | 4          |
# |    time_elapsed         | 56         |
# |    total_timesteps      | 1024       |
# | train/                  |            |
# |    approx_kl            | 0.11816039 |
# |    clip_fraction        | 0.665      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.875      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.11      |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.1       |
# |    std                  | 0.15       |
# |    value_loss           | 0.0303     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 5           |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 1280        |
# | train/                  |             |
# |    approx_kl            | 0.039962452 |
# |    clip_fraction        | 0.642       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0745     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.111      |
# |    std                  | 0.15        |
# |    value_loss           | 0.0127      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 6           |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.019170713 |
# |    clip_fraction        | 0.679       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0883     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.101      |
# |    std                  | 0.15        |
# |    value_loss           | 0.0108      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 7           |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 1792        |
# | train/                  |             |
# |    approx_kl            | 0.059330598 |
# |    clip_fraction        | 0.654       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.767       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0858     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.104      |
# |    std                  | 0.15        |
# |    value_loss           | 0.0264      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 8          |
# |    time_elapsed         | 121        |
# |    total_timesteps      | 2048       |
# | train/                  |            |
# |    approx_kl            | 0.08958109 |
# |    clip_fraction        | 0.698      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.647      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.111     |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.111     |
# |    std                  | 0.15       |
# |    value_loss           | 0.0094     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 9          |
# |    time_elapsed         | 137        |
# |    total_timesteps      | 2304       |
# | train/                  |            |
# |    approx_kl            | 0.06998211 |
# |    clip_fraction        | 0.659      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.562      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0503    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.103     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00228    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 10         |
# |    time_elapsed         | 154        |
# |    total_timesteps      | 2560       |
# | train/                  |            |
# |    approx_kl            | 0.13585332 |
# |    clip_fraction        | 0.7        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | -0.702     |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0915    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.11      |
# |    std                  | 0.15       |
# |    value_loss           | 0.0171     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 11         |
# |    time_elapsed         | 171        |
# |    total_timesteps      | 2816       |
# | train/                  |            |
# |    approx_kl            | 0.08481197 |
# |    clip_fraction        | 0.653      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | -0.308     |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.102     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0962    |
# |    std                  | 0.15       |
# |    value_loss           | 0.00854    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 12         |
# |    time_elapsed         | 187        |
# |    total_timesteps      | 3072       |
# | train/                  |            |
# |    approx_kl            | 0.24159747 |
# |    clip_fraction        | 0.623      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.484      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0821    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0822    |
# |    std                  | 0.15       |
# |    value_loss           | 0.000661   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 13         |
# |    time_elapsed         | 204        |
# |    total_timesteps      | 3328       |
# | train/                  |            |
# |    approx_kl            | 0.07460416 |
# |    clip_fraction        | 0.684      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.939      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.076     |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.104     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00128    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 14         |
# |    time_elapsed         | 221        |
# |    total_timesteps      | 3584       |
# | train/                  |            |
# |    approx_kl            | 0.24933742 |
# |    clip_fraction        | 0.717      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.721      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.116     |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.12      |
# |    std                  | 0.15       |
# |    value_loss           | 0.00272    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 15         |
# |    time_elapsed         | 237        |
# |    total_timesteps      | 3840       |
# | train/                  |            |
# |    approx_kl            | 0.11310342 |
# |    clip_fraction        | 0.714      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.935      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0715    |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.11      |
# |    std                  | 0.15       |
# |    value_loss           | 0.0302     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 16         |
# |    time_elapsed         | 254        |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.11424606 |
# |    clip_fraction        | 0.703      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.743      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.11      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.104     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00219    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 17         |
# |    time_elapsed         | 270        |
# |    total_timesteps      | 4352       |
# | train/                  |            |
# |    approx_kl            | 0.16038448 |
# |    clip_fraction        | 0.696      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.952      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0653    |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0944    |
# |    std                  | 0.15       |
# |    value_loss           | 0.00107    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 18         |
# |    time_elapsed         | 287        |
# |    total_timesteps      | 4608       |
# | train/                  |            |
# |    approx_kl            | 0.12585229 |
# |    clip_fraction        | 0.705      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.946      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0987    |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.096     |
# |    std                  | 0.15       |
# |    value_loss           | 0.000681   |
# ----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 15       |
# |    iterations           | 19       |
# |    time_elapsed         | 304      |
# |    total_timesteps      | 4864     |
# | train/                  |          |
# |    approx_kl            | 0.130096 |
# |    clip_fraction        | 0.732    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 29.8     |
# |    explained_variance   | 0.822    |
# |    learning_rate        | 1e-05    |
# |    loss                 | 0.0269   |
# |    n_updates            | 360      |
# |    policy_gradient_loss | -0.115   |
# |    std                  | 0.15     |
# |    value_loss           | 0.00462  |
# --------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 20          |
# |    time_elapsed         | 321         |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | -0.05769401 |
# |    clip_fraction        | 0.73        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | -33.1       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0589     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.117      |
# |    std                  | 0.15        |
# |    value_loss           | 0.0217      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 21         |
# |    time_elapsed         | 339        |
# |    total_timesteps      | 5376       |
# | train/                  |            |
# |    approx_kl            | 0.22025093 |
# |    clip_fraction        | 0.721      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | -2.83      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.1       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.111     |
# |    std                  | 0.15       |
# |    value_loss           | 0.0161     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 22         |
# |    time_elapsed         | 356        |
# |    total_timesteps      | 5632       |
# | train/                  |            |
# |    approx_kl            | 0.42200536 |
# |    clip_fraction        | 0.703      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | -1.73      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.083     |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0786    |
# |    std                  | 0.15       |
# |    value_loss           | 0.0059     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 23         |
# |    time_elapsed         | 374        |
# |    total_timesteps      | 5888       |
# | train/                  |            |
# |    approx_kl            | 0.28366062 |
# |    clip_fraction        | 0.72       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.434      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 0.0452     |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.102     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00685    |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 15        |
# |    iterations           | 24        |
# |    time_elapsed         | 391       |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 0.1705826 |
# |    clip_fraction        | 0.738     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 29.8      |
# |    explained_variance   | 0.629     |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.0871   |
# |    n_updates            | 460       |
# |    policy_gradient_loss | -0.108    |
# |    std                  | 0.15      |
# |    value_loss           | 0.00714   |
# ---------------------------------------
# Eval num_timesteps=6400, episode_reward=0.33 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=6400, episode_reward=0.33 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 5          |
# |    mean_reward          | 0.334      |
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 25         |
# |    time_elapsed         | 455        |
# |    total_timesteps      | 6400       |
# | train/                  |            |
# |    approx_kl            | 0.15561944 |
# |    clip_fraction        | 0.746      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | -0.599     |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.107     |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.112     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00318    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 26         |
# |    time_elapsed         | 472        |
# |    total_timesteps      | 6656       |
# | train/                  |            |
# |    approx_kl            | 0.16686644 |
# |    clip_fraction        | 0.711      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.819      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.113     |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0995    |
# |    std                  | 0.15       |
# |    value_loss           | 0.000761   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 27         |
# |    time_elapsed         | 488        |
# |    total_timesteps      | 6912       |
# | train/                  |            |
# |    approx_kl            | 0.11122196 |
# |    clip_fraction        | 0.722      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0841    |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.105     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00628    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 28         |
# |    time_elapsed         | 505        |
# |    total_timesteps      | 7168       |
# | train/                  |            |
# |    approx_kl            | 0.19659887 |
# |    clip_fraction        | 0.74       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.911      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0913    |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.108     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00106    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 29         |
# |    time_elapsed         | 521        |
# |    total_timesteps      | 7424       |
# | train/                  |            |
# |    approx_kl            | 0.09316089 |
# |    clip_fraction        | 0.721      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0714    |
# |    n_updates            | 560        |
# |    policy_gradient_loss | -0.104     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00069    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 30         |
# |    time_elapsed         | 538        |
# |    total_timesteps      | 7680       |
# | train/                  |            |
# |    approx_kl            | 0.09566708 |
# |    clip_fraction        | 0.739      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0445    |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.103     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00238    |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 14        |
# |    iterations           | 31        |
# |    time_elapsed         | 555       |
# |    total_timesteps      | 7936      |
# | train/                  |           |
# |    approx_kl            | 0.2920642 |
# |    clip_fraction        | 0.761     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 29.8      |
# |    explained_variance   | 0.609     |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.0426   |
# |    n_updates            | 600       |
# |    policy_gradient_loss | -0.0981   |
# |    std                  | 0.15      |
# |    value_loss           | 0.00367   |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 32         |
# |    time_elapsed         | 572        |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.08645976 |
# |    clip_fraction        | 0.759      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.909      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.121     |
# |    n_updates            | 620        |
# |    policy_gradient_loss | -0.107     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00177    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 33         |
# |    time_elapsed         | 590        |
# |    total_timesteps      | 8448       |
# | train/                  |            |
# |    approx_kl            | 0.15060553 |
# |    clip_fraction        | 0.747      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.936      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0734    |
# |    n_updates            | 640        |
# |    policy_gradient_loss | -0.11      |
# |    std                  | 0.15       |
# |    value_loss           | 0.0133     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 34         |
# |    time_elapsed         | 607        |
# |    total_timesteps      | 8704       |
# | train/                  |            |
# |    approx_kl            | 0.15944667 |
# |    clip_fraction        | 0.757      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | -0.306     |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.103     |
# |    n_updates            | 660        |
# |    policy_gradient_loss | -0.114     |
# |    std                  | 0.15       |
# |    value_loss           | 0.0198     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 35         |
# |    time_elapsed         | 624        |
# |    total_timesteps      | 8960       |
# | train/                  |            |
# |    approx_kl            | 0.06619315 |
# |    clip_fraction        | 0.737      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | -0.0736    |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.121     |
# |    n_updates            | 680        |
# |    policy_gradient_loss | -0.0965    |
# |    std                  | 0.15       |
# |    value_loss           | 0.0117     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 36         |
# |    time_elapsed         | 641        |
# |    total_timesteps      | 9216       |
# | train/                  |            |
# |    approx_kl            | 0.25787705 |
# |    clip_fraction        | 0.766      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.691      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 0.0318     |
# |    n_updates            | 700        |
# |    policy_gradient_loss | -0.0956    |
# |    std                  | 0.15       |
# |    value_loss           | 0.00547    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 37          |
# |    time_elapsed         | 657         |
# |    total_timesteps      | 9472        |
# | train/                  |             |
# |    approx_kl            | 0.039508615 |
# |    clip_fraction        | 0.755       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0974     |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.112      |
# |    std                  | 0.15        |
# |    value_loss           | 0.00443     |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 14        |
# |    iterations           | 38        |
# |    time_elapsed         | 674       |
# |    total_timesteps      | 9728      |
# | train/                  |           |
# |    approx_kl            | 0.1635581 |
# |    clip_fraction        | 0.792     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 29.8      |
# |    explained_variance   | 0.736     |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.119    |
# |    n_updates            | 740       |
# |    policy_gradient_loss | -0.106    |
# |    std                  | 0.15      |
# |    value_loss           | 0.00216   |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 39         |
# |    time_elapsed         | 691        |
# |    total_timesteps      | 9984       |
# | train/                  |            |
# |    approx_kl            | 0.13216813 |
# |    clip_fraction        | 0.737      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.763      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0298    |
# |    n_updates            | 760        |
# |    policy_gradient_loss | -0.107     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00424    |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 14        |
# |    iterations           | 40        |
# |    time_elapsed         | 708       |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.3744516 |
# |    clip_fraction        | 0.734     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 29.8      |
# |    explained_variance   | -0.968    |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.067    |
# |    n_updates            | 780       |
# |    policy_gradient_loss | -0.0963   |
# |    std                  | 0.15      |
# |    value_loss           | 0.0144    |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 41          |
# |    time_elapsed         | 725         |
# |    total_timesteps      | 10496       |
# | train/                  |             |
# |    approx_kl            | -0.06653403 |
# |    clip_fraction        | 0.709       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0371     |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.104      |
# |    std                  | 0.15        |
# |    value_loss           | 0.00389     |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 14        |
# |    iterations           | 42        |
# |    time_elapsed         | 741       |
# |    total_timesteps      | 10752     |
# | train/                  |           |
# |    approx_kl            | 0.0676652 |
# |    clip_fraction        | 0.745     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 29.8      |
# |    explained_variance   | 0.729     |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.0834   |
# |    n_updates            | 820       |
# |    policy_gradient_loss | -0.11     |
# |    std                  | 0.15      |
# |    value_loss           | 0.00283   |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 14        |
# |    iterations           | 43        |
# |    time_elapsed         | 758       |
# |    total_timesteps      | 11008     |
# | train/                  |           |
# |    approx_kl            | 0.5326569 |
# |    clip_fraction        | 0.79      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 29.8      |
# |    explained_variance   | 0.0581    |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.0717   |
# |    n_updates            | 840       |
# |    policy_gradient_loss | -0.118    |
# |    std                  | 0.15      |
# |    value_loss           | 0.0177    |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 44         |
# |    time_elapsed         | 775        |
# |    total_timesteps      | 11264      |
# | train/                  |            |
# |    approx_kl            | 0.12639898 |
# |    clip_fraction        | 0.74       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | -0.051     |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0891    |
# |    n_updates            | 860        |
# |    policy_gradient_loss | -0.113     |
# |    std                  | 0.15       |
# |    value_loss           | 0.0111     |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 14        |
# |    iterations           | 45        |
# |    time_elapsed         | 792       |
# |    total_timesteps      | 11520     |
# | train/                  |           |
# |    approx_kl            | 0.3057109 |
# |    clip_fraction        | 0.742     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 29.8      |
# |    explained_variance   | -2        |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.121    |
# |    n_updates            | 880       |
# |    policy_gradient_loss | -0.109    |
# |    std                  | 0.15      |
# |    value_loss           | 0.00701   |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 46         |
# |    time_elapsed         | 808        |
# |    total_timesteps      | 11776      |
# | train/                  |            |
# |    approx_kl            | 0.21563068 |
# |    clip_fraction        | 0.748      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.751      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0784    |
# |    n_updates            | 900        |
# |    policy_gradient_loss | -0.103     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00123    |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 14        |
# |    iterations           | 47        |
# |    time_elapsed         | 825       |
# |    total_timesteps      | 12032     |
# | train/                  |           |
# |    approx_kl            | 0.4180982 |
# |    clip_fraction        | 0.717     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 29.8      |
# |    explained_variance   | -0.341    |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.0778   |
# |    n_updates            | 920       |
# |    policy_gradient_loss | -0.0855   |
# |    std                  | 0.15      |
# |    value_loss           | 0.00516   |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 48         |
# |    time_elapsed         | 841        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.09406993 |
# |    clip_fraction        | 0.701      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.535      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0888    |
# |    n_updates            | 940        |
# |    policy_gradient_loss | -0.0835    |
# |    std                  | 0.15       |
# |    value_loss           | 0.00351    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 49         |
# |    time_elapsed         | 858        |
# |    total_timesteps      | 12544      |
# | train/                  |            |
# |    approx_kl            | 0.05805818 |
# |    clip_fraction        | 0.748      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.888      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.108     |
# |    n_updates            | 960        |
# |    policy_gradient_loss | -0.0994    |
# |    std                  | 0.15       |
# |    value_loss           | 0.00347    |
# ----------------------------------------
# Eval num_timesteps=12800, episode_reward=0.34 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=12800, episode_reward=0.33 +/- 0.00
# Episode length: 5.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 5          |
# |    mean_reward          | 0.33       |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 50         |
# |    time_elapsed         | 920        |
# |    total_timesteps      | 12800      |
# | train/                  |            |
# |    approx_kl            | 0.46344197 |
# |    clip_fraction        | 0.746      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | -6.06      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0186    |
# |    n_updates            | 980        |
# |    policy_gradient_loss | -0.0845    |
# |    std                  | 0.15       |
# |    value_loss           | 0.00838    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 51         |
# |    time_elapsed         | 937        |
# |    total_timesteps      | 13056      |
# | train/                  |            |
# |    approx_kl            | 0.24837314 |
# |    clip_fraction        | 0.758      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.7       |
# |    explained_variance   | 0.827      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.119     |
# |    n_updates            | 1000       |
# |    policy_gradient_loss | -0.105     |
# |    std                  | 0.15       |
# |    value_loss           | 0.000951   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 52           |
# |    time_elapsed         | 955          |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | -0.021232996 |
# |    clip_fraction        | 0.73         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 29.7         |
# |    explained_variance   | 0.796        |
# |    learning_rate        | 1e-05        |
# |    loss                 | -0.0911      |
# |    n_updates            | 1020         |
# |    policy_gradient_loss | -0.115       |
# |    std                  | 0.15         |
# |    value_loss           | 0.000987     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 53         |
# |    time_elapsed         | 972        |
# |    total_timesteps      | 13568      |
# | train/                  |            |
# |    approx_kl            | 0.20549095 |
# |    clip_fraction        | 0.737      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.7       |
# |    explained_variance   | 0.857      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0878    |
# |    n_updates            | 1040       |
# |    policy_gradient_loss | -0.0918    |
# |    std                  | 0.15       |
# |    value_loss           | 0.00128    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 54         |
# |    time_elapsed         | 989        |
# |    total_timesteps      | 13824      |
# | train/                  |            |
# |    approx_kl            | 0.14353849 |
# |    clip_fraction        | 0.744      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.7       |
# |    explained_variance   | 0.875      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.13      |
# |    n_updates            | 1060       |
# |    policy_gradient_loss | -0.0973    |
# |    std                  | 0.15       |
# |    value_loss           | 0.00134    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 55         |
# |    time_elapsed         | 1006       |
# |    total_timesteps      | 14080      |
# | train/                  |            |
# |    approx_kl            | 0.15524618 |
# |    clip_fraction        | 0.745      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.7       |
# |    explained_variance   | 0.856      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.096     |
# |    n_updates            | 1080       |
# |    policy_gradient_loss | -0.104     |
# |    std                  | 0.15       |
# |    value_loss           | 0.000832   |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 14        |
# |    iterations           | 56        |
# |    time_elapsed         | 1023      |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 0.1798597 |
# |    clip_fraction        | 0.739     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 29.7      |
# |    explained_variance   | 0.833     |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.0337   |
# |    n_updates            | 1100      |
# |    policy_gradient_loss | -0.103    |
# |    std                  | 0.15      |
# |    value_loss           | 0.00316   |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 57         |
# |    time_elapsed         | 1040       |
# |    total_timesteps      | 14592      |
# | train/                  |            |
# |    approx_kl            | 0.14754276 |
# |    clip_fraction        | 0.768      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.7       |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.105     |
# |    n_updates            | 1120       |
# |    policy_gradient_loss | -0.108     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00496    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 58         |
# |    time_elapsed         | 1057       |
# |    total_timesteps      | 14848      |
# | train/                  |            |
# |    approx_kl            | 0.19388753 |
# |    clip_fraction        | 0.675      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.7       |
# |    explained_variance   | 0.02       |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.00855   |
# |    n_updates            | 1140       |
# |    policy_gradient_loss | -0.0757    |
# |    std                  | 0.15       |
# |    value_loss           | 0.00153    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 59         |
# |    time_elapsed         | 1075       |
# |    total_timesteps      | 15104      |
# | train/                  |            |
# |    approx_kl            | 0.16119196 |
# |    clip_fraction        | 0.721      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.7       |
# |    explained_variance   | 0.966      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0977    |
# |    n_updates            | 1160       |
# |    policy_gradient_loss | -0.0943    |
# |    std                  | 0.15       |
# |    value_loss           | 0.000794   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 60         |
# |    time_elapsed         | 1092       |
# |    total_timesteps      | 15360      |
# | train/                  |            |
# |    approx_kl            | 0.15835431 |
# |    clip_fraction        | 0.765      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.7       |
# |    explained_variance   | 0.955      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.122     |
# |    n_updates            | 1180       |
# |    policy_gradient_loss | -0.0979    |
# |    std                  | 0.15       |
# |    value_loss           | 0.00116    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 61         |
# |    time_elapsed         | 1109       |
# |    total_timesteps      | 15616      |
# ...
# |    value_loss           | 0.000247   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 1544       |
# |    time_elapsed         | 22926      |
# |    total_timesteps      | 395264     |
# | train/                  |            |
# |    approx_kl            | 0.09603934 |
# |    clip_fraction        | 0.818      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 17.3       |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.134     |
# |    n_updates            | 30860      |
# |    policy_gradient_loss | -0.119     |
# |    std                  | 0.183      |
# |    value_loss           | 0.000352   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 1545       |
# |    time_elapsed         | 22938      |
# |    total_timesteps      | 395520     |
# | train/                  |            |
# |    approx_kl            | 0.13531822 |
# |    clip_fraction        | 0.764      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 17.3       |
# |    explained_variance   | 0.972      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.124     |
# |    n_updates            | 30880      |
# |    policy_gradient_loss | -0.0991    |
# |    std                  | 0.183      |
# |    value_loss           | 0.000317   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 1546       |
# |    time_elapsed         | 22949      |
# |    total_timesteps      | 395776     |
# | train/                  |            |
# |    approx_kl            | 0.07137067 |
# |    clip_fraction        | 0.831      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 17.3       |
# |    explained_variance   | 0.968      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.149     |
# |    n_updates            | 30900      |
# |    policy_gradient_loss | -0.121     |
# |    std                  | 0.183      |
# |    value_loss           | 0.000261   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 1547       |
# |    time_elapsed         | 22961      |
# |    total_timesteps      | 396032     |
# | train/                  |            |
# |    approx_kl            | 0.14446712 |
# |    clip_fraction        | 0.827      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 17.3       |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.12      |
# |    n_updates            | 30920      |
# |    policy_gradient_loss | -0.12      |
# |    std                  | 0.183      |
# |    value_loss           | 0.000309   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 1548       |
# |    time_elapsed         | 22973      |
# |    total_timesteps      | 396288     |
# | train/                  |            |
# |    approx_kl            | 0.23894459 |
# |    clip_fraction        | 0.797      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 17.3       |
# |    explained_variance   | 0.963      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.108     |
# |    n_updates            | 30940      |
# |    policy_gradient_loss | -0.11      |
# |    std                  | 0.183      |
# |    value_loss           | 0.000389   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 1549       |
# |    time_elapsed         | 22985      |
# |    total_timesteps      | 396544     |
# | train/                  |            |
# |    approx_kl            | 0.14627996 |
# |    clip_fraction        | 0.806      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 17.3       |
# |    explained_variance   | 0.982      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.127     |
# |    n_updates            | 30960      |
# |    policy_gradient_loss | -0.116     |
# |    std                  | 0.183      |
# |    value_loss           | 0.000272   |
# ----------------------------------------
# Eval num_timesteps=396800, episode_reward=0.38 +/- 0.00
# Episode length: 5.00 +/- 0.00
# Eval num_timesteps=396800, episode_reward=0.37 +/- 0.00
# Episode length: 5.00 +/- 0.00
# --------------------------------------
# | eval/                   |          |
# |    mean_ep_length       | 5        |
# |    mean_reward          | 0.375    |
# | time/                   |          |
# |    fps                  | 17       |
# |    iterations           | 1550     |
# |    time_elapsed         | 23044    |
# |    total_timesteps      | 396800   |
# | train/                  |          |
# |    approx_kl            | 0.075825 |
# |    clip_fraction        | 0.813    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 17.3     |
# |    explained_variance   | 0.986    |
# |    learning_rate        | 1e-05    |
# |    loss                 | -0.129   |
# |    n_updates            | 30980    |
# |    policy_gradient_loss | -0.122   |
# |    std                  | 0.183    |
# |    value_loss           | 0.000189 |
# --------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 1551        |
# |    time_elapsed         | 23055       |
# |    total_timesteps      | 397056      |
# | train/                  |             |
# |    approx_kl            | 0.038096964 |
# |    clip_fraction        | 0.817       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 17.2        |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.101      |
# |    n_updates            | 31000       |
# |    policy_gradient_loss | -0.107      |
# |    std                  | 0.183       |
# |    value_loss           | 0.000247    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 1552       |
# |    time_elapsed         | 23067      |
# |    total_timesteps      | 397312     |
# | train/                  |            |
# |    approx_kl            | 0.31387413 |
# |    clip_fraction        | 0.827      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 17.2       |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.138     |
# |    n_updates            | 31020      |
# |    policy_gradient_loss | -0.121     |
# |    std                  | 0.183      |
# |    value_loss           | 0.000297   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 1553       |
# |    time_elapsed         | 23079      |
# |    total_timesteps      | 397568     |
# | train/                  |            |
# |    approx_kl            | 0.16724804 |
# |    clip_fraction        | 0.817      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 17.2       |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0837    |
# |    n_updates            | 31040      |
# |    policy_gradient_loss | -0.122     |
# |    std                  | 0.183      |
# |    value_loss           | 0.000328   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 1554       |
# |    time_elapsed         | 23091      |
# |    total_timesteps      | 397824     |
# | train/                  |            |
# |    approx_kl            | 0.15949687 |
# |    clip_fraction        | 0.798      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 17.2       |
# |    explained_variance   | 0.97       |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.131     |
# |    n_updates            | 31060      |
# |    policy_gradient_loss | -0.115     |
# |    std                  | 0.183      |
# |    value_loss           | 0.000399   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 1555       |
# |    time_elapsed         | 23104      |
# |    total_timesteps      | 398080     |
# | train/                  |            |
# |    approx_kl            | 0.17602947 |
# |    clip_fraction        | 0.809      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 17.2       |
# |    explained_variance   | 0.97       |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0959    |
# |    n_updates            | 31080      |
# |    policy_gradient_loss | -0.119     |
# |    std                  | 0.183      |
# |    value_loss           | 0.000367   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 1556       |
# |    time_elapsed         | 23116      |
# |    total_timesteps      | 398336     |
# | train/                  |            |
# |    approx_kl            | 0.19168825 |
# |    clip_fraction        | 0.836      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 17.2       |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.144     |
# |    n_updates            | 31100      |
# |    policy_gradient_loss | -0.115     |
# |    std                  | 0.183      |
# |    value_loss           | 0.000298   |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 1557      |
# |    time_elapsed         | 23127     |
# |    total_timesteps      | 398592    |
# | train/                  |           |
# |    approx_kl            | 0.2014764 |
# |    clip_fraction        | 0.833     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 17.2      |
# |    explained_variance   | 0.963     |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.14     |
# |    n_updates            | 31120     |
# |    policy_gradient_loss | -0.122    |
# |    std                  | 0.183     |
# |    value_loss           | 0.000331  |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 1558       |
# |    time_elapsed         | 23139      |
# |    total_timesteps      | 398848     |
# | train/                  |            |
# |    approx_kl            | 0.06521264 |
# |    clip_fraction        | 0.787      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 17.2       |
# |    explained_variance   | 0.952      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0859    |
# |    n_updates            | 31140      |
# |    policy_gradient_loss | -0.103     |
# |    std                  | 0.183      |
# |    value_loss           | 0.00044    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 1559       |
# |    time_elapsed         | 23151      |
# |    total_timesteps      | 399104     |
# | train/                  |            |
# |    approx_kl            | 0.23144178 |
# |    clip_fraction        | 0.807      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 17.2       |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.1       |
# |    n_updates            | 31160      |
# |    policy_gradient_loss | -0.116     |
# |    std                  | 0.183      |
# |    value_loss           | 0.000321   |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 1560      |
# |    time_elapsed         | 23163     |
# |    total_timesteps      | 399360    |
# | train/                  |           |
# |    approx_kl            | 0.1286681 |
# |    clip_fraction        | 0.83      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 17.2      |
# |    explained_variance   | 0.982     |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.157    |
# |    n_updates            | 31180     |
# |    policy_gradient_loss | -0.124    |
# |    std                  | 0.184     |
# |    value_loss           | 0.000252  |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 1561        |
# |    time_elapsed         | 23175       |
# |    total_timesteps      | 399616      |
# | train/                  |             |
# |    approx_kl            | 0.090324104 |
# |    clip_fraction        | 0.806       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 17.1        |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.141      |
# |    n_updates            | 31200       |
# |    policy_gradient_loss | -0.113      |
# |    std                  | 0.184       |
# |    value_loss           | 0.000238    |
# -----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 17       |
# |    iterations           | 1562     |
# |    time_elapsed         | 23187    |
# |    total_timesteps      | 399872   |
# | train/                  |          |
# |    approx_kl            | 0.18245  |
# |    clip_fraction        | 0.819    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 17.1     |
# |    explained_variance   | 0.969    |
# |    learning_rate        | 1e-05    |
# |    loss                 | -0.0768  |
# |    n_updates            | 31220    |
# |    policy_gradient_loss | -0.114   |
# |    std                  | 0.184    |
# |    value_loss           | 0.000332 |
# --------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 1563       |
# |    time_elapsed         | 23199      |
# |    total_timesteps      | 400128     |
# | train/                  |            |
# |    approx_kl            | 0.17643353 |
# |    clip_fraction        | 0.798      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 17.1       |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.122     |
# |    n_updates            | 31240      |
# |    policy_gradient_loss | -0.121     |
# |    std                  | 0.184      |
# |    value_loss           | 0.000318   |
# ----------------------------------------
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">

# %%
env.close()

# %%
# action = [0.001, 1., 1., 0.48112956, 0.001, 0.001, 0.001, 1., 1., 0.001, 0.001, 0.001, 1., 1., 0.01334454, 0.77358127, 0.001, 0.001, 0.001, 1., 0.001, 0.001, 0.001, 0.001, 1.,    0.001, 1.,    1.,    1.,    0.001,  0.001, 1.,    1.,    0.001, 1.,  0.001, 0.001, 0.001, 0.001, 0.001, 1.,    1., 1.,    1.,    1.,    0.001, 0.001, 0.001,  0.001, 0.001, 1.,    0.001, 0.001, 1., 0.001, 1.,    0.001, 1.,    0.001, 1., 1.,0.001]
# self = env_eval

# # convert input array into producer/injector 
# inj_flow = action[:self.n_inj] / np.sum(action[:self.n_inj])
# inj_flow = self.Q * inj_flow
# prod_flow = action[self.n_inj:] / np.sum(action[self.n_inj:])
# prod_flow = -self.Q * prod_flow

# assert np.sum(inj_flow)>0, 'Invalid action: zero injector flow'
# assert np.sum(prod_flow)<0, 'Invalid action: zero producer flow'

# # add producer/injector flow values
# q = np.zeros(self.grid.shape)
# for i,(x,y) in enumerate( zip(self.i_x, self.i_y) ):
#     q[x,y] = inj_flow[i]

# for i,(x,y) in enumerate( zip(self.p_x, self.p_y) ):
#     q[x,y] = prod_flow[i]
    
# # if np.abs(np.sum(q)) < self.tol:
# #     q[3,3] = q[3,3] - np.sum(q) # to adjust unbalanced source term in arbitary location in the field due to precision error

# %%
# np.abs(np.sum(q))
