# %%
# to access functions from other locations
import sys
sys.path.append('/data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/')

# %%
# %matplotlib notebook
import numpy as np
import time
import pickle
import os
import matplotlib.pyplot as plt

import gym
from stable_baselines3.ppo import PPO, MlpPolicy
# from utils.subproc_vec_env import SubprocVecEnv
# from utils.multiprocessing_env import SubprocVecEnv
from stable_baselines3.common.vec_env import SubprocVecEnv, DummyVecEnv
from stable_baselines3.common.callbacks import CallbackList
from utils.custom_eval_callback import CustomEvalCallback
from typing import Callable
from utils.plot_functions import plot_learning

from model.ressim import Grid
from ressim_env import ResSimEnv_v0, ResSimEnv_v1, ResSimEnv_v3
# Out:
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
seed=1
case='1ph_v1'

# %%
os.makedirs('./data', exist_ok=True)
os.makedirs('./data/'+case, exist_ok=True)

# %%
with open('../envs_params/env_data/env_'+case+'_train.pkl', 'rb') as input:
    env_train = pickle.load(input)
    
rl_indices = [13,15,4,10,5,0,9,7,1]
with open('../envs_params/env_data/env_'+case+'_eval.pkl', 'rb') as input:
    env_eval = pickle.load(input)
k_list_rl = env_eval.k_list[rl_indices]
env_eval.set_k(k_list_rl)
    
with open('../envs_params/env_data/env_list_'+case+'_eval.pkl', 'rb') as input:
    envs = pickle.load(input)

# %%
def make_env(env, rank: int, seed: int = 0) -> Callable:
    """
    Utility function for multiprocessed env.
    
    :param env_id: (str) the environment ID
    :param num_env: (int) the number of environment you wish to have in subprocesses
    :param seed: (int) the inital seed for RNG
    :param rank: (int) index of the subprocess
    :return: (Callable)
    """
    def _init() -> gym.Env:
        env_ = env
        env_.seed(seed + rank)
        return env_
    return _init

# %%
for seed in range(1,6):
    if seed>3:
        print(f'seed {seed}')
        log_dir = './data/'+case+'/seed_'+str(seed)
        os.makedirs(log_dir, exist_ok=True)
        num_cpu = 64
        env_train.seed(seed)
        env_eval.seed(seed)
        train_callback = CustomEvalCallback(env_train, best_model_save_path=str(log_dir)+'/best_model_train', n_eval_episodes=1,
                             log_path=str(log_dir)+'/results_train', eval_freq=100)
        callback_list = [train_callback]
        for i in range(16):
            envs[i].seed(seed)
            eval_callback = CustomEvalCallback(envs[i], best_model_save_path=str(log_dir)+'/best_model_eval_'+str(i), n_eval_episodes=1,
                             log_path=str(log_dir)+'/results_eval_'+str(i), eval_freq=300)
            callback_list.append(eval_callback)
        eval_callback = CustomEvalCallback(env_eval, best_model_save_path=str(log_dir)+'/best_model_eval', n_eval_episodes=1,
                             log_path=str(log_dir)+'/results_eval', eval_freq=100)
        callback_list.append(eval_callback)
        callback = CallbackList(callback_list)
        env = SubprocVecEnv([make_env(env_train, i, seed) for i in range(num_cpu)])
#     env = VecMonitor(env, filename=log_dir)
        print(f'seed {seed}: model definition ..')
        model = PPO(policy=MlpPolicy,
            env=env,
            learning_rate = 1e-5,
            n_steps = 4,
            batch_size = 16,
            n_epochs = 20,
            gamma = 0.99,
            gae_lambda = 0.95,
            clip_range = 0.2,
            clip_range_vf = None,
            ent_coef = 0.001,
            vf_coef = 0.5,
            max_grad_norm = 0.5,
            use_sde= False,
            create_eval_env= False,
            policy_kwargs = dict(net_arch=[4000,2000,800,300], log_std_init=-1.9),
            verbose = 1,
            seed = seed,
            device = "auto")
        print(f'seed {seed}: learning ..')
        model.learn(total_timesteps=200000, callback=callback)
        model.save(log_dir+'/PPO')
        del model
        fig = plot_learning(log_dir, case='train')
        fig.savefig(log_dir+'/learn_train.png')
        fig = plot_learning(log_dir, case='eval')
        fig.savefig(log_dir+'/learn_eval.png')
# Out:
# seed 4
# seed 4: model definition ..
# Using cuda device
# seed 4: learning ..
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f0c78570550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f0c785e7e10>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f0c78570550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f0c785e7e48>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f0c78570550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f0c785e7e80>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f0c78570550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f0c785e7ef0>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f0c78570550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f0c785e7f60>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f0c78570550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f0c78570048>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f0c78570550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f0c78570080>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f0c78570550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f0c785700f0>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f0c78570550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f0c78570160>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f0c78570550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f0c785701d0>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f0c78570550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f0c78570240>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f0c78570550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f0c785702b0>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f0c78570550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f0c78570320>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f0c78570550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f0c78570390>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f0c78570550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f0c78570400>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f0c78570550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f0c785b2710>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f0c78570550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f0c78570470>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# /data/ad181/RemoteDir/k_variability_in_ressim_env/SPE10_like_envs/utils/custom_eval_callback.py:95: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f0c78570550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f0c785704e0>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ----------------------------
# | time/              |     |
# |    fps             | 91  |
# |    iterations      | 1   |
# |    time_elapsed    | 2   |
# |    total_timesteps | 256 |
# ----------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 59        |
# |    iterations           | 2         |
# |    time_elapsed         | 8         |
# |    total_timesteps      | 512       |
# | train/                  |           |
# |    approx_kl            | 0.2215068 |
# |    clip_fraction        | 0.637     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 29.8      |
# |    explained_variance   | -0.399    |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.0902   |
# |    n_updates            | 20        |
# |    policy_gradient_loss | -0.108    |
# |    std                  | 0.15      |
# |    value_loss           | 0.0503    |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 52          |
# |    iterations           | 3           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 768         |
# | train/                  |             |
# |    approx_kl            | -0.05211522 |
# |    clip_fraction        | 0.612       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0817     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.101      |
# |    std                  | 0.15        |
# |    value_loss           | 0.0241      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 4           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | -0.08579403 |
# |    clip_fraction        | 0.569       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.14        |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0487     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.089      |
# |    std                  | 0.15        |
# |    value_loss           | 0.0338      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 48         |
# |    iterations           | 5          |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 1280       |
# | train/                  |            |
# |    approx_kl            | 0.09076821 |
# |    clip_fraction        | 0.6        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | -0.0677    |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.102     |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0948    |
# |    std                  | 0.15       |
# |    value_loss           | 0.0109     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 6           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | -0.10202466 |
# |    clip_fraction        | 0.732       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.722       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0633     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.111      |
# |    std                  | 0.15        |
# |    value_loss           | 0.0333      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 46         |
# |    iterations           | 7          |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 1792       |
# | train/                  |            |
# |    approx_kl            | 0.44112653 |
# |    clip_fraction        | 0.672      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | -0.192     |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.119     |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0955    |
# |    std                  | 0.15       |
# |    value_loss           | 0.00681    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 46         |
# |    iterations           | 8          |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 2048       |
# | train/                  |            |
# |    approx_kl            | 0.10717364 |
# |    clip_fraction        | 0.63       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.921      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.116     |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.107     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00272    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 45         |
# |    iterations           | 9          |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 2304       |
# | train/                  |            |
# |    approx_kl            | -0.0908798 |
# |    clip_fraction        | 0.62       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.908      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.104     |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.107     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00568    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 45         |
# |    iterations           | 10         |
# |    time_elapsed         | 56         |
# |    total_timesteps      | 2560       |
# | train/                  |            |
# |    approx_kl            | 0.25592306 |
# |    clip_fraction        | 0.647      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.835      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.115     |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0983    |
# |    std                  | 0.15       |
# |    value_loss           | 0.00542    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 45         |
# |    iterations           | 11         |
# |    time_elapsed         | 61         |
# |    total_timesteps      | 2816       |
# | train/                  |            |
# |    approx_kl            | 0.14116575 |
# |    clip_fraction        | 0.797      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.541      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0663    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.128     |
# |    std                  | 0.15       |
# |    value_loss           | 0.0226     |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 45           |
# |    iterations           | 12           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | -0.042624645 |
# |    clip_fraction        | 0.598        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 29.8         |
# |    explained_variance   | 0.865        |
# |    learning_rate        | 1e-05        |
# |    loss                 | -0.1         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.107       |
# |    std                  | 0.15         |
# |    value_loss           | 0.00493      |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 45         |
# |    iterations           | 13         |
# |    time_elapsed         | 73         |
# |    total_timesteps      | 3328       |
# | train/                  |            |
# |    approx_kl            | 0.06522111 |
# |    clip_fraction        | 0.637      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.852      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.111     |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.102     |
# |    std                  | 0.15       |
# |    value_loss           | 0.003      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 14         |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 3584       |
# | train/                  |            |
# |    approx_kl            | 0.11203204 |
# |    clip_fraction        | 0.636      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.882      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0757    |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0957    |
# |    std                  | 0.15       |
# |    value_loss           | 0.00276    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 15         |
# |    time_elapsed         | 86         |
# |    total_timesteps      | 3840       |
# | train/                  |            |
# |    approx_kl            | 0.13074642 |
# |    clip_fraction        | 0.624      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.856      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0931    |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.092     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00236    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 16         |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.08457074 |
# |    clip_fraction        | 0.76       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.927      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0999    |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.111     |
# |    std                  | 0.15       |
# |    value_loss           | 0.0113     |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 44        |
# |    iterations           | 17        |
# |    time_elapsed         | 98        |
# |    total_timesteps      | 4352      |
# | train/                  |           |
# |    approx_kl            | 0.4667743 |
# |    clip_fraction        | 0.7       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 29.8      |
# |    explained_variance   | -0.075    |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.118    |
# |    n_updates            | 320       |
# |    policy_gradient_loss | -0.0985   |
# |    std                  | 0.15      |
# |    value_loss           | 0.00689   |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 18          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | -0.04500404 |
# |    clip_fraction        | 0.636       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0953     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.109      |
# |    std                  | 0.15        |
# |    value_loss           | 0.00357     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 19         |
# |    time_elapsed         | 110        |
# |    total_timesteps      | 4864       |
# | train/                  |            |
# |    approx_kl            | 0.17627707 |
# |    clip_fraction        | 0.679      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.101     |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.106     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00359    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 20         |
# |    time_elapsed         | 116        |
# |    total_timesteps      | 5120       |
# | train/                  |            |
# |    approx_kl            | 0.01923414 |
# |    clip_fraction        | 0.627      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.928      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0998    |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0949    |
# |    std                  | 0.15       |
# |    value_loss           | 0.003      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 21          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 5376        |
# | train/                  |             |
# |    approx_kl            | 0.037358295 |
# |    clip_fraction        | 0.749       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0978     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.106      |
# |    std                  | 0.15        |
# |    value_loss           | 0.00289     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 22          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 5632        |
# | train/                  |             |
# |    approx_kl            | -0.21952324 |
# |    clip_fraction        | 0.641       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0828     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0942     |
# |    std                  | 0.15        |
# |    value_loss           | 0.00353     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 23         |
# |    time_elapsed         | 134        |
# |    total_timesteps      | 5888       |
# | train/                  |            |
# |    approx_kl            | 0.09284487 |
# |    clip_fraction        | 0.67       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.925      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0768    |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.109     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00232    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 24         |
# |    time_elapsed         | 141        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.40846217 |
# |    clip_fraction        | 0.734      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.784      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0953    |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.117     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00467    |
# ----------------------------------------
# Eval num_timesteps=6400, episode_reward=0.64 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=6400, episode_reward=0.64 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 5          |
# |    mean_reward          | 0.643      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 25         |
# |    time_elapsed         | 169        |
# |    total_timesteps      | 6400       |
# | train/                  |            |
# |    approx_kl            | 0.19203365 |
# |    clip_fraction        | 0.69       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.89       |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.121     |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.115     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00374    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 26         |
# |    time_elapsed         | 176        |
# |    total_timesteps      | 6656       |
# | train/                  |            |
# |    approx_kl            | 0.18535832 |
# |    clip_fraction        | 0.788      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.892      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0708    |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.105     |
# |    std                  | 0.15       |
# |    value_loss           | 0.0158     |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 27        |
# |    time_elapsed         | 182       |
# |    total_timesteps      | 6912      |
# | train/                  |           |
# |    approx_kl            | -0.297965 |
# |    clip_fraction        | 0.687     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 29.8      |
# |    explained_variance   | 0.79      |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.115    |
# |    n_updates            | 520       |
# |    policy_gradient_loss | -0.11     |
# |    std                  | 0.15      |
# |    value_loss           | 0.00595   |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 28          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.089810275 |
# |    clip_fraction        | 0.653       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.12       |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.112      |
# |    std                  | 0.15        |
# |    value_loss           | 0.004       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 29         |
# |    time_elapsed         | 195        |
# |    total_timesteps      | 7424       |
# | train/                  |            |
# |    approx_kl            | 0.15688567 |
# |    clip_fraction        | 0.695      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.928      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.138     |
# |    n_updates            | 560        |
# |    policy_gradient_loss | -0.111     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00195    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 30          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.012770023 |
# |    clip_fraction        | 0.685       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.01       |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.105      |
# |    std                  | 0.15        |
# |    value_loss           | 0.00145     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 31         |
# |    time_elapsed         | 206        |
# |    total_timesteps      | 7936       |
# | train/                  |            |
# |    approx_kl            | 0.17205493 |
# |    clip_fraction        | 0.763      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.868      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0928    |
# |    n_updates            | 600        |
# |    policy_gradient_loss | -0.117     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00796    |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 38        |
# |    iterations           | 32        |
# |    time_elapsed         | 212       |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.4056897 |
# |    clip_fraction        | 0.73      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 29.8      |
# |    explained_variance   | -0.0168   |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.134    |
# |    n_updates            | 620       |
# |    policy_gradient_loss | -0.111    |
# |    std                  | 0.15      |
# |    value_loss           | 0.00619   |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 33         |
# |    time_elapsed         | 218        |
# |    total_timesteps      | 8448       |
# | train/                  |            |
# |    approx_kl            | 0.29023796 |
# |    clip_fraction        | 0.714      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.921      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.103     |
# |    n_updates            | 640        |
# |    policy_gradient_loss | -0.11      |
# |    std                  | 0.15       |
# |    value_loss           | 0.00287    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 34          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 8704        |
# | train/                  |             |
# |    approx_kl            | 0.043083206 |
# |    clip_fraction        | 0.703       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.12       |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.112      |
# |    std                  | 0.15        |
# |    value_loss           | 0.00165     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 35          |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 8960        |
# | train/                  |             |
# |    approx_kl            | -0.13796556 |
# |    clip_fraction        | 0.68        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0857     |
# |    n_updates            | 680         |
# |    policy_gradient_loss | -0.114      |
# |    std                  | 0.15        |
# |    value_loss           | 0.00557     |
# -----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 38       |
# |    iterations           | 36       |
# |    time_elapsed         | 236      |
# |    total_timesteps      | 9216     |
# | train/                  |          |
# |    approx_kl            | 0.187282 |
# |    clip_fraction        | 0.784    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 29.8     |
# |    explained_variance   | 0.892    |
# |    learning_rate        | 1e-05    |
# |    loss                 | -0.095   |
# |    n_updates            | 700      |
# |    policy_gradient_loss | -0.113   |
# |    std                  | 0.15     |
# |    value_loss           | 0.00201  |
# --------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 37         |
# |    time_elapsed         | 242        |
# |    total_timesteps      | 9472       |
# | train/                  |            |
# |    approx_kl            | 0.22041415 |
# |    clip_fraction        | 0.719      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.867      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.108     |
# |    n_updates            | 720        |
# |    policy_gradient_loss | -0.113     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00213    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 38          |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 9728        |
# | train/                  |             |
# |    approx_kl            | 0.076542035 |
# |    clip_fraction        | 0.683       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0597     |
# |    n_updates            | 740         |
# |    policy_gradient_loss | -0.113      |
# |    std                  | 0.15        |
# |    value_loss           | 0.00137     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 39          |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 9984        |
# | train/                  |             |
# |    approx_kl            | 0.060271636 |
# |    clip_fraction        | 0.686       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.114      |
# |    n_updates            | 760         |
# |    policy_gradient_loss | -0.11       |
# |    std                  | 0.15        |
# |    value_loss           | 0.0013      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 40          |
# |    time_elapsed         | 260         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | -0.07493445 |
# |    clip_fraction        | 0.668       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.115      |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.105      |
# |    std                  | 0.15        |
# |    value_loss           | 0.00198     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 41         |
# |    time_elapsed         | 266        |
# |    total_timesteps      | 10496      |
# | train/                  |            |
# |    approx_kl            | 0.18310353 |
# |    clip_fraction        | 0.789      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.889      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.111     |
# |    n_updates            | 800        |
# |    policy_gradient_loss | -0.122     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00542    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 42         |
# |    time_elapsed         | 273        |
# |    total_timesteps      | 10752      |
# | train/                  |            |
# |    approx_kl            | 0.13387504 |
# |    clip_fraction        | 0.712      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.688      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.122     |
# |    n_updates            | 820        |
# |    policy_gradient_loss | -0.113     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00538    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 43          |
# |    time_elapsed         | 279         |
# |    total_timesteps      | 11008       |
# | train/                  |             |
# |    approx_kl            | 0.059886448 |
# |    clip_fraction        | 0.725       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.144      |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.118      |
# |    std                  | 0.15        |
# |    value_loss           | 0.00222     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 44          |
# |    time_elapsed         | 285         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.014335543 |
# |    clip_fraction        | 0.695       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.11       |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.11       |
# |    std                  | 0.15        |
# |    value_loss           | 0.00278     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 45           |
# |    time_elapsed         | 292          |
# |    total_timesteps      | 11520        |
# | train/                  |              |
# |    approx_kl            | -0.058805298 |
# |    clip_fraction        | 0.69         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 29.8         |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 1e-05        |
# |    loss                 | -0.0985      |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.0969      |
# |    std                  | 0.15         |
# |    value_loss           | 0.00174      |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 46         |
# |    time_elapsed         | 299        |
# |    total_timesteps      | 11776      |
# | train/                  |            |
# |    approx_kl            | 0.14454782 |
# |    clip_fraction        | 0.805      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 29.8       |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0905    |
# |    n_updates            | 900        |
# |    policy_gradient_loss | -0.114     |
# |    std                  | 0.15       |
# |    value_loss           | 0.00233    |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 39        |
# |    iterations           | 47        |
# |    time_elapsed         | 306       |
# |    total_timesteps      | 12032     |
# | train/                  |           |
# |    approx_kl            | 0.4438413 |
# |    clip_fraction        | 0.732     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 29.8      |
# |    explained_variance   | 0.896     |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.0904   |
# |    n_updates            | 920       |
# |    policy_gradient_loss | -0.111    |
# |    std                  | 0.15      |
# |    value_loss           | 0.00304   |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 48           |
# |    time_elapsed         | 312          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | -0.010653291 |
# |    clip_fraction        | 0.692        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 29.8         |
# |    explained_variance   | 0.922        |
# |    learning_rate        | 1e-05        |
# |    loss                 | -0.132       |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.124       |
# |    std                  | 0.15         |
# |    value_loss           | 0.00209      |
# ------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 39        |
# |    iterations           | 49        |
# |    time_elapsed         | 318       |
# |    total_timesteps      | 12544     |
# | train/                  |           |
# |    approx_kl            | 0.0688866 |
# |    clip_fraction        | 0.727     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 29.8      |
# |    explained_variance   | 0.96      |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.121    |
# |    n_updates            | 960       |
# |    policy_gradient_loss | -0.121    |
# |    std                  | 0.15      |
# |    value_loss           | 0.00133   |
# ---------------------------------------
# Eval num_timesteps=12800, episode_reward=0.67 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=12800, episode_reward=0.65 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.647       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 50          |
# |    time_elapsed         | 345         |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | -0.06923977 |
# |    clip_fraction        | 0.697       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.125      |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.113      |
# |    std                  | 0.15        |
# |    value_loss           | 0.00203     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 51          |
# |    time_elapsed         | 352         |
# |    total_timesteps      | 13056       |
# | train/                  |             |
# |    approx_kl            | 0.090965986 |
# |    clip_fraction        | 0.821       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 29.8        |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 1e-05       |
# ...
# |    fps                  | 35          |
# |    iterations           | 763         |
# |    time_elapsed         | 5469        |
# |    total_timesteps      | 195328      |
# | train/                  |             |
# |    approx_kl            | 0.046499237 |
# |    clip_fraction        | 0.833       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 24.5        |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.116      |
# |    n_updates            | 15240       |
# |    policy_gradient_loss | -0.127      |
# |    std                  | 0.163       |
# |    value_loss           | 0.00041     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 764        |
# |    time_elapsed         | 5475       |
# |    total_timesteps      | 195584     |
# | train/                  |            |
# |    approx_kl            | 0.30573454 |
# |    clip_fraction        | 0.794      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 24.5       |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.101     |
# |    n_updates            | 15260      |
# |    policy_gradient_loss | -0.107     |
# |    std                  | 0.163      |
# |    value_loss           | 0.000413   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 765        |
# |    time_elapsed         | 5481       |
# |    total_timesteps      | 195840     |
# | train/                  |            |
# |    approx_kl            | 0.26744556 |
# |    clip_fraction        | 0.796      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 24.5       |
# |    explained_variance   | 0.993      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.112     |
# |    n_updates            | 15280      |
# |    policy_gradient_loss | -0.115     |
# |    std                  | 0.163      |
# |    value_loss           | 0.000368   |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 35        |
# |    iterations           | 766       |
# |    time_elapsed         | 5487      |
# |    total_timesteps      | 196096    |
# | train/                  |           |
# |    approx_kl            | 0.1659993 |
# |    clip_fraction        | 0.845     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 24.5      |
# |    explained_variance   | 0.985     |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.138    |
# |    n_updates            | 15300     |
# |    policy_gradient_loss | -0.121    |
# |    std                  | 0.163     |
# |    value_loss           | 0.000382  |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 767        |
# |    time_elapsed         | 5493       |
# |    total_timesteps      | 196352     |
# | train/                  |            |
# |    approx_kl            | 0.16387267 |
# |    clip_fraction        | 0.787      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 24.5       |
# |    explained_variance   | 0.979      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.076     |
# |    n_updates            | 15320      |
# |    policy_gradient_loss | -0.115     |
# |    std                  | 0.163      |
# |    value_loss           | 0.000392   |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 35        |
# |    iterations           | 768       |
# |    time_elapsed         | 5499      |
# |    total_timesteps      | 196608    |
# | train/                  |           |
# |    approx_kl            | 0.2010827 |
# |    clip_fraction        | 0.778     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 24.5      |
# |    explained_variance   | 0.993     |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.113    |
# |    n_updates            | 15340     |
# |    policy_gradient_loss | -0.117    |
# |    std                  | 0.163     |
# |    value_loss           | 0.00048   |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 769         |
# |    time_elapsed         | 5505        |
# |    total_timesteps      | 196864      |
# | train/                  |             |
# |    approx_kl            | -0.09048518 |
# |    clip_fraction        | 0.785       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 24.5        |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.124      |
# |    n_updates            | 15360       |
# |    policy_gradient_loss | -0.112      |
# |    std                  | 0.163       |
# |    value_loss           | 0.000817    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 35           |
# |    iterations           | 770          |
# |    time_elapsed         | 5511         |
# |    total_timesteps      | 197120       |
# | train/                  |              |
# |    approx_kl            | -0.053161424 |
# |    clip_fraction        | 0.796        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 24.5         |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 1e-05        |
# |    loss                 | -0.138       |
# |    n_updates            | 15380        |
# |    policy_gradient_loss | -0.108       |
# |    std                  | 0.163        |
# |    value_loss           | 0.000557     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 771        |
# |    time_elapsed         | 5517       |
# |    total_timesteps      | 197376     |
# | train/                  |            |
# |    approx_kl            | 0.61114347 |
# |    clip_fraction        | 0.862      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 24.5       |
# |    explained_variance   | 0.913      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.127     |
# |    n_updates            | 15400      |
# |    policy_gradient_loss | -0.116     |
# |    std                  | 0.163      |
# |    value_loss           | 0.000513   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 772        |
# |    time_elapsed         | 5523       |
# |    total_timesteps      | 197632     |
# | train/                  |            |
# |    approx_kl            | 0.49196285 |
# |    clip_fraction        | 0.816      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 24.4       |
# |    explained_variance   | 0.917      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.118     |
# |    n_updates            | 15420      |
# |    policy_gradient_loss | -0.114     |
# |    std                  | 0.163      |
# |    value_loss           | 0.000556   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 773         |
# |    time_elapsed         | 5529        |
# |    total_timesteps      | 197888      |
# | train/                  |             |
# |    approx_kl            | 0.049780563 |
# |    clip_fraction        | 0.796       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 24.4        |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.114      |
# |    n_updates            | 15440       |
# |    policy_gradient_loss | -0.117      |
# |    std                  | 0.163       |
# |    value_loss           | 0.000354    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 774         |
# |    time_elapsed         | 5535        |
# |    total_timesteps      | 198144      |
# | train/                  |             |
# |    approx_kl            | 0.086762905 |
# |    clip_fraction        | 0.77        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 24.4        |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.11       |
# |    n_updates            | 15460       |
# |    policy_gradient_loss | -0.105      |
# |    std                  | 0.163       |
# |    value_loss           | 0.000405    |
# -----------------------------------------
# Eval num_timesteps=198400, episode_reward=0.70 +/- 0.00
# Episode length: 5.00 +/- 0.00
# Eval num_timesteps=198400, episode_reward=0.69 +/- 0.00
# Episode length: 5.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 5          |
# |    mean_reward          | 0.686      |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 775        |
# |    time_elapsed         | 5558       |
# |    total_timesteps      | 198400     |
# | train/                  |            |
# |    approx_kl            | 0.18171287 |
# |    clip_fraction        | 0.803      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 24.4       |
# |    explained_variance   | 0.991      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.132     |
# |    n_updates            | 15480      |
# |    policy_gradient_loss | -0.106     |
# |    std                  | 0.163      |
# |    value_loss           | 0.000395   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 776        |
# |    time_elapsed         | 5563       |
# |    total_timesteps      | 198656     |
# | train/                  |            |
# |    approx_kl            | 0.10516917 |
# |    clip_fraction        | 0.854      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 24.4       |
# |    explained_variance   | 0.986      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0918    |
# |    n_updates            | 15500      |
# |    policy_gradient_loss | -0.108     |
# |    std                  | 0.163      |
# |    value_loss           | 0.000269   |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 35        |
# |    iterations           | 777       |
# |    time_elapsed         | 5570      |
# |    total_timesteps      | 198912    |
# | train/                  |           |
# |    approx_kl            | 0.1833359 |
# |    clip_fraction        | 0.775     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 24.4      |
# |    explained_variance   | 0.982     |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.111    |
# |    n_updates            | 15520     |
# |    policy_gradient_loss | -0.12     |
# |    std                  | 0.163     |
# |    value_loss           | 0.000429  |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 778         |
# |    time_elapsed         | 5576        |
# |    total_timesteps      | 199168      |
# | train/                  |             |
# |    approx_kl            | 0.041056857 |
# |    clip_fraction        | 0.794       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 24.4        |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.13       |
# |    n_updates            | 15540       |
# |    policy_gradient_loss | -0.123      |
# |    std                  | 0.163       |
# |    value_loss           | 0.000486    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 35           |
# |    iterations           | 779          |
# |    time_elapsed         | 5583         |
# |    total_timesteps      | 199424       |
# | train/                  |              |
# |    approx_kl            | -0.026346684 |
# |    clip_fraction        | 0.795        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 24.4         |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 1e-05        |
# |    loss                 | -0.0622      |
# |    n_updates            | 15560        |
# |    policy_gradient_loss | -0.107       |
# |    std                  | 0.163        |
# |    value_loss           | 0.000622     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 780        |
# |    time_elapsed         | 5589       |
# |    total_timesteps      | 199680     |
# | train/                  |            |
# |    approx_kl            | 0.33064193 |
# |    clip_fraction        | 0.773      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 24.4       |
# |    explained_variance   | 0.979      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.112     |
# |    n_updates            | 15580      |
# |    policy_gradient_loss | -0.0971    |
# |    std                  | 0.163      |
# |    value_loss           | 0.00071    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 781        |
# |    time_elapsed         | 5595       |
# |    total_timesteps      | 199936     |
# | train/                  |            |
# |    approx_kl            | 0.20789252 |
# |    clip_fraction        | 0.842      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 24.4       |
# |    explained_variance   | 0.98       |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0838    |
# |    n_updates            | 15600      |
# |    policy_gradient_loss | -0.109     |
# |    std                  | 0.163      |
# |    value_loss           | 0.000449   |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 35        |
# |    iterations           | 782       |
# |    time_elapsed         | 5601      |
# |    total_timesteps      | 200192    |
# | train/                  |           |
# |    approx_kl            | 0.2623958 |
# |    clip_fraction        | 0.806     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 24.4      |
# |    explained_variance   | 0.984     |
# |    learning_rate        | 1e-05     |
# |    loss                 | -0.112    |
# |    n_updates            | 15620     |
# |    policy_gradient_loss | -0.124    |
# |    std                  | 0.163     |
# |    value_loss           | 0.000475  |
# ---------------------------------------
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">
