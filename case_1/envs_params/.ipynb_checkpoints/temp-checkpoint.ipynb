# %%
# to access functions from other locations
import sys
sys.path.append('/data/ad181/RemoteDir/rl_robust_owc/')

# %%
# %matplotlib notebook
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt 
import functools
from time import time, sleep
from mpl_toolkits.axes_grid1 import make_axes_locatable

from utils.plot_functions import plot_k_array, plot_k
# Out:
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
log_k_dir = './k_data'
k_eval = np.load(log_k_dir+'/k_log_md_eval.npy')

# %%
fig, axs = plt.subplots(1,1, figsize=(4,4) )
k_index = 3
im = plot_k(k_eval[k_index], q=None, axs=axs, title='')
divider = make_axes_locatable(axs)
cax = divider.append_axes('right', size='5%', pad=0.05)
fig.colorbar(im, cax=cax, orientation='vertical')
fig.savefig('../data_viz/1ph_v1/1ph_v1_k_sample_w_legend.pdf')
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
# case_='1ph_v1'
# md_m2_conv = 1/1.01325e+15
# with open('env_data/env_'+case_+'_train.pkl', 'rb') as input:
#     env = pickle.load(input)
# env.set_k(np.array([ md_m2_conv*np.exp(k_eval[k_index]) ]))
# action = np.ones(62)

# ps = []
# state, done = env.reset(), False
# print(env.solverP.p)
# while not done:
#     state, reward, done, info = env.step(action)
#     ps.append(env.solverP.p)
    
# ps = np.array(ps)
# org_shape = ps.shape
# ps = ps.reshape(-1)
# ps_scaled = np.interp(ps, (ps.min(), ps.max()), (-1,1))
# ps_scaled = ps_scaled.reshape(org_shape)

# fig, axs = plt.subplots(1,5, figsize=(10,2) )
# for p,ax in zip(ps_scaled, axs):
#     im = plot_k(p, q=None, axs=ax, title='')
# #     print('\n')
# #     for x,y in zip(env.i_x, env.i_y):
# #         print(x,y,p[x,y])
# #     for x,y in zip(env.p_x, env.p_y):
# #         print(x,y,p[x,y])
#     divider = make_axes_locatable(ax)
#     cax = divider.append_axes('right', size='10%', pad=0.05)
#     fig.colorbar(im, cax=cax, orientation='vertical')
# plt.show()

# %%
# case_='2ph_v1'
# md_m2_conv = 1/1.01325e+15
# with open('env_data/env_'+case_+'_train.pkl', 'rb') as input:
#     env = pickle.load(input)
# env.set_k(np.array([ md_m2_conv*np.exp(k_eval[k_index]) ]))
# action = np.ones(62)

# ps = []
# state, done = env.reset(), False
# while not done:
#     state, reward, done, info = env.step(action)
#     ps.append(env.solverP.p)
    
# ps = np.array(ps)
# org_shape = ps.shape
# ps = ps.reshape(-1)
# ps_scaled = np.interp(ps, (ps.min(), ps.max()), (-1,1))
# ps_scaled = ps_scaled.reshape(org_shape)

# fig, axs = plt.subplots(1,5, figsize=(10,2) )
# for p,ax in zip(ps_scaled, axs):
#     im = plot_k(p, q=None, axs=ax, title='')
# #     print('\n')
# #     for x,y in zip(env.i_x, env.i_y):
# #         print(x,y,p[x,y])
# #     for x,y in zip(env.p_x, env.p_y):
# #         print(x,y,p[x,y])
#     divider = make_axes_locatable(ax)
#     cax = divider.append_axes('right', size='10%', pad=0.05)
#     fig.colorbar(im, cax=cax, orientation='vertical')
# plt.show()
